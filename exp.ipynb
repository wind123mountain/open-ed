# %%
from datasets import load_dataset


ace_gen = load_dataset("datht/ace-short-generated-dataset")

# %%
# ace = load_dataset("datht/ace-event-dataset")

# %%
# system_prompt = """You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.
# IMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.
# Output Format (JSON only, no markdown):

# {"events": [{"trigger_text": <trigger span>, "type": <event type>, "arguments": [{"text": <argument span>, "role": <semantic role>}, {"text": <argument span 2>, "role": <semantic role 2>}], "description": <description>}, {"trigger_text": <trigger span 2>, "type": <event type 2>, "arguments": [], "description": <description 2>}]} 

# - If no events are detected, return: {"events": []}"""

# user_prompt = """Given an input text: 
# <input>
# {input}
# </input>

# Your task is to extract all events present in the text. The text may contain zero, one, or multiple events.

# For each event:
# - Identify a trigger: the word or phrase that most clearly indicates the event.
# - Identify event type
# - Extract all relevant arguments participating in the event.
# - Each argument must be an exact span from the text and assigned a semantic role.
# - Description: explaining what this event type means

# Constraints and Guidelines
# - Do not invent information not supported by the text.
# - Do not paraphrase triggers or arguments.
# - The "text" field must exactly match a span in the original input (from <input>...</input>).
# """

# %%
# system_prompt = """You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.
# IMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.
# Output Format (JSON only, no markdown):

# {"events": [{"trigger_text": <trigger span>, "type": <event type>, "arguments": [{"text": <argument span>, "role": <semantic role>}, {"text": <argument span 2>, "role": <semantic role 2>}]}, {"trigger_text": <trigger span 2>, "type": <event type 2>, "arguments": []}]} 

# - If no events are detected, return: {"events": []}"""

# user_prompt = """Given an input text: 
# <input>
# {input}
# </input>

# Your task is to extract all events present in the text. The text may contain zero, one, or multiple events.

# For each event:
# - Identify a trigger: the word or phrase that most clearly indicates the event.
# - Identify event type
# - Extract all relevant arguments participating in the event.
# - Each argument must be an exact span from the text and assigned a semantic role.

# Constraints and Guidelines
# - Do not invent information not supported by the text.
# - Do not paraphrase triggers or arguments.
# - The "text" field must exactly match a span in the original input (from <input>...</input>).
# """

# %%
# system_prompt = """You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.
# IMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.
# Output Format (JSON only, no markdown):

# {"events": [[<trigger span>, <event type>, <description>], [<trigger span 2>, <event type 2>, <description 2>]]} 

# - If no events are detected, return: {"events": []}"""

# user_prompt = """Given an input text: 
# <input>
# {input}
# </input>

# Your task is to extract all events present in the text. The text may contain zero, one, or multiple events.

# For each event:
# - Identify a trigger: the word or phrase that most clearly indicates the event.
# - Identify event type
# - Description: explaining what this event type means

# Constraints and Guidelines
# - Do not invent information not supported by the text.
# - Do not paraphrase triggers or arguments.
# - The "text" field must exactly match a span in the original input (from <input>...</input>).
# """

# %%
system_prompt = """You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.
IMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.
Output Format (JSON only, no markdown):

{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}

- If no events are detected, return: {"events": []}"""

user_prompt = """Given an input text: 
<input>
{input}
</input>

Your task is to extract all events present in the text. The text may contain zero, one, or multiple events.

For each event:
- Identify a trigger: the word or phrase that most clearly indicates the event.
- Identify event type
- Description: explaining what this event type means

Constraints and Guidelines
- Do not invent information not supported by the text.
- Do not paraphrase triggers or arguments.
- The "text" field must exactly match a span in the original input (from <input>...</input>).
"""

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained('Qwen/Qwen3-0.6B', padding_side="right")

# %%
import json
import numpy as np
import random


def process_data(raw_data, is_test=False):
    full_len = []
    sent_total = 0
    data = []
    prompt_len = []
    response_len = []
    none_data = []

    for sample in raw_data:
        sent_id_to_sentence = {i: content['sentence'] for i, content in enumerate(sample["content"])}
        sent_id_set = set(sent_id_to_sentence.keys())
        sent_total += len(sent_id_to_sentence)
        sent_to_existing_events = {}
        for event in sample.get("events", []):
            if event.get("type_id", -1) == -1: continue
            event_type = event.get("type")
            description = event.get("description")
            
            for mention in event.get("mention", []):
                sent_id = mention.get("sent_id")
                             
                if sent_id not in sent_to_existing_events:
                    sent_to_existing_events[sent_id] = []

                args = [[arg["text"], arg["role"]] for arg in mention.get("arguments", [])]
                # args = [{"text": arg["text"], "role": arg["role"]} for arg in mention.get("arguments", [])]
                event_info = [mention.get("trigger_word"), event_type, args, description]
                # event_info = [mention.get("trigger_word"), event_type, description]  
                # if description:
                #     event_info = { 
                #             # "description": description, 
                #             "trigger_text": mention.get("trigger_word"),
                #             "type": event_type,
                #             # "arguments": args,
                #             "description": description, 
                #         }
                # else:
                #     event_info = { 
                #             "trigger_text": mention.get("trigger_word"),
                #             "type": event_type,
                #             # "arguments": args,
                #         }

                sent_to_existing_events[sent_id].append(event_info)
                

                # keys = list(event_info.keys())
                # random.shuffle(keys)
                # random_event_info = {k: event_info[k] for k in keys}
                # sent_to_existing_events[sent_id].append(random_event_info)

        for sent_id, events in sent_to_existing_events.items():
            sent_txt = sent_id_to_sentence[sent_id]
            sent_id_set.remove(sent_id)

            # trigger_texts = [event['trigger_text'] for event in events]
            # response = json.dumps({"triggers": trigger_texts, "events": events})

            response = json.dumps({"events": events})

            data.append({"system_prompt": system_prompt, "user_prompt": user_prompt.format(input=sent_txt), "response": response})

        for sent_id in sent_id_set:
            sent_txt = sent_id_to_sentence[sent_id]

            # response = json.dumps({"triggers": [], "events": []})
            response = json.dumps({"events": []})
            
            none_data.append({"system_prompt": system_prompt, "user_prompt": user_prompt.format(input=sent_txt), "response": response})


    if is_test:
        # data.extend(none_data)
        pass
    else:
        data.extend(random.sample(list(none_data), min(len(none_data), len(data) // 100)))
    for sample in data:
        prompt = tokenizer.apply_chat_template(
                [{"role": "system", "content": sample['system_prompt']},
                {"role": "user", "content": sample['user_prompt']}],
                add_generation_prompt=True,
                tokenize=False 
            )
        full = prompt + sample['response'] + tokenizer.eos_token
        
        prompt_tokens = tokenizer.encode(prompt, add_special_tokens=False)
        full_tokens = tokenizer.encode(full, add_special_tokens=False)
        response_tokens = full_tokens[len(prompt_tokens):]

        full_len.append(len(full_tokens))
        prompt_len.append(len(prompt_tokens))
        response_len.append(len(response_tokens))

    return data, full_len, prompt_len, response_len

# %%
data, full_len, prompt_len, response_len = process_data(ace_gen["train"])

# %%
np.max(response_len)
# Out:
# np.int64(354)

# %%
np.max(prompt_len)
# Out:
# np.int64(538)

# %%
np.median(full_len)
# Out:
# np.float64(473.0)

# %%
np.sum(np.array(prompt_len) > 460)
# Out:
# np.int64(51)

# %%
np.max(full_len)
# Out:
# np.int64(823)

# %%
len(data)
# Out:
# 3167

# %%
np.mean(full_len)
# Out:
# np.float64(415.7120303125987)

# %%
import os

def save(data, data_name): 
    os.makedirs(f"data/{data_name}", exist_ok=True)
    train, _, _, _ = process_data(data["train"])
    with open(f"data/{data_name}/train.jsonl", "w", encoding="utf-8") as f:
        for item in train:
            f.write(json.dumps(item, ensure_ascii=False) + "\n")

    dev, _, prompt_len, _ = process_data(data["validation"], is_test=True)
    with open(f"data/{data_name}/dev.jsonl", "w", encoding="utf-8") as f:
        for item in dev:
            f.write(json.dumps(item, ensure_ascii=False) + "\n")

    test, _, prompt_len, _ = process_data(data["test"], is_test=True)
    with open(f"data/{data_name}/test.jsonl", "w", encoding="utf-8") as f:
        for item in test:
            f.write(json.dumps(item, ensure_ascii=False) + "\n")

    return train, dev, test

# %%
save(ace_gen, "ace")
# Out:
# ([{'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nEven as the secretary of homeland security was putting his people on high alert last month , a 30-foot Cuban patrol boat with four heavily armed men landed on American shores , utterly undetected by the Coast Guard Secretary Ridge now leads .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["landed", "Movement:Transport", [["boat", "Vehicle"], ["men", "Artifact"], ["shores", "Destination"]], "This event describes the physical movement of a vehicle and individuals from one location to another, specifically onto American shores."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nHe lost an election to a dead man .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["election", "Personnel:Elect", [["man", "Person"]], "This event represents a person losing an election to another individual, indicating a political outcome involving defeat in a voting process."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nNOVAK Paul , as I understand your definition of a political -- of a professional politician based on that is somebody who is elected to public office .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["elected", "Personnel:Elect", [], "This event indicates a person is formally chosen by voters to hold a public office through an election process."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nAnd these bozos let four armed Cubans land on our shores when they \'re trying to make a high terrorist alert .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["land", "Movement:Transport", [["bozos", "Agent"], ["Cubans", "Artifact"], ["shores", "Destination"]], "This event describes the physical movement of individuals from one location to another via transportation, such as landing on a shore."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nHire professionals , Mr. President .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["Hire", "Personnel:Start-Position", [["professionals", "Person"]], "This event indicates the initiation of a professional\'s appointment to a new position within an organization or government."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nIt \'s OK to put Democratic career politicians at the Pentagon and the Justice Department if they \'re Democrats but not if they \'re Republicans , is that right ?\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["put", "Personnel:Start-Position", [["politicians", "Person"], ["Pentagon", "Entity"], ["Justice Department", "Entity"]], "This event indicates the assignment of individuals to specific government positions within the Pentagon or Justice Department."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nSenator Christopher Dodd of Connecticut made the announcement today that he would not be the 10th candidate for the nomination .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["nomination", "Personnel:Nominate", [["candidate", "Person"]], "This event signifies the formal selection of a person to run for a political office or position through official nomination."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nHe explained he could better spend the next two years on homeland security , the economy and judicial nominations .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["nominations", "Personnel:Nominate", [], "This event signifies the act of proposing or selecting individuals for judicial positions within the government."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nIt could swell to as much as $ 500 billion if we go to war in Iraq .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["war", "Conflict:Attack", [["Iraq", "Place"]], "This event represents a military conflict initiated by an attack, indicating a potential escalation in hostilities between parties."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nNOVAK Former Arkansas Governor and U.S. Senator Dale Bumpers has just published a memoir called " The Best Lawyer in a One - Lawyer Town . " And it spans his life from the depression era to the Clinton era .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["Former", "Personnel:End-Position", [["Arkansas", "Entity"], ["U.S.", "Entity"], ["Dale Bumpers", "Person"]], "This event indicates the conclusion of a person\'s official position in a government or organizational role."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nYou cite a session you had with President Lyndon Johnson in Austin , I guess , at his ranch , right ? Here is what you quote our President Johnson to you .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["session", "Contact:Meet", [["Lyndon Johnson", "Entity"], ["ranch", "Place"]], "This event represents a meeting between two entities at a specific location, indicating interpersonal interaction during a session."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\n" When I was majority leader , and later president , I spent all my time pulling every power string I could find to pull , trying to pass bills that helped people . That made their lives better and the country stronger .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["was", "Personnel:End-Position", [], "This event signifies the conclusion of a person\'s official role in a political or organizational hierarchy."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nI knew it was time to leave .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["leave", "Personnel:End-Position", [], "This event signifies the termination of an individual\'s role or position within an organization or team."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nAnd I \'ve said many times , if we all agreed on everything , everybody would want to marry Betty and we would really be in a mess , would n\'t we , Bob ?\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["marry", "Life:Marry", [["Betty", "Person"]], "This event represents a marriage proposal or intention, indicating a potential union between two individuals in a social or relational context."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nNOVAK Senator Bumpers , of the 22 senators of the old confederacy , when I got to Washington with the Associated Press , 45 years ago , 22 of them were Democrats , nine were Republicans .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["got", "Movement:Transport", [["Washington", "Destination"], ["Associated Press", "Agent"]], "This event represents a physical movement from one location to another, involving transportation by an agent."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nBUMPERS Bob , I think that the reason everybody in the south -- you know , first of all , we were -- when Franklin Roosevelt was elected president , we had been living what we thought was still a conquered nation after the Civil War .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["elected", "Personnel:Elect", [["Franklin Roosevelt", "Person"], ["president", "Entity"]], "This event signifies the election of a person to a political office, such as president, marking a significant leadership change."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nIt \'s amazing how someone can actually do two things at once . I \'m chewing gum and talking on the phone while writing this note . " Joshua , you could n\'t have said anything better .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["talking", "Contact:Phone-Write", [], "This event captures simultaneous phone conversation and writing activity, indicating multitasking behavior in real-time communication and note-taking."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nDan Snyder of Baden , Pennsylvania writes , " Bush should torture the al Qaeda chief operations officer .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["torture", "Conflict:Attack", [["Bush", "Target"], ["officer", "Attacker"]], "This event represents an attack involving torture, indicating a violent and unethical action against a target by an attacker."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nIf the budget goes through as is , why do n\'t Mr. Begala and Mr. Carville just donate the extra tax money they do n\'t want ?\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["donate", "Transaction:Transfer-Money", [["Begala", "Giver"], ["Carville", "Giver"]], "This event represents a monetary transfer where individuals give money to others, typically in a charitable or voluntary context."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nBEGALA I \'ll donate to the Democrats .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["donate", "Transaction:Transfer-Money", [["Democrats", "Recipient"]], "This event represents a financial contribution made by an individual to a political party, indicating support through monetary donation."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nHe had to sue to become our president , and he keeps trying to bribe other countries \' democratic governments into his supporting his agenda .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["sue", "Justice:Sue", [], "Suing to become president indicates legal action taken to gain political office through judicial or legal means."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nAnd now how are people going to argue that the U.S. can no longer both fight a war with Iraq and also fight terrorism , specifically al Qaeda ?\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["war", "Conflict:Attack", [["U.S.", "Attacker"], ["Iraq", "Place"]], "This event represents a conflict where one party launches an attack against another, involving military or violent action."], ["terrorism", "Conflict:Attack", [], "This event represents a conflict where one party launches an attack against another, involving military or violent action."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nWe go to war in Iraq , 200,000 people start protesting in Pakistan , they put too much pressure on the government .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["war", "Conflict:Attack", [["Iraq", "Place"]], "A military conflict initiated against a nation, involving violence or combat actions targeting a specific geographic location."], ["protesting", "Conflict:Demonstrate", [["people", "Entity"], ["Pakistan", "Place"]], "A public gathering of individuals expressing political, social, or ideological opinions through peaceful protest actions."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nWe go to war in Iraq , it would be the worst thing we can do ...\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["war", "Conflict:Attack", [["Iraq", "Place"]], "This event represents a military conflict initiated against a nation, involving combat and potential loss of life or resources."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nWhat I ca n\'t stand is a president who is going to screw up our war against terrorism when I thought that was his job .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["war", "Conflict:Attack", [], "This event represents a conflict involving an attack, typically against a nation or group, driven by hostile actions or aggression."], ["terrorism", "Conflict:Attack", [], "This event represents a conflict involving an attack, typically against a nation or group, driven by hostile actions or aggression."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nBoth the AMA and the Bush administration released reports this week saying out of control trial lawyers are driving doctors out of their practices all across the country .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["driving", "Business:End-Org", [["country", "Place"]], "This event indicates an organization ceasing operations due to external pressures like legal actions or market forces affecting its sustainability."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nPresident Bush points this way today , even the most frivolous of lawsuits cost money , premiums go up and either way , the patient pays .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["lawsuits", "Justice:Sue", [["patient", "Plaintiff"]], "This event represents a legal action initiated by a plaintiff against a defendant, seeking compensation or justice through the court system."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nLet me set aside the hypocrisy of a man who became president because of a lawsuit trying to eliminate everybody else \'s lawsuits , but instead focus on his own experience .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["became", "Personnel:Elect", [], "This event denotes the election of a person to a leadership position, such as president, through democratic or official processes."], ["lawsuit", "Justice:Sue", [], "This event represents an individual or entity initiating legal action against another party to seek compensation or redress through the court system."], ["lawsuits", "Justice:Sue", [], "This event represents an individual or entity initiating legal action against another party to seek compensation or redress through the court system."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nIt has refused in the last five years to revoke the license of a single doctor for committing medical errors .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["revoke", "Personnel:End-Position", [["doctor", "Person"]], "This event indicates the termination or end of a professional position held by an individual in a healthcare setting."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nIf there are any bad doctors we want them removed from the practice of medicine .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["removed", "Personnel:End-Position", [], "This event signifies the termination of a medical professional\'s position due to misconduct or unfitness for practice."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nBecause someone pays money in a case , the insurance company may pay money because they \'re afraid there \'s is going to be a giant award in this case because of this broken liability system .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["pays", "Transaction:Transfer-Money", [], "This event represents a monetary transfer where one party gives money to another in a legal or financial context."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nNADER Actually , Troy Brennan , the same doctor at Harvard Public School of Health said the issue is not to fuel lawsuits , it \'s too many .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["lawsuits", "Justice:Sue", [], "This event represents a legal action initiated to hold someone accountable for wrongdoing or harm through litigation."]]}'},
# ...
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nHe also brought a check from Campbell to pay the fines and fees .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["fines", "Justice:Fine", [["Campbell", "Entity"]], "This event represents the imposition of financial penalties on an individual for violating legal or regulatory standards."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nIn a tearful news conference after returning to Vancouver two days later , Campbell apologized to British Columbians , but refused to resign as premier .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["returning", "Movement:Transport", [["Vancouver", "Destination"], ["Campbell", "Artifact"]], "This event represents a physical movement of a person from one location to another, indicating travel or relocation."], ["resign", "Personnel:End-Position", [["Vancouver", "Place"], ["Campbell", "Person"], ["British Columbians", "Entity"]], "This event signifies the termination of a person\'s official position or role in an organization or government."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nRetired General Electric Co. Chairman Jack Welch is seeking work - related documents of his estranged wife in his high - stakes divorce case .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["Retired", "Personnel:End-Position", [["General Electric Co.", "Entity"], ["Jack Welch", "Person"]], "This event indicates a person has retired from a leadership role in an organization, marking the end of their official position."], ["divorce", "Life:Divorce", [["wife", "Person"]], "This event denotes a legal separation between spouses, involving the dissolution of a marital union and potential financial or personal disputes."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nThe Welches disclosed their plans to divorce a year ago , shortly after Suzy Wetlaufer _ then editor of the Harvard Business Review _ revealed she had become romantically involved with Welch while working on a story about him .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["divorce", "Life:Divorce", [["Welches", "Person"]], "This event represents the legal termination of a marital union between two individuals, marking the end of their marriage."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nHe also wants to subpoena all documents maintained in Jane Beasley Welch \'s personnel file by Shearman & amp ; Sterling , a prestigious corporate law firm where she worked before she married Welch .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["married", "Life:Marry", [["Welch", "Person"]], "This event represents a marital union between two individuals, indicating a formal partnership established through marriage."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nWelch specifically is seeking performance evaluations , correspondence between his estranged wife and partners while she worked at the law firm \'s office in London , and documents related to her prospects of becoming a partner .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["correspondence", "Contact:Phone-Write", [["wife", "Entity"], ["partners", "Entity"], ["office", "Place"]], "This event captures written communication between individuals at a specific location, indicating intent to gather correspondence records."], ["becoming", "Personnel:Start-Position", [["firm", "Entity"]], "This event indicates the initiation of a person\'s role as a partner within an organization, such as a law firm."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nWelch also wants details on Jane Beasley Welch \'s salary , benefits , retirement plan and other compensation paid to her .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["retirement", "Personnel:End-Position", [["Jane Beasley Welch", "Person"]], "This event indicates the termination of a person\'s job position, marking the end of their employment role within an organization."], ["paid", "Transaction:Transfer-Money", [["Jane Beasley Welch", "Recipient"]], "This event represents a financial transfer involving compensation paid to an individual, such as salary or benefits."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nA judge ruled in February that depositions in the divorce case will remain confidential .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["divorce", "Life:Divorce", [], "A divorce event signifies the legal termination of a marriage, involving separation and division of assets or property between spouses."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nEarlier documents in the case have included embarrassing details about perks Welch received as part of his retirement package from GE at a time when corporate scandals were sparking outrage .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["retirement", "Personnel:End-Position", [["Welch", "Person"], ["GE", "Entity"]], "This event signifies the end of a person\'s position in an organization, such as retirement or resignation."]]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{"events": [[<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>], [<trigger span 2>, <event type 2>, [], <description 2>]]}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: \n<input>\nWebb also said details of the breakdowns of the Welches \' previous marriages were likely to come up , and cited reports of alleged extramarital affairs by both .\n</input>\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Identify event type\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input (from <input>...</input>).\n',
#    'response': '{"events": [["breakdowns", "Life:Divorce", [["Welches", "Person"]], "This event represents the end of a marital relationship between individuals, indicating a formal or informal dissolution of marriage."], ["marriages", "Life:Marry", [["Welches", "Person"]], "This event denotes the formation of a marital bond between two individuals, indicating a union established through marriage."]]}'}])

# %%
maven = load_dataset("datht/maven-event-dataset")

# %%
maven_train, maven_dev, maven_test = save(maven, "maven")

# %%
geneva = load_dataset("datht/geneva-short-generated-dataset")

geneva_train, geneva_dev, geneva_test = save(geneva, "geneva")

# %%
len(geneva_train)
# Out:
# 1968

# %%
with open(f"data/train.jsonl", "w", encoding="utf-8") as f:
    for item in maven_train + geneva_train:
        f.write(json.dumps(item, ensure_ascii=False) + "\n")

with open(f"data/dev.jsonl", "w", encoding="utf-8") as f:
    for item in geneva_dev + maven_dev:
        f.write(json.dumps(item, ensure_ascii=False) + "\n")

with open(f"data/test.jsonl", "w", encoding="utf-8") as f:
    for item in maven_test + geneva_test:
        f.write(json.dumps(item, ensure_ascii=False) + "\n")

# %%
data, full_len, prompt_len, response_len = process_data(geneva["train"])

# %%
len(data)
# Out:
# 1968

# %%
np.median(full_len)
# Out:
# np.float64(501.0)

# %%
np.sum(np.array(full_len) > 768)
# Out:
# np.int64(31)

# %%
np.sum(np.array(prompt_len) > 460)
# Out:
# np.int64(1)

# %%
np.max(full_len)
# Out:
# np.int64(1065)

# %%
maven = load_dataset("datht/maven-short-generated-dataset")

maven_train, maven_dev, maven_test = save(maven, "maven")

# %%
len(maven_train)
# Out:
# 26278

# %%
rams = load_dataset("datht/rams-event-dataset")
maven = load_dataset("datht/maven-short-generated-dataset")

# %%
data, full_len, prompt_len, response_len = process_data(maven["train"])

# %%
len(data)
# Out:
# 26278

# %%
np.median(full_len)
# Out:
# np.float64(374.0)

# %%
np.sum(np.array(full_len) > 768)
# Out:
# np.int64(18)

# %%
import json
from datasets import load_dataset

def extract_key_info(doc):
    """
    Trích xuất các trường: type, trigger_word, arguments (text, role) 
    từ một document và format lại để dễ so sánh.
    """
    info_list = []
    
    # Duyệt qua các event
    for event in doc.get('events', []):
        event_type = event.get('type')
        
        # Duyệt qua các mention trong event
        for mention in event.get('mention', []):
            trigger_word = mention.get('trigger_word')
            
            # Trích xuất list arguments (chỉ lấy text và role)
            args = []
            for arg in mention.get('arguments', []):
                args.append({
                    'text': arg.get('text'),
                    'role': arg.get('role')
                })
            
            # Sắp xếp arguments theo text để đảm bảo thứ tự không làm sai kết quả so sánh
            args = sorted(args, key=lambda x: (x['text'] or "", x['role'] or ""))
            
            info_list.append({
                'type': event_type,
                'trigger_word': trigger_word,
                'arguments': args
            })
            
    # Sắp xếp toàn bộ danh sách event theo type và trigger_word
    info_list = sorted(info_list, key=lambda x: (x['type'] or "", x['trigger_word'] or ""))
    return info_list

def compare_json_lists(list1, list2):
    """
    So sánh 2 list dữ liệu dựa trên document ID chung.
    """
    # Chuyển list thành dictionary với key là document id để tra cứu nhanh (O(1))
    dict1 = {doc['id']: doc for doc in list1}
    dict2 = {doc['id']: doc for doc in list2}
    
    # Tìm các document ID có mặt ở cả 2 list
    common_ids = set(dict1.keys()).intersection(set(dict2.keys()))
    
    if not common_ids:
        print("Không tìm thấy Document ID nào chung giữa 2 list!")
        return

    print("total: ", len(dict1), len(dict2))
    print(f"Tìm thấy {len(common_ids)} Document ID chung. Đang tiến hành so sánh...\n")
    print("-" * 50)
    
    failed_count = 0
    for doc_id in common_ids:
        # Trích xuất thông tin trọng tâm từ 2 list
        info1 = extract_key_info(dict1[doc_id])
        info2 = extract_key_info(dict2[doc_id])
        
        # So sánh trực tiếp 2 cấu trúc đã được chuẩn hóa
        if info1 == info2:
            # print(f"✅ Document ID: {doc_id} -> GIỐNG NHAU HOÀN TOÀN")
            pass
        else:
            print(f"❌ Document ID: {doc_id} -> CÓ SỰ KHÁC BIỆT")
            print("  🔻 Ở List 1:")
            print(f"    {json.dumps(info1, indent=2, ensure_ascii=False)}")
            print("  🔻 Ở List 2:")
            print(f"    {json.dumps(info2, indent=2, ensure_ascii=False)}")
            failed_count += 1 
        # print("-" * 50)

    print("failed_count: ", failed_count)


data = load_dataset("datht/geneva-event-dataset")
data_gen = load_dataset("datht/geneva-short-generated-dataset")
compare_json_lists(data['validation'], data_gen['validation'])

# %%
data = load_dataset("datht/geneva-event-dataset")
data_gen = load_dataset("datht/geneva-short-generated-dataset")
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'title', 'content', 'events', 'negative_triggers', 'doc_idx'],
#         num_rows: 1968
#     })
#     validation: Dataset({
#         features: ['id', 'title', 'content', 'events', 'negative_triggers', 'doc_idx'],
#         num_rows: 783
#     })
#     test: Dataset({
#         features: ['id', 'title', 'content', 'events', 'negative_triggers', 'doc_idx'],
#         num_rows: 933
#     })
# })

# %%
compare_json_lists(data['validation'], data_gen['validation'])
# Out:
# total:  783 783
# Tìm thấy 783 Document ID chung. Đang tiến hành so sánh...
#
# --------------------------------------------------
# ❌ Document ID: 5ce2acc44adfebf9cc66507e8c8f2618 -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Adducing",
#     "trigger_word": "cited",
#     "arguments": [
#       {
#         "text": "The United States",
#         "role": "Speaker"
#       },
#       {
#         "text": "numerous cases of Iran receiving assistance in its missile production from countries such as North Korea and Russia",
#         "role": "Specified_entity"
#       }
#     ]
#   },
#   {
#     "type": "Assistance",
#     "trigger_word": "aiding",
#     "arguments": [
#       {
#         "text": "Iran",
#         "role": "Benefited_party"
#       },
#       {
#         "text": "private companies",
#         "role": "Helper"
#       }
#     ]
#   },
#   {
#     "type": "Assistance",
#     "trigger_word": "assistance",
#     "arguments": [
#       {
#         "text": "Iran",
#         "role": "Benefited_party"
#       },
#       {
#         "text": "from countries such as North Korea and Russia",
#         "role": "Helper"
#       },
#       {
#         "text": "in its missile production",
#         "role": "Goal"
#       }
#     ]
#   },
#   {
#     "type": "Manufacturing",
#     "trigger_word": "production",
#     "arguments": [
#       {
#         "text": "its",
#         "role": "Producer"
#       },
#       {
#         "text": "missile",
#         "role": "Product"
#       }
#     ]
#   },
#   {
#     "type": "Receiving",
#     "trigger_word": "receiving",
#     "arguments": [
#       {
#         "text": "Iran",
#         "role": "Recipient"
#       },
#       {
#         "text": "assistance in its missile production",
#         "role": "Theme"
#       },
#       {
#         "text": "from countries such as North Korea and Russia",
#         "role": "Donor"
#       }
#     ]
#   },
#   {
#     "type": "Revenge",
#     "trigger_word": "sanctions",
#     "arguments": [
#       {
#         "text": "The United States",
#         "role": "Avenger"
#       },
#       {
#         "text": "for aiding Iran",
#         "role": "Injury"
#       },
#       {
#         "text": "on private companies",
#         "role": "Offender"
#       }
#     ]
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Adducing",
#     "trigger_word": "cited",
#     "arguments": [
#       {
#         "text": "The United States",
#         "role": "Speaker"
#       },
#       {
#         "text": "numerous cases of Iran receiving assistance in its missile production from countries such as North Korea and Russia",
#         "role": "Specified_entity"
#       }
#     ]
#   },
#   {
#     "type": "Assistance",
#     "trigger_word": "aiding",
#     "arguments": []
#   },
#   {
#     "type": "Assistance",
#     "trigger_word": "assistance",
#     "arguments": [
#       {
#         "text": "Iran",
#         "role": "Benefited_party"
#       },
#       {
#         "text": "from countries such as North Korea and Russia",
#         "role": "Helper"
#       },
#       {
#         "text": "in its missile production",
#         "role": "Goal"
#       }
#     ]
#   },
#   {
#     "type": "Manufacturing",
#     "trigger_word": "production",
#     "arguments": [
#       {
#         "text": "its",
#         "role": "Producer"
#       },
#       {
#         "text": "missile",
#         "role": "Product"
#       }
#     ]
#   },
#   {
#     "type": "Receiving",
#     "trigger_word": "receiving",
#     "arguments": [
#       {
#         "text": "Iran",
#         "role": "Recipient"
#       },
#       {
#         "text": "assistance in its missile production",
#         "role": "Theme"
#       },
#       {
#         "text": "from countries such as North Korea and Russia",
#         "role": "Donor"
#       }
#     ]
#   },
#   {
#     "type": "Revenge",
#     "trigger_word": "sanctions",
#     "arguments": [
#       {
#         "text": "The United States",
#         "role": "Avenger"
#       },
#       {
#         "text": "for aiding Iran",
#         "role": "Injury"
#       },
#       {
#         "text": "on private companies",
#         "role": "Offender"
#       }
#     ]
#   }
# ]
# ❌ Document ID: 39d0b9c3a2e8630aec74572d139932b8 -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Assistance",
#     "trigger_word": "helped",
#     "arguments": [
#       {
#         "text": "draw a line in the desert sand between legitimate operations and mob casinos , where illegal skimming of profits was rampant",
#         "role": "Goal"
#       },
#       {
#         "text": "their influence",
#         "role": "Helper"
#       }
#     ]
#   },
#   {
#     "type": "Causation",
#     "trigger_word": "of",
#     "arguments": [
#       {
#         "text": "established companies such as Hilton Hotels bought into the gaming business",
#         "role": "Effect"
#       },
#       {
#         "text": "the new legitimacy Las Vegas acquired from Hughes ' investments",
#         "role": "Cause"
#       }
#     ]
#   },
#   {
#     "type": "Earnings_and_losses",
#     "trigger_word": "profits",
#     "arguments": [
#       {
#         "text": "profits",
#         "role": "Earnings"
#       }
#     ]
#   },
#   {
#     "type": "Getting",
#     "trigger_word": "acquired",
#     "arguments": [
#       {
#         "text": "Las Vegas",
#         "role": "Recipient"
#       },
#       {
#         "text": "from Hughes",
#         "role": "Source"
#       },
#       {
#         "text": "the new legitimacy",
#         "role": "Theme"
#       }
#     ]
#   },
#   {
#     "type": "Legality",
#     "trigger_word": "illegal",
#     "arguments": [
#       {
#         "text": "skimming of profits",
#         "role": "Action"
#       }
#     ]
#   },
#   {
#     "type": "Legality",
#     "trigger_word": "legitimate",
#     "arguments": [
#       {
#         "text": "operations",
#         "role": "Action"
#       }
#     ]
#   },
#   {
#     "type": "Removing",
#     "trigger_word": "skimming",
#     "arguments": [
#       {
#         "text": "of profits",
#         "role": "Theme"
#       }
#     ]
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Assistance",
#     "trigger_word": "helped",
#     "arguments": [
#       {
#         "text": "draw a line in the desert sand between legitimate operations and mob casinos , where illegal skimming of profits was rampant",
#         "role": "Goal"
#       },
#       {
#         "text": "their influence",
#         "role": "Helper"
#       }
#     ]
#   },
#   {
#     "type": "Causation",
#     "trigger_word": "of",
#     "arguments": [
#       {
#         "text": "established companies such as Hilton Hotels bought into the gaming business",
#         "role": "Effect"
#       },
#       {
#         "text": "the new legitimacy Las Vegas acquired from Hughes ' investments",
#         "role": "Cause"
#       }
#     ]
#   },
#   {
#     "type": "Earnings_and_losses",
#     "trigger_word": "profits",
#     "arguments": [
#       {
#         "text": "profits",
#         "role": "Earnings"
#       }
#     ]
#   },
#   {
#     "type": "Getting",
#     "trigger_word": "acquired",
#     "arguments": [
#       {
#         "text": "Las Vegas",
#         "role": "Recipient"
#       },
#       {
#         "text": "from Hughes",
#         "role": "Source"
#       },
#       {
#         "text": "the new legitimacy",
#         "role": "Theme"
#       }
#     ]
#   },
#   {
#     "type": "Legality",
#     "trigger_word": "illegal",
#     "arguments": []
#   },
#   {
#     "type": "Legality",
#     "trigger_word": "legitimate",
#     "arguments": [
#       {
#         "text": "operations",
#         "role": "Action"
#       }
#     ]
#   },
#   {
#     "type": "Removing",
#     "trigger_word": "skimming",
#     "arguments": [
#       {
#         "text": "of profits",
#         "role": "Theme"
#       }
#     ]
#   }
# ]
# ❌ Document ID: 2a59815e710a4c370ff4bbe6ae409104 -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Statement",
#     "trigger_word": "comments",
#     "arguments": [
#       {
#         "text": "against Iraq 's use of such weapons",
#         "role": "Message"
#       }
#     ]
#   },
#   {
#     "type": "Using",
#     "trigger_word": "use",
#     "arguments": [
#       {
#         "text": "of chemical weapons",
#         "role": "Instrument"
#       }
#     ]
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Statement",
#     "trigger_word": "comments",
#     "arguments": [
#       {
#         "text": "against Iraq's use of such weapons",
#         "role": "Message"
#       }
#     ]
#   },
#   {
#     "type": "Using",
#     "trigger_word": "use",
#     "arguments": [
#       {
#         "text": "of chemical weapons",
#         "role": "Instrument"
#       }
#     ]
#   }
# ]
# ❌ Document ID: b361be35f0efeb37eb0faeb85ff06fc6 -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Arriving",
#     "trigger_word": "arrived",
#     "arguments": [
#       {
#         "text": "Thousands of people",
#         "role": "Theme"
#       }
#     ]
#   },
#   {
#     "type": "Placing",
#     "trigger_word": "putting",
#     "arguments": [
#       {
#         "text": "Thousands of people arrived with little more than the clothes they wore",
#         "role": "Cause"
#       },
#       {
#         "text": "great strain",
#         "role": "Theme"
#       },
#       {
#         "text": "on the resources of the islands",
#         "role": "Location"
#       }
#     ]
#   },
#   {
#     "type": "Wearing",
#     "trigger_word": "clothes",
#     "arguments": [
#       {
#         "text": "clothes",
#         "role": "Clothing"
#       },
#       {
#         "text": "they",
#         "role": "Wearer"
#       }
#     ]
#   },
#   {
#     "type": "Wearing",
#     "trigger_word": "wore",
#     "arguments": [
#       {
#         "text": "the clothes",
#         "role": "Clothing"
#       },
#       {
#         "text": "they",
#         "role": "Wearer"
#       }
#     ]
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Arriving",
#     "trigger_word": "arrived",
#     "arguments": [
#       {
#         "text": "Thousands of people",
#         "role": "Theme"
#       }
#     ]
#   },
#   {
#     "type": "Placing",
#     "trigger_word": "putting",
#     "arguments": [
#       {
#         "text": "Thousands of people arrived with little more than the clothes they wore",
#         "role": "Cause"
#       },
#       {
#         "text": "great strain",
#         "role": "Theme"
#       },
#       {
#         "text": "on the resources of the islands",
#         "role": "Location"
#       }
#     ]
#   },
#   {
#     "type": "Wearing",
#     "trigger_word": "clothes",
#     "arguments": [
#       {
#         "text": "clothes",
#         "role": "Clothing"
#       },
#       {
#         "text": "they",
#         "role": "Wearer"
#       }
#     ]
#   },
#   {
#     "type": "Wearing",
#     "trigger_word": "wore",
#     "arguments": []
#   }
# ]
# ❌ Document ID: 2d23ee47e6c358429d4c2fca3ad83c90 -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Preventing_or_letting",
#     "trigger_word": "stop",
#     "arguments": [
#       {
#         "text": "Libya",
#         "role": "Event"
#       },
#       {
#         "text": "from completing what Washington claimed was a chemical weapons plant in Tarunah , near Tripoli",
#         "role": "Event"
#       },
#       {
#         "text": "it",
#         "role": "Potential_hindrance"
#       }
#     ]
#   },
#   {
#     "type": "Statement",
#     "trigger_word": "announced",
#     "arguments": [
#       {
#         "text": "that it had not ruled out using conventional weapons to stop Libya from completing what Washington claimed was a chemical weapons plant in Tarunah , near Tripoli",
#         "role": "Message"
#       },
#       {
#         "text": "the U.S.",
#         "role": "Speaker"
#       }
#     ]
#   },
#   {
#     "type": "Statement",
#     "trigger_word": "claimed",
#     "arguments": [
#       {
#         "text": "Washington",
#         "role": "Speaker"
#       },
#       {
#         "text": "was a chemical weapons plant in Tarunah , near Tripoli",
#         "role": "Message"
#       },
#       {
#         "text": "what",
#         "role": "Message"
#       }
#     ]
#   },
#   {
#     "type": "Using",
#     "trigger_word": "using",
#     "arguments": [
#       {
#         "text": "conventional weapons",
#         "role": "Instrument"
#       },
#       {
#         "text": "it",
#         "role": "Agent"
#       },
#       {
#         "text": "to stop Libya from completing what Washington claimed was a chemical weapons plant in Tarunah , near Tripoli",
#         "role": "Purpose"
#       }
#     ]
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Preventing_or_letting",
#     "trigger_word": "stop",
#     "arguments": [
#       {
#         "text": "Libya",
#         "role": "Event"
#       },
#       {
#         "text": "from completing what Washington claimed was a chemical weapons plant in Tarunah , near Tripoli",
#         "role": "Event"
#       },
#       {
#         "text": "it",
#         "role": "Potential_hindrance"
#       }
#     ]
#   },
#   {
#     "type": "Statement",
#     "trigger_word": "announced",
#     "arguments": [
#       {
#         "text": "that it had not ruled out using conventional weapons to stop Libya from completing what Washington claimed was a chemical weapons plant in Tarunah , near Tripoli",
#         "role": "Message"
#       },
#       {
#         "text": "the U.S.",
#         "role": "Speaker"
#       }
#     ]
#   },
#   {
#     "type": "Statement",
#     "trigger_word": "claimed",
#     "arguments": []
#   },
#   {
#     "type": "Using",
#     "trigger_word": "using",
#     "arguments": [
#       {
#         "text": "conventional weapons",
#         "role": "Instrument"
#       },
#       {
#         "text": "it",
#         "role": "Agent"
#       },
#       {
#         "text": "to stop Libya from completing what Washington claimed was a chemical weapons plant in Tarunah , near Tripoli",
#         "role": "Purpose"
#       }
#     ]
#   }
# ]
# ❌ Document ID: f75b0ac5eec2299defcc5f94376ae52a -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Statement",
#     "trigger_word": "claims",
#     "arguments": [
#       {
#         "text": "North Korea",
#         "role": "Speaker"
#       },
#       {
#         "text": "this is not necessary since Pyongyang already declared its intention to withdraw in 1993 , only to `` suspend its intention withdraw ''",
#         "role": "Message"
#       }
#     ]
#   },
#   {
#     "type": "Statement",
#     "trigger_word": "declared",
#     "arguments": [
#       {
#         "text": "Pyongyang",
#         "role": "Speaker"
#       },
#       {
#         "text": "its intention to withdraw",
#         "role": "Message"
#       }
#     ]
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Statement",
#     "trigger_word": "claims",
#     "arguments": [
#       {
#         "text": "North Korea",
#         "role": "Speaker"
#       },
#       {
#         "text": "this is not necessary since Pyongyang already declared its intention to withdraw in 1993 , only to `` suspend its intention withdraw ''",
#         "role": "Message"
#       }
#     ]
#   },
#   {
#     "type": "Statement",
#     "trigger_word": "declared",
#     "arguments": []
#   }
# ]
# ❌ Document ID: b0d5b6ddedad36a31168e5acfbcf81ce -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Action",
#     "trigger_word": "out",
#     "arguments": [
#       {
#         "text": "Israel",
#         "role": "Agent"
#       },
#       {
#         "text": "its threats to invade the Gaza Strip",
#         "role": "Act"
#       }
#     ]
#   },
#   {
#     "type": "Commitment",
#     "trigger_word": "threatened",
#     "arguments": [
#       {
#         "text": "It",
#         "role": "Speaker"
#       },
#       {
#         "text": "to use the weapons against IDF soldiers",
#         "role": "Message"
#       }
#     ]
#   },
#   {
#     "type": "Commitment",
#     "trigger_word": "threats",
#     "arguments": [
#       {
#         "text": "to invade the Gaza Strip",
#         "role": "Message"
#       }
#     ]
#   },
#   {
#     "type": "Using",
#     "trigger_word": "use",
#     "arguments": [
#       {
#         "text": "It",
#         "role": "Agent"
#       },
#       {
#         "text": "against IDF soldiers",
#         "role": "Purpose"
#       },
#       {
#         "text": "the weapons",
#         "role": "Instrument"
#       }
#     ]
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Action",
#     "trigger_word": "out",
#     "arguments": [
#       {
#         "text": "Israel",
#         "role": "Agent"
#       },
#       {
#         "text": "its threats to invade the Gaza Strip",
#         "role": "Act"
#       }
#     ]
#   },
#   {
#     "type": "Commitment",
#     "trigger_word": "threatened",
#     "arguments": [
#       {
#         "text": "It",
#         "role": "Speaker"
#       },
#       {
#         "text": "to use the weapons against IDF soldiers",
#         "role": "Message"
#       }
#     ]
#   },
#   {
#     "type": "Commitment",
#     "trigger_word": "threats",
#     "arguments": []
#   },
#   {
#     "type": "Using",
#     "trigger_word": "use",
#     "arguments": [
#       {
#         "text": "It",
#         "role": "Agent"
#       },
#       {
#         "text": "against IDF soldiers",
#         "role": "Purpose"
#       },
#       {
#         "text": "the weapons",
#         "role": "Instrument"
#       }
#     ]
#   }
# ]
# ❌ Document ID: a0ba514b486643b710bcceb76cc807e1 -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Collaboration",
#     "trigger_word": "cooperation",
#     "arguments": [
#       {
#         "text": "China 's",
#         "role": "Partners"
#       },
#       {
#         "text": "nuclear",
#         "role": "Undertaking"
#       },
#       {
#         "text": "with Iran",
#         "role": "Partners"
#       }
#     ]
#   },
#   {
#     "type": "Commitment",
#     "trigger_word": "pledge",
#     "arguments": [
#       {
#         "text": "China 's",
#         "role": "Speaker"
#       },
#       {
#         "text": "not to engage in any new nuclear cooperation with Iran",
#         "role": "Message"
#       }
#     ]
#   },
#   {
#     "type": "Statement",
#     "trigger_word": "suggests",
#     "arguments": [
#       {
#         "text": "An unclassified CIA report to Congress released in February 2000",
#         "role": "Medium"
#       },
#       {
#         "text": "that China 's October 1997 pledge not to engage in any new nuclear cooperation with Iran appears to be holding",
#         "role": "Message"
#       }
#     ]
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Collaboration",
#     "trigger_word": "cooperation",
#     "arguments": [
#       {
#         "text": "China's",
#         "role": "Partners"
#       },
#       {
#         "text": "nuclear",
#         "role": "Undertaking"
#       },
#       {
#         "text": "with Iran",
#         "role": "Partners"
#       }
#     ]
#   },
#   {
#     "type": "Commitment",
#     "trigger_word": "pledge",
#     "arguments": [
#       {
#         "text": "China's",
#         "role": "Speaker"
#       },
#       {
#         "text": "not to engage in any new nuclear cooperation with Iran",
#         "role": "Message"
#       }
#     ]
#   },
#   {
#     "type": "Statement",
#     "trigger_word": "suggests",
#     "arguments": [
#       {
#         "text": "An unclassified CIA report to Congress released in February 2000",
#         "role": "Medium"
#       },
#       {
#         "text": "that China's October 1997 pledge not to engage in any new nuclear cooperation with Iran appears to be holding",
#         "role": "Message"
#       }
#     ]
#   }
# ]
# ❌ Document ID: 153513b3c98bf5e1f2576a3e35d16381 -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Action",
#     "trigger_word": "activities",
#     "arguments": [
#       {
#         "text": "of several nuclear research centers , most notably the TNRC and ENTC",
#         "role": "Agent"
#       }
#     ]
#   },
#   {
#     "type": "Action",
#     "trigger_word": "does",
#     "arguments": [
#       {
#         "text": "It",
#         "role": "Agent"
#       },
#       {
#         "text": "so",
#         "role": "Act"
#       }
#     ]
#   },
#   {
#     "type": "Research",
#     "trigger_word": "research",
#     "arguments": [
#       {
#         "text": "nuclear",
#         "role": "Field"
#       }
#     ]
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Action",
#     "trigger_word": "activities",
#     "arguments": []
#   },
#   {
#     "type": "Action",
#     "trigger_word": "does",
#     "arguments": [
#       {
#         "text": "It",
#         "role": "Agent"
#       },
#       {
#         "text": "so",
#         "role": "Act"
#       }
#     ]
#   },
#   {
#     "type": "Research",
#     "trigger_word": "research",
#     "arguments": [
#       {
#         "text": "nuclear",
#         "role": "Field"
#       }
#     ]
#   }
# ]
# ❌ Document ID: 4748a247d5ae362049b3644aa017aaa2 -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Connect",
#     "trigger_word": "on",
#     "arguments": [
#       {
#         "text": "some of the territory 's best beaches",
#         "role": "Figures"
#       },
#       {
#         "text": "the south side of the peninsula",
#         "role": "Ground"
#       }
#     ]
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Connect",
#     "trigger_word": "on",
#     "arguments": [
#       {
#         "text": "some of the territory's best beaches",
#         "role": "Figures"
#       },
#       {
#         "text": "the south side of the peninsula",
#         "role": "Ground"
#       }
#     ]
#   }
# ]
# ❌ Document ID: 8ca64f08b094e5de1162ab876d82eff8 -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Attack",
#     "trigger_word": "attacks",
#     "arguments": []
#   },
#   {
#     "type": "Attack",
#     "trigger_word": "strike",
#     "arguments": [
#       {
#         "text": "at the Iranian strategic rear",
#         "role": "Victim"
#       },
#       {
#         "text": "it",
#         "role": "Assailant"
#       }
#     ]
#   },
#   {
#     "type": "Attack",
#     "trigger_word": "strikes",
#     "arguments": [
#       {
#         "text": "FROG-7As",
#         "role": "Weapon"
#       }
#     ]
#   },
#   {
#     "type": "Hostile_encounter",
#     "trigger_word": "war",
#     "arguments": []
#   },
#   {
#     "type": "Process_start",
#     "trigger_word": "entered",
#     "arguments": [
#       {
#         "text": "In 1982 , as the war dragged on into its second year",
#         "role": "Time"
#       },
#       {
#         "text": "Iraqi operations",
#         "role": "Agent"
#       },
#       {
#         "text": "a new phase in which it expanded the use of FROG-7As strikes and the first employment ( three attacks in 1982 ) of the Scud-B short - range ballistic missile ( SRBM ) to strike at the Iranian strategic rear",
#         "role": "Event"
#       }
#     ]
#   },
#   {
#     "type": "Using",
#     "trigger_word": "use",
#     "arguments": [
#       {
#         "text": "of FROG-7As strikes",
#         "role": "Instrument"
#       }
#     ]
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Attack",
#     "trigger_word": "attacks",
#     "arguments": []
#   },
#   {
#     "type": "Attack",
#     "trigger_word": "strike",
#     "arguments": [
#       {
#         "text": "at the Iranian strategic rear",
#         "role": "Victim"
#       },
#       {
#         "text": "it",
#         "role": "Assailant"
#       }
#     ]
#   },
#   {
#     "type": "Attack",
#     "trigger_word": "strikes",
#     "arguments": []
#   },
#   {
#     "type": "Hostile_encounter",
#     "trigger_word": "war",
#     "arguments": []
#   },
#   {
#     "type": "Process_start",
#     "trigger_word": "entered",
#     "arguments": [
#       {
#         "text": "In 1982 , as the war dragged on into its second year",
#         "role": "Time"
#       },
#       {
#         "text": "Iraqi operations",
#         "role": "Agent"
#       },
#       {
#         "text": "a new phase in which it expanded the use of FROG-7As strikes and the first employment ( three attacks in 1982 ) of the Scud-B short - range ballistic missile ( SRBM ) to strike at the Iranian strategic rear",
#         "role": "Event"
#       }
#     ]
#   },
#   {
#     "type": "Using",
#     "trigger_word": "use",
#     "arguments": [
#       {
#         "text": "of FROG-7As strikes",
#         "role": "Instrument"
#       }
#     ]
#   }
# ]
# ❌ Document ID: 023670737072dadca6afda49fb4ece7d -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Connect",
#     "trigger_word": "on",
#     "arguments": [
#       {
#         "text": "I rode it out",
#         "role": "Figures"
#       },
#       {
#         "text": "the second floor of Leo 's at 55th and Telegraph in Oakland",
#         "role": "Ground"
#       }
#     ]
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Connect",
#     "trigger_word": "on",
#     "arguments": [
#       {
#         "text": "I rode it out",
#         "role": "Figures"
#       },
#       {
#         "text": "the second floor of Leo's at 55th and Telegraph in Oakland",
#         "role": "Ground"
#       }
#     ]
#   }
# ]
# ❌ Document ID: d31028e32a715461f3faaaeffe1f852a -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Creating",
#     "trigger_word": "production",
#     "arguments": [
#       {
#         "text": "of isotopes",
#         "role": "Created_entity"
#       }
#     ]
#   },
#   {
#     "type": "Research",
#     "trigger_word": "research",
#     "arguments": [
#       {
#         "text": "of isotopes",
#         "role": "Topic"
#       }
#     ]
#   },
#   {
#     "type": "Using",
#     "trigger_word": "applications",
#     "arguments": [
#       {
#         "text": "applications",
#         "role": "Purpose"
#       }
#     ]
#   },
#   {
#     "type": "Using",
#     "trigger_word": "use",
#     "arguments": [
#       {
#         "text": "in medical and agricultural applications",
#         "role": "Purpose"
#       }
#     ]
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Creating",
#     "trigger_word": "production",
#     "arguments": [
#       {
#         "text": "of isotopes",
#         "role": "Created_entity"
#       }
#     ]
#   },
#   {
#     "type": "Research",
#     "trigger_word": "research",
#     "arguments": [
#       {
#         "text": "of isotopes",
#         "role": "Topic"
#       }
#     ]
#   },
#   {
#     "type": "Using",
#     "trigger_word": "applications",
#     "arguments": []
#   },
#   {
#     "type": "Using",
#     "trigger_word": "use",
#     "arguments": [
#       {
#         "text": "in medical and agricultural applications",
#         "role": "Purpose"
#       }
#     ]
#   }
# ]
# ❌ Document ID: ad613184ddcb9878b4727fe73eda66ff -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Cause_to_make_progress",
#     "trigger_word": "develop",
#     "arguments": [
#       {
#         "text": "protective clothing , manufacture exotic assassination devices , and `` weaponize '' irritants ( Riot Control Agents such as CS and CR ) and incapacitants by placing them in artillery shells , mortar bombs , and grenades",
#         "role": "Project"
#       }
#     ]
#   },
#   {
#     "type": "Creating",
#     "trigger_word": "up",
#     "arguments": [
#       {
#         "text": "several other facilities",
#         "role": "Created_entity"
#       }
#     ]
#   },
#   {
#     "type": "Killing",
#     "trigger_word": "assassination",
#     "arguments": []
#   },
#   {
#     "type": "Manufacturing",
#     "trigger_word": "manufacture",
#     "arguments": [
#       {
#         "text": "exotic assassination devices",
#         "role": "Product"
#       }
#     ]
#   },
#   {
#     "type": "Manufacturing",
#     "trigger_word": "producing",
#     "arguments": [
#       {
#         "text": "CW agents",
#         "role": "Product"
#       }
#     ]
#   },
#   {
#     "type": "Placing",
#     "trigger_word": "located",
#     "arguments": [
#       {
#         "text": "a military front company called Delta G Scientific",
#         "role": "Theme"
#       },
#       {
#         "text": "between Johannesburg and Pretoria",
#         "role": "Location"
#       }
#     ]
#   },
#   {
#     "type": "Placing",
#     "trigger_word": "placing",
#     "arguments": [
#       {
#         "text": "in artillery shells , mortar bombs , and grenades",
#         "role": "Location"
#       },
#       {
#         "text": "them",
#         "role": "Theme"
#       }
#     ]
#   },
#   {
#     "type": "Research",
#     "trigger_word": "researching",
#     "arguments": [
#       {
#         "text": "CW agents",
#         "role": "Topic"
#       }
#     ]
#   },
#   {
#     "type": "Wearing",
#     "trigger_word": "clothing",
#     "arguments": [
#       {
#         "text": "clothing",
#         "role": "Clothing"
#       }
#     ]
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Cause_to_make_progress",
#     "trigger_word": "develop",
#     "arguments": [
#       {
#         "text": "protective clothing , manufacture exotic assassination devices , and `` weaponize '' irritants ( Riot Control Agents such as CS and CR ) and incapacitants by placing them in artillery shells , mortar bombs , and grenades",
#         "role": "Project"
#       }
#     ]
#   },
#   {
#     "type": "Creating",
#     "trigger_word": "up",
#     "arguments": [
#       {
#         "text": "several other facilities",
#         "role": "Created_entity"
#       }
#     ]
#   },
#   {
#     "type": "Killing",
#     "trigger_word": "assassination",
#     "arguments": []
#   },
#   {
#     "type": "Manufacturing",
#     "trigger_word": "manufacture",
#     "arguments": []
#   },
#   {
#     "type": "Manufacturing",
#     "trigger_word": "producing",
#     "arguments": [
#       {
#         "text": "CW agents",
#         "role": "Product"
#       }
#     ]
#   },
#   {
#     "type": "Placing",
#     "trigger_word": "located",
#     "arguments": [
#       {
#         "text": "a military front company called Delta G Scientific",
#         "role": "Theme"
#       },
#       {
#         "text": "between Johannesburg and Pretoria",
#         "role": "Location"
#       }
#     ]
#   },
#   {
#     "type": "Placing",
#     "trigger_word": "placing",
#     "arguments": []
#   },
#   {
#     "type": "Research",
#     "trigger_word": "researching",
#     "arguments": [
#       {
#         "text": "CW agents",
#         "role": "Topic"
#       }
#     ]
#   },
#   {
#     "type": "Wearing",
#     "trigger_word": "clothing",
#     "arguments": [
#       {
#         "text": "clothing",
#         "role": "Clothing"
#       }
#     ]
#   }
# ]
# ❌ Document ID: 7ebda9541a1c597f3b54169f3b866524 -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Causation",
#     "trigger_word": "made",
#     "arguments": [
#       {
#         "text": "Las Vegas",
#         "role": "Affected"
#       },
#       {
#         "text": "a part of Nevada 's new Clark County",
#         "role": "Effect"
#       }
#     ]
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Causation",
#     "trigger_word": "made",
#     "arguments": [
#       {
#         "text": "Las Vegas",
#         "role": "Affected"
#       },
#       {
#         "text": "a part of Nevada's new Clark County",
#         "role": "Effect"
#       }
#     ]
#   }
# ]
# ❌ Document ID: 9995d4fa5bc5fee2c663c82343e43e92 -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Death",
#     "trigger_word": "death",
#     "arguments": []
#   },
#   {
#     "type": "Killing",
#     "trigger_word": "assassination",
#     "arguments": []
#   },
#   {
#     "type": "Statement",
#     "trigger_word": "said",
#     "arguments": [
#       {
#         "text": "A final statement",
#         "role": "Speaker"
#       },
#       {
#         "text": "`` While some advances are being made in nations throughout the hemisphere , the state of press freedom in the Americas still must be regarded as grim as long as journalists and their families are subject to the crudest form of censorship : death by assassination . ''",
#         "role": "Message"
#       }
#     ]
#   },
#   {
#     "type": "Statement",
#     "trigger_word": "statement",
#     "arguments": [
#       {
#         "text": "said : `` While some advances are being made in nations throughout the hemisphere , the state of press freedom in the Americas still must be regarded as grim as long as journalists and their families are subject to the crudest form of censorship : death by assassination",
#         "role": "Message"
#       }
#     ]
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Death",
#     "trigger_word": "death",
#     "arguments": []
#   },
#   {
#     "type": "Killing",
#     "trigger_word": "assassination",
#     "arguments": []
#   },
#   {
#     "type": "Statement",
#     "trigger_word": "said",
#     "arguments": []
#   },
#   {
#     "type": "Statement",
#     "trigger_word": "statement",
#     "arguments": [
#       {
#         "text": "said : `` While some advances are being made in nations throughout the hemisphere , the state of press freedom in the Americas still must be regarded as grim as long as journalists and their families are subject to the crudest form of censorship : death by assassination",
#         "role": "Message"
#       }
#     ]
#   }
# ]
# ❌ Document ID: c34bdf5a8c85b48d7a2ff4fd3e1c3de0 -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Assistance",
#     "trigger_word": "assist",
#     "arguments": [
#       {
#         "text": "The FDA 's US Orphan Drug Act",
#         "role": "Helper"
#       },
#       {
#         "text": "companies",
#         "role": "Benefited_party"
#       },
#       {
#         "text": "to develop safe and effective therapies for the treatment of rare diseases and disorders",
#         "role": "Goal"
#       }
#     ]
#   },
#   {
#     "type": "Cause_to_make_progress",
#     "trigger_word": "develop",
#     "arguments": [
#       {
#         "text": "companies",
#         "role": "Agent"
#       },
#       {
#         "text": "safe and effective therapies for the treatment of rare diseases and disorders",
#         "role": "Project"
#       }
#     ]
#   },
#   {
#     "type": "Cure",
#     "trigger_word": "therapies",
#     "arguments": [
#       {
#         "text": "for the treatment of rare diseases and disorders",
#         "role": "Affliction"
#       }
#     ]
#   },
#   {
#     "type": "Cure",
#     "trigger_word": "treatment",
#     "arguments": [
#       {
#         "text": "of rare diseases and disorders",
#         "role": "Affliction"
#       },
#       {
#         "text": "treatment",
#         "role": "Treatment"
#       }
#     ]
#   },
#   {
#     "type": "Influence",
#     "trigger_word": "encourage",
#     "arguments": [
#       {
#         "text": "The FDA 's US Orphan Drug Act",
#         "role": "Situation"
#       },
#       {
#         "text": "companies",
#         "role": "Cognizer"
#       },
#       {
#         "text": "to develop safe and effective therapies for the treatment of rare diseases and disorders",
#         "role": "Action"
#       }
#     ]
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Assistance",
#     "trigger_word": "assist",
#     "arguments": [
#       {
#         "text": "The FDA 's US Orphan Drug Act",
#         "role": "Helper"
#       },
#       {
#         "text": "companies",
#         "role": "Benefited_party"
#       },
#       {
#         "text": "to develop safe and effective therapies for the treatment of rare diseases and disorders",
#         "role": "Goal"
#       }
#     ]
#   },
#   {
#     "type": "Cause_to_make_progress",
#     "trigger_word": "develop",
#     "arguments": [
#       {
#         "text": "companies",
#         "role": "Agent"
#       },
#       {
#         "text": "safe and effective therapies for the treatment of rare diseases and disorders",
#         "role": "Project"
#       }
#     ]
#   },
#   {
#     "type": "Cure",
#     "trigger_word": "therapies",
#     "arguments": []
#   },
#   {
#     "type": "Cure",
#     "trigger_word": "treatment",
#     "arguments": [
#       {
#         "text": "of rare diseases and disorders",
#         "role": "Affliction"
#       },
#       {
#         "text": "treatment",
#         "role": "Treatment"
#       }
#     ]
#   },
#   {
#     "type": "Influence",
#     "trigger_word": "encourage",
#     "arguments": [
#       {
#         "text": "The FDA 's US Orphan Drug Act",
#         "role": "Situation"
#       },
#       {
#         "text": "companies",
#         "role": "Cognizer"
#       },
#       {
#         "text": "to develop safe and effective therapies for the treatment of rare diseases and disorders",
#         "role": "Action"
#       }
#     ]
#   }
# ]
# ❌ Document ID: 25efac86490f536a2e99241e90054e6a -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Statement",
#     "trigger_word": "said",
#     "arguments": [
#       {
#         "text": "He",
#         "role": "Speaker"
#       },
#       {
#         "text": "he had problems in his marriage",
#         "role": "Message"
#       }
#     ]
#   },
#   {
#     "type": "Statement",
#     "trigger_word": "says",
#     "arguments": [
#       {
#         "text": "Stephanopoulos",
#         "role": "Speaker"
#       },
#       {
#         "text": "`` He said he had problems in his marriage , ''",
#         "role": "Message"
#       }
#     ]
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Statement",
#     "trigger_word": "said",
#     "arguments": [
#       {
#         "text": "He",
#         "role": "Speaker"
#       },
#       {
#         "text": "he had problems in his marriage",
#         "role": "Message"
#       }
#     ]
#   },
#   {
#     "type": "Statement",
#     "trigger_word": "says",
#     "arguments": []
#   }
# ]
# ❌ Document ID: c8e4a5f779fa62b0dc91e82ac49d79b2 -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Action",
#     "trigger_word": "action",
#     "arguments": [
#       {
#         "text": "action",
#         "role": "Act"
#       }
#     ]
#   },
#   {
#     "type": "Placing",
#     "trigger_word": "placement",
#     "arguments": [
#       {
#         "text": "of the spent fuel rods",
#         "role": "Theme"
#       }
#     ]
#   },
#   {
#     "type": "Statement",
#     "trigger_word": "reported",
#     "arguments": [
#       {
#         "text": "plutonium reprocessing",
#         "role": "Message"
#       }
#     ]
#   },
#   {
#     "type": "Using",
#     "trigger_word": "used",
#     "arguments": [
#       {
#         "text": "the operational history of the reactor",
#         "role": "Instrument"
#       },
#       {
#         "text": "to account for the discrepancies in Pyongyang 's reported plutonium reprocessing",
#         "role": "Purpose"
#       },
#       {
#         "text": "which",
#         "role": "Instrument"
#       }
#     ]
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Action",
#     "trigger_word": "action",
#     "arguments": [
#       {
#         "text": "action",
#         "role": "Act"
#       }
#     ]
#   },
#   {
#     "type": "Placing",
#     "trigger_word": "placement",
#     "arguments": [
#       {
#         "text": "of the spent fuel rods",
#         "role": "Theme"
#       }
#     ]
#   },
#   {
#     "type": "Statement",
#     "trigger_word": "reported",
#     "arguments": [
#       {
#         "text": "plutonium reprocessing",
#         "role": "Message"
#       }
#     ]
#   },
#   {
#     "type": "Using",
#     "trigger_word": "used",
#     "arguments": [
#       {
#         "text": "the operational history of the reactor",
#         "role": "Instrument"
#       },
#       {
#         "text": "to account for the discrepancies in Pyongyang's reported plutonium reprocessing",
#         "role": "Purpose"
#       },
#       {
#         "text": "which",
#         "role": "Instrument"
#       }
#     ]
#   }
# ]
# ❌ Document ID: cea00949f3c402a5273c51d5179d25e3 -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Assistance",
#     "trigger_word": "assistance",
#     "arguments": []
#   },
#   {
#     "type": "Assistance",
#     "trigger_word": "help",
#     "arguments": [
#       {
#         "text": "Syria",
#         "role": "Benefited_party"
#       },
#       {
#         "text": "an IAEA cooperative assistance project",
#         "role": "Helper"
#       },
#       {
#         "text": "understand the requirements for developing and maintaining a nuclear program",
#         "role": "Goal"
#       }
#     ]
#   },
#   {
#     "type": "Cause_to_make_progress",
#     "trigger_word": "developing",
#     "arguments": [
#       {
#         "text": "Syria",
#         "role": "Agent"
#       },
#       {
#         "text": "a nuclear program",
#         "role": "Project"
#       }
#     ]
#   },
#   {
#     "type": "Scrutiny",
#     "trigger_word": "study",
#     "arguments": []
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Assistance",
#     "trigger_word": "assistance",
#     "arguments": []
#   },
#   {
#     "type": "Assistance",
#     "trigger_word": "help",
#     "arguments": []
#   },
#   {
#     "type": "Cause_to_make_progress",
#     "trigger_word": "developing",
#     "arguments": [
#       {
#         "text": "Syria",
#         "role": "Agent"
#       },
#       {
#         "text": "a nuclear program",
#         "role": "Project"
#       }
#     ]
#   },
#   {
#     "type": "Scrutiny",
#     "trigger_word": "study",
#     "arguments": []
#   }
# ]
# ❌ Document ID: da3950e5f489d082c66355d8e248756f -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Arranging",
#     "trigger_word": "deployed",
#     "arguments": [
#       {
#         "text": "forward",
#         "role": "Configuration"
#       },
#       {
#         "text": "military forces",
#         "role": "Theme"
#       }
#     ]
#   },
#   {
#     "type": "Change_of_leadership",
#     "trigger_word": "revolution",
#     "arguments": []
#   },
#   {
#     "type": "Statement",
#     "trigger_word": "claims",
#     "arguments": [
#       {
#         "text": "claims",
#         "role": "Message"
#       },
#       {
#         "text": "its",
#         "role": "Speaker"
#       }
#     ]
#   },
#   {
#     "type": "Statement",
#     "trigger_word": "states",
#     "arguments": [
#       {
#         "text": "a constitution",
#         "role": "Medium"
#       },
#       {
#         "text": "that",
#         "role": "Medium"
#       },
#       {
#         "text": "that the DPRK is the sole legitimate government for all of Korea",
#         "role": "Message"
#       }
#     ]
#   },
#   {
#     "type": "Terrorism",
#     "trigger_word": "terrorism",
#     "arguments": [
#       {
#         "text": "terrorism",
#         "role": "Act"
#       }
#     ]
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Arranging",
#     "trigger_word": "deployed",
#     "arguments": [
#       {
#         "text": "forward",
#         "role": "Configuration"
#       },
#       {
#         "text": "military forces",
#         "role": "Theme"
#       }
#     ]
#   },
#   {
#     "type": "Change_of_leadership",
#     "trigger_word": "revolution",
#     "arguments": []
#   },
#   {
#     "type": "Statement",
#     "trigger_word": "claims",
#     "arguments": [
#       {
#         "text": "claims",
#         "role": "Message"
#       },
#       {
#         "text": "its",
#         "role": "Speaker"
#       }
#     ]
#   },
#   {
#     "type": "Statement",
#     "trigger_word": "states",
#     "arguments": []
#   },
#   {
#     "type": "Terrorism",
#     "trigger_word": "terrorism",
#     "arguments": [
#       {
#         "text": "terrorism",
#         "role": "Act"
#       }
#     ]
#   }
# ]
# ❌ Document ID: e21cc62818b2774574777bf0d1a3b0df -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Statement",
#     "trigger_word": "proposed",
#     "arguments": [
#       {
#         "text": "an Argentine - German - Spanish consortium",
#         "role": "Message"
#       },
#       {
#         "text": "to complete the Bushehr project",
#         "role": "Message"
#       }
#     ]
#   },
#   {
#     "type": "Statement",
#     "trigger_word": "reported",
#     "arguments": [
#       {
#         "text": "that an Argentine - German - Spanish consortium has been proposed to complete the Bushehr project",
#         "role": "Message"
#       }
#     ]
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Statement",
#     "trigger_word": "proposed",
#     "arguments": []
#   },
#   {
#     "type": "Statement",
#     "trigger_word": "reported",
#     "arguments": [
#       {
#         "text": "that an Argentine - German - Spanish consortium has been proposed to complete the Bushehr project",
#         "role": "Message"
#       }
#     ]
#   }
# ]
# ❌ Document ID: 87e1194c85dd54073dd6165075e9acab -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Process_end",
#     "trigger_word": "lifting",
#     "arguments": [
#       {
#         "text": "North Korea",
#         "role": "Agent"
#       },
#       {
#         "text": "the freeze on its nuclear facilities",
#         "role": "State"
#       }
#     ]
#   },
#   {
#     "type": "Removing",
#     "trigger_word": "expelling",
#     "arguments": [
#       {
#         "text": "IAEA inspectors monitoring that freeze",
#         "role": "Theme"
#       },
#       {
#         "text": "North Korea",
#         "role": "Agent"
#       }
#     ]
#   },
#   {
#     "type": "Response",
#     "trigger_word": "responded",
#     "arguments": [
#       {
#         "text": "The United States",
#         "role": "Agent"
#       },
#       {
#         "text": "by suspending heavy oil shipments",
#         "role": "Response"
#       }
#     ]
#   },
#   {
#     "type": "Revenge",
#     "trigger_word": "retaliated",
#     "arguments": [
#       {
#         "text": "North Korea",
#         "role": "Avenger"
#       },
#       {
#         "text": "by lifting the freeze on its nuclear facilities , expelling IAEA inspectors monitoring that freeze , and announcing its withdrawal from the NPT on 10 January 2003",
#         "role": "Punishment"
#       }
#     ]
#   },
#   {
#     "type": "Scrutiny",
#     "trigger_word": "inspectors",
#     "arguments": [
#       {
#         "text": "inspectors",
#         "role": "Cognizer"
#       }
#     ]
#   },
#   {
#     "type": "Scrutiny",
#     "trigger_word": "monitoring",
#     "arguments": [
#       {
#         "text": "IAEA inspectors",
#         "role": "Cognizer"
#       },
#       {
#         "text": "that freeze",
#         "role": "Ground"
#       }
#     ]
#   },
#   {
#     "type": "Sending",
#     "trigger_word": "shipments",
#     "arguments": [
#       {
#         "text": "heavy oil",
#         "role": "Theme"
#       }
#     ]
#   },
#   {
#     "type": "Statement",
#     "trigger_word": "announcing",
#     "arguments": [
#       {
#         "text": "North Korea",
#         "role": "Speaker"
#       },
#       {
#         "text": "its withdrawal from the NPT on 10 January 2003",
#         "role": "Message"
#       }
#     ]
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Process_end",
#     "trigger_word": "lifting",
#     "arguments": [
#       {
#         "text": "North Korea",
#         "role": "Agent"
#       },
#       {
#         "text": "the freeze on its nuclear facilities",
#         "role": "State"
#       }
#     ]
#   },
#   {
#     "type": "Removing",
#     "trigger_word": "expelling",
#     "arguments": [
#       {
#         "text": "IAEA inspectors monitoring that freeze",
#         "role": "Theme"
#       },
#       {
#         "text": "North Korea",
#         "role": "Agent"
#       }
#     ]
#   },
#   {
#     "type": "Response",
#     "trigger_word": "responded",
#     "arguments": [
#       {
#         "text": "The United States",
#         "role": "Agent"
#       },
#       {
#         "text": "by suspending heavy oil shipments",
#         "role": "Response"
#       }
#     ]
#   },
#   {
#     "type": "Revenge",
#     "trigger_word": "retaliated",
#     "arguments": [
#       {
#         "text": "North Korea",
#         "role": "Avenger"
#       },
#       {
#         "text": "by lifting the freeze on its nuclear facilities , expelling IAEA inspectors monitoring that freeze , and announcing its withdrawal from the NPT on 10 January 2003",
#         "role": "Punishment"
#       }
#     ]
#   },
#   {
#     "type": "Scrutiny",
#     "trigger_word": "inspectors",
#     "arguments": [
#       {
#         "text": "inspectors",
#         "role": "Cognizer"
#       }
#     ]
#   },
#   {
#     "type": "Scrutiny",
#     "trigger_word": "monitoring",
#     "arguments": []
#   },
#   {
#     "type": "Sending",
#     "trigger_word": "shipments",
#     "arguments": [
#       {
#         "text": "heavy oil",
#         "role": "Theme"
#       }
#     ]
#   },
#   {
#     "type": "Statement",
#     "trigger_word": "announcing",
#     "arguments": [
#       {
#         "text": "North Korea",
#         "role": "Speaker"
#       },
#       {
#         "text": "its withdrawal from the NPT on 10 January 2003",
#         "role": "Message"
#       }
#     ]
#   }
# ]
# ❌ Document ID: a44c4f7e9031e42f87b09772f53a04d3 -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Communication",
#     "trigger_word": "acknowledged",
#     "arguments": [
#       {
#         "text": "it",
#         "role": "Speaker"
#       },
#       {
#         "text": "navigational instructions from the FAA 's air traffic control ( ATC ) center in Boston",
#         "role": "Trigger"
#       }
#     ]
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Communication",
#     "trigger_word": "acknowledged",
#     "arguments": [
#       {
#         "text": "it",
#         "role": "Speaker"
#       },
#       {
#         "text": "navigational instructions from the FAA's air traffic control (ATC) center in Boston",
#         "role": "Trigger"
#       }
#     ]
#   }
# ]
# ❌ Document ID: 86d54d61209ffbaa5dd02165196bc939 -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Action",
#     "trigger_word": "activity",
#     "arguments": [
#       {
#         "text": "AL QAEDA 's",
#         "role": "Agent"
#       }
#     ]
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Action",
#     "trigger_word": "activity",
#     "arguments": [
#       {
#         "text": "AL QAEDA's",
#         "role": "Agent"
#       }
#     ]
#   }
# ]
# ❌ Document ID: 62b28df342d7ab8d911593703c866776 -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Commerce_sell",
#     "trigger_word": "sold",
#     "arguments": [
#       {
#         "text": "gas - centrifuge technology",
#         "role": "Goods"
#       },
#       {
#         "text": "he",
#         "role": "Seller"
#       },
#       {
#         "text": "to North Korea , Libya and Iran",
#         "role": "Buyer"
#       }
#     ]
#   },
#   {
#     "type": "Reveal_secret",
#     "trigger_word": "revealed",
#     "arguments": [
#       {
#         "text": "Pakistani nuclear scientist Dr . A. Q. Khan",
#         "role": "Speaker"
#       },
#       {
#         "text": "that he had sold gas - centrifuge technology to North Korea , Libya and Iran",
#         "role": "Information"
#       }
#     ]
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Commerce_sell",
#     "trigger_word": "sold",
#     "arguments": [
#       {
#         "text": "gas - centrifuge technology",
#         "role": "Goods"
#       },
#       {
#         "text": "he",
#         "role": "Seller"
#       },
#       {
#         "text": "to North Korea, Libya and Iran",
#         "role": "Buyer"
#       }
#     ]
#   },
#   {
#     "type": "Reveal_secret",
#     "trigger_word": "revealed",
#     "arguments": [
#       {
#         "text": "Pakistani nuclear scientist Dr. A. Q. Khan",
#         "role": "Speaker"
#       },
#       {
#         "text": "that he had sold gas - centrifuge technology to North Korea, Libya and Iran",
#         "role": "Information"
#       }
#     ]
#   }
# ]
# ❌ Document ID: 647ef162f18014c644da29bc067c09cb -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Building",
#     "trigger_word": "construct",
#     "arguments": [
#       {
#         "text": "India",
#         "role": "Agent"
#       },
#       {
# ...
#       {
#         "text": "An investigation",
#         "role": "Act"
#       }
#     ]
#   },
#   {
#     "type": "Causation",
#     "trigger_word": "cause",
#     "arguments": [
#       {
#         "text": "arson",
#         "role": "Cause"
#       }
#     ]
#   },
#   {
#     "type": "Criminal_investigation",
#     "trigger_word": "investigation",
#     "arguments": []
#   },
#   {
#     "type": "Statement",
#     "trigger_word": "added",
#     "arguments": []
#   },
#   {
#     "type": "Statement",
#     "trigger_word": "said",
#     "arguments": [
#       {
#         "text": "An investigation is being conducted",
#         "role": "Message"
#       },
#       {
#         "text": "Battalion Chief Joe Fahey who also added that they did not believe arson was the cause",
#         "role": "Speaker"
#       }
#     ]
#   }
# ]
# ❌ Document ID: 095c64223056890ed1d1b98db56ddb75 -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Assistance",
#     "trigger_word": "helps",
#     "arguments": [
#       {
#         "text": "A robust economy",
#         "role": "Helper"
#       },
#       {
#         "text": "by providing job opportunities",
#         "role": "Goal"
#       }
#     ]
#   },
#   {
#     "type": "Employment",
#     "trigger_word": "job",
#     "arguments": [
#       {
#         "text": "opportunities",
#         "role": "Position"
#       }
#     ]
#   },
#   {
#     "type": "Employment",
#     "trigger_word": "working",
#     "arguments": [
#       {
#         "text": "people",
#         "role": "Employee"
#       },
#       {
#         "text": "who",
#         "role": "Employee"
#       }
#     ]
#   },
#   {
#     "type": "Supply",
#     "trigger_word": "providing",
#     "arguments": [
#       {
#         "text": "job opportunities",
#         "role": "Theme"
#       }
#     ]
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Assistance",
#     "trigger_word": "helps",
#     "arguments": [
#       {
#         "text": "A robust economy",
#         "role": "Helper"
#       },
#       {
#         "text": "by providing job opportunities",
#         "role": "Goal"
#       }
#     ]
#   },
#   {
#     "type": "Employment",
#     "trigger_word": "job",
#     "arguments": [
#       {
#         "text": "opportunities",
#         "role": "Position"
#       }
#     ]
#   },
#   {
#     "type": "Employment",
#     "trigger_word": "working",
#     "arguments": []
#   },
#   {
#     "type": "Supply",
#     "trigger_word": "providing",
#     "arguments": [
#       {
#         "text": "job opportunities",
#         "role": "Theme"
#       }
#     ]
#   }
# ]
# ❌ Document ID: 8150a94c9d967e87b4e275cc5efbae6e -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Creating",
#     "trigger_word": "up",
#     "arguments": [
#       {
#         "text": "Project Officer Dr . Wouter Basson",
#         "role": "Creator"
#       },
#       {
#         "text": "an elaborate network of procurement and financial front companies",
#         "role": "Created_entity"
#       }
#     ]
#   },
#   {
#     "type": "Getting",
#     "trigger_word": "procurement",
#     "arguments": [
#       {
#         "text": "companies",
#         "role": "Recipient"
#       }
#     ]
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Creating",
#     "trigger_word": "up",
#     "arguments": [
#       {
#         "text": "Project Officer Dr. Wouter Basson",
#         "role": "Creator"
#       },
#       {
#         "text": "an elaborate network of procurement and financial front companies",
#         "role": "Created_entity"
#       }
#     ]
#   },
#   {
#     "type": "Getting",
#     "trigger_word": "procurement",
#     "arguments": [
#       {
#         "text": "companies",
#         "role": "Recipient"
#       }
#     ]
#   }
# ]
# ❌ Document ID: 197fa7b87c1e30df45209283b6190321 -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Action",
#     "trigger_word": "activity",
#     "arguments": [
#       {
#         "text": "activity",
#         "role": "Act"
#       },
#       {
#         "text": "inspectors '",
#         "role": "Agent"
#       }
#     ]
#   },
#   {
#     "type": "Causation",
#     "trigger_word": "causing",
#     "arguments": [
#       {
#         "text": "Iranian officials",
#         "role": "Actor"
#       },
#       {
#         "text": "further delays in the inspectors ' activity",
#         "role": "Effect"
#       }
#     ]
#   },
#   {
#     "type": "Preventing_or_letting",
#     "trigger_word": "allowing",
#     "arguments": [
#       {
#         "text": "Iranian officials",
#         "role": "Agent"
#       },
#       {
#         "text": "the IAEA",
#         "role": "Event"
#       },
#       {
#         "text": "to install the cameras inside the cascade halls in Natanz",
#         "role": "Event"
#       }
#     ]
#   },
#   {
#     "type": "Scrutiny",
#     "trigger_word": "inspectors",
#     "arguments": [
#       {
#         "text": "inspectors",
#         "role": "Cognizer"
#       }
#     ]
#   },
#   {
#     "type": "Scrutiny",
#     "trigger_word": "monitor",
#     "arguments": [
#       {
#         "text": "The nuclear agency",
#         "role": "Cognizer"
#       },
#       {
#         "text": "the larger centrifuge cascade",
#         "role": "Ground"
#       },
#       {
#         "text": "with cameras",
#         "role": "Instrument"
#       }
#     ]
#   },
#   {
#     "type": "Scrutiny",
#     "trigger_word": "monitors",
#     "arguments": [
#       {
#         "text": "a diplomat",
#         "role": "Cognizer"
#       },
#       {
#         "text": "the agency",
#         "role": "Ground"
#       },
#       {
#         "text": "who",
#         "role": "Cognizer"
#       }
#     ]
#   },
#   {
#     "type": "Statement",
#     "trigger_word": "said",
#     "arguments": [
#       {
#         "text": "The nuclear agency had hoped to monitor the larger centrifuge cascade with cameras , but Iranian officials were `` not allowing the IAEA to install the cameras inside the cascade halls in Natanz and are causing further delays in the inspectors ' activity , ''",
#         "role": "Message"
#       },
#       {
#         "text": "a diplomat who closely monitors the agency",
#         "role": "Speaker"
#       }
#     ]
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Action",
#     "trigger_word": "activity",
#     "arguments": [
#       {
#         "text": "activity",
#         "role": "Act"
#       },
#       {
#         "text": "inspectors '",
#         "role": "Agent"
#       }
#     ]
#   },
#   {
#     "type": "Causation",
#     "trigger_word": "causing",
#     "arguments": [
#       {
#         "text": "Iranian officials",
#         "role": "Actor"
#       },
#       {
#         "text": "further delays in the inspectors ' activity",
#         "role": "Effect"
#       }
#     ]
#   },
#   {
#     "type": "Preventing_or_letting",
#     "trigger_word": "allowing",
#     "arguments": [
#       {
#         "text": "Iranian officials",
#         "role": "Agent"
#       },
#       {
#         "text": "the IAEA",
#         "role": "Event"
#       },
#       {
#         "text": "to install the cameras inside the cascade halls in Natanz",
#         "role": "Event"
#       }
#     ]
#   },
#   {
#     "type": "Scrutiny",
#     "trigger_word": "inspectors",
#     "arguments": []
#   },
#   {
#     "type": "Scrutiny",
#     "trigger_word": "monitor",
#     "arguments": [
#       {
#         "text": "The nuclear agency",
#         "role": "Cognizer"
#       },
#       {
#         "text": "the larger centrifuge cascade",
#         "role": "Ground"
#       },
#       {
#         "text": "with cameras",
#         "role": "Instrument"
#       }
#     ]
#   },
#   {
#     "type": "Scrutiny",
#     "trigger_word": "monitors",
#     "arguments": []
#   },
#   {
#     "type": "Statement",
#     "trigger_word": "said",
#     "arguments": [
#       {
#         "text": "The nuclear agency had hoped to monitor the larger centrifuge cascade with cameras , but Iranian officials were `` not allowing the IAEA to install the cameras inside the cascade halls in Natanz and are causing further delays in the inspectors ' activity , ''",
#         "role": "Message"
#       },
#       {
#         "text": "a diplomat who closely monitors the agency",
#         "role": "Speaker"
#       }
#     ]
#   }
# ]
# ❌ Document ID: 03fb7ead01516667dbbe60248f462d82 -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Presence",
#     "trigger_word": "are",
#     "arguments": [
#       {
#         "text": "a number of operating research facilities in Syria , including the Der Al-Hadjar Nuclear Research Center near Damascus , a nuclear analysis laboratory , and the Scientific Research Institute ( SRI ) in Damascus",
#         "role": "Entity"
#       }
#     ]
#   },
#   {
#     "type": "Research",
#     "trigger_word": "Research",
#     "arguments": [
#       {
#         "text": "Nuclear",
#         "role": "Topic"
#       }
#     ]
#   },
#   {
#     "type": "Research",
#     "trigger_word": "research",
#     "arguments": []
#   },
#   {
#     "type": "Scrutiny",
#     "trigger_word": "analysis",
#     "arguments": [
#       {
#         "text": "nuclear",
#         "role": "Ground"
#       }
#     ]
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Presence",
#     "trigger_word": "are",
#     "arguments": [
#       {
#         "text": "a number of operating research facilities in Syria , including the Der Al-Hadjar Nuclear Research Center near Damascus , a nuclear analysis laboratory , and the Scientific Research Institute ( SRI ) in Damascus",
#         "role": "Entity"
#       }
#     ]
#   },
#   {
#     "type": "Research",
#     "trigger_word": "Research",
#     "arguments": []
#   },
#   {
#     "type": "Research",
#     "trigger_word": "research",
#     "arguments": []
#   },
#   {
#     "type": "Scrutiny",
#     "trigger_word": "analysis",
#     "arguments": [
#       {
#         "text": "nuclear",
#         "role": "Ground"
#       }
#     ]
#   }
# ]
# ❌ Document ID: ea9a41c1858393c1d7e3ef841f83c45d -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Building",
#     "trigger_word": "constructing",
#     "arguments": [
#       {
#         "text": "it",
#         "role": "Agent"
#       },
#       {
#         "text": "several new facilities",
#         "role": "Created_entity"
#       }
#     ]
#   },
#   {
#     "type": "Statement",
#     "trigger_word": "allegations",
#     "arguments": [
#       {
#         "text": "by opposition groups and Western governments",
#         "role": "Speaker"
#       }
#     ]
#   },
#   {
#     "type": "Statement",
#     "trigger_word": "announced",
#     "arguments": [
#       {
#         "text": "Iran",
#         "role": "Speaker"
#       },
#       {
#         "text": "that it was constructing several new facilities",
#         "role": "Message"
#       }
#     ]
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Building",
#     "trigger_word": "constructing",
#     "arguments": [
#       {
#         "text": "it",
#         "role": "Agent"
#       },
#       {
#         "text": "several new facilities",
#         "role": "Created_entity"
#       }
#     ]
#   },
#   {
#     "type": "Statement",
#     "trigger_word": "allegations",
#     "arguments": [
#       {
#         "text": "by opposition groups and Western governments",
#         "role": "Speaker"
#       }
#     ]
#   },
#   {
#     "type": "Statement",
#     "trigger_word": "announced",
#     "arguments": []
#   }
# ]
# ❌ Document ID: bb8004d04bbe3d74982e4831d70a8fff -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Causation",
#     "trigger_word": "makes",
#     "arguments": [
#       {
#         "text": "This",
#         "role": "Cause"
#       },
#       {
#         "text": "one of the safest places in the nation to work",
#         "role": "Effect"
#       },
#       {
#         "text": "working at the chemical weapons destruction facility in Anniston",
#         "role": "Affected"
#       }
#     ]
#   },
#   {
#     "type": "Destroying",
#     "trigger_word": "destruction",
#     "arguments": [
#       {
#         "text": "chemical weapons",
#         "role": "Patient"
#       }
#     ]
#   },
#   {
#     "type": "Employment",
#     "trigger_word": "work",
#     "arguments": [
#       {
#         "text": "one of the safest places in the nation",
#         "role": "Place_of_employment"
#       }
#     ]
#   },
#   {
#     "type": "Employment",
#     "trigger_word": "working",
#     "arguments": [
#       {
#         "text": "at the chemical weapons destruction facility in Anniston",
#         "role": "Place_of_employment"
#       }
#     ]
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Causation",
#     "trigger_word": "makes",
#     "arguments": [
#       {
#         "text": "This",
#         "role": "Cause"
#       },
#       {
#         "text": "one of the safest places in the nation to work",
#         "role": "Effect"
#       },
#       {
#         "text": "working at the chemical weapons destruction facility in Anniston",
#         "role": "Affected"
#       }
#     ]
#   },
#   {
#     "type": "Destroying",
#     "trigger_word": "destruction",
#     "arguments": [
#       {
#         "text": "chemical weapons",
#         "role": "Patient"
#       }
#     ]
#   },
#   {
#     "type": "Employment",
#     "trigger_word": "work",
#     "arguments": []
#   },
#   {
#     "type": "Employment",
#     "trigger_word": "working",
#     "arguments": [
#       {
#         "text": "at the chemical weapons destruction facility in Anniston",
#         "role": "Place_of_employment"
#       }
#     ]
#   }
# ]
# ❌ Document ID: 9eb70873d5b03416cdfcd719281e23fc -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Cause_to_make_progress",
#     "trigger_word": "develop",
#     "arguments": [
#       {
#         "text": "job skills",
#         "role": "Project"
#       }
#     ]
#   },
#   {
#     "type": "Employment",
#     "trigger_word": "job",
#     "arguments": []
#   },
#   {
#     "type": "Employment",
#     "trigger_word": "working",
#     "arguments": [
#       {
#         "text": "a man with some serious disabilities",
#         "role": "Employee"
#       },
#       {
#         "text": "in Goodwill 's industrial division",
#         "role": "Place_of_employment"
#       }
#     ]
#   },
#   {
#     "type": "Process_start",
#     "trigger_word": "begins",
#     "arguments": [
#       {
#         "text": "a man with some serious disabilities",
#         "role": "Agent"
#       },
#       {
#         "text": "working in Goodwill 's industrial division",
#         "role": "Event"
#       }
#     ]
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Cause_to_make_progress",
#     "trigger_word": "develop",
#     "arguments": [
#       {
#         "text": "job skills",
#         "role": "Project"
#       }
#     ]
#   },
#   {
#     "type": "Employment",
#     "trigger_word": "job",
#     "arguments": []
#   },
#   {
#     "type": "Employment",
#     "trigger_word": "working",
#     "arguments": []
#   },
#   {
#     "type": "Process_start",
#     "trigger_word": "begins",
#     "arguments": [
#       {
#         "text": "a man with some serious disabilities",
#         "role": "Agent"
#       },
#       {
#         "text": "working in Goodwill 's industrial division",
#         "role": "Event"
#       }
#     ]
#   }
# ]
# ❌ Document ID: 037b77cc4a921628d754bfb71d2ac3eb -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Manufacturing",
#     "trigger_word": "production",
#     "arguments": [
#       {
#         "text": "fuel",
#         "role": "Product"
#       }
#     ]
#   },
#   {
#     "type": "Scrutiny",
#     "trigger_word": "analysts",
#     "arguments": []
#   },
#   {
#     "type": "Supply",
#     "trigger_word": "provided",
#     "arguments": [
#       {
#         "text": "by a supplier country ( fuel production plant )",
#         "role": "Supplier"
#       },
#       {
#         "text": "the feedstock or product",
#         "role": "Theme"
#       }
#     ]
#   },
#   {
#     "type": "Supply",
#     "trigger_word": "supplier",
#     "arguments": [
#       {
#         "text": "supplier",
#         "role": "Supplier"
#       }
#     ]
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Manufacturing",
#     "trigger_word": "production",
#     "arguments": [
#       {
#         "text": "fuel",
#         "role": "Product"
#       }
#     ]
#   },
#   {
#     "type": "Scrutiny",
#     "trigger_word": "analysts",
#     "arguments": []
#   },
#   {
#     "type": "Supply",
#     "trigger_word": "provided",
#     "arguments": []
#   },
#   {
#     "type": "Supply",
#     "trigger_word": "supplier",
#     "arguments": [
#       {
#         "text": "supplier",
#         "role": "Supplier"
#       }
#     ]
#   }
# ]
# ❌ Document ID: 09c6bd7a5b35d9ca2a7931bff8923dd9 -> CÓ SỰ KHÁC BIỆT
#   🔻 Ở List 1:
#     [
#   {
#     "type": "Action",
#     "trigger_word": "action",
#     "arguments": [
#       {
#         "text": "action",
#         "role": "Act"
#       },
#       {
#         "text": "the city 's now-formidable public relations machine",
#         "role": "Agent"
#       }
#     ]
#   }
# ]
#   🔻 Ở List 2:
#     [
#   {
#     "type": "Action",
#     "trigger_word": "action",
#     "arguments": [
#       {
#         "text": "action",
#         "role": "Act"
#       },
#       {
#         "text": "the city's now-formidable public relations machine",
#         "role": "Agent"
#       }
#     ]
#   }
# ]
# failed_count:  52

# %%
import time
import csv
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse

BASE_URL = "https://chiaki.vn/"
DOMAIN = urlparse(BASE_URL).netloc
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 "
                  "(KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36"
}

session = requests.Session()
session.headers.update(HEADERS)

def is_internal(url: str) -> bool:
    p = urlparse(url)
    return (p.netloc == "" or p.netloc == DOMAIN) and p.scheme in ("", "http", "https")

def get_soup(url: str):
    try:
        r = session.get(url, timeout=20)
        r.raise_for_status()
        return BeautifulSoup(r.text, "html.parser")
    except Exception as e:
        print(f"[WARN] Failed: {url} -> {e}")
        return None

def extract_products(soup, page_url):
    products = []
    
    # Common product containers (fallback strategy)
    containers = soup.select(
        ".product-item, .item-product, .product, .p-item, .box-product, li.product, .list-product .item"
    )
    
    for c in containers:
        # Name
        name_tag = c.select_one("h2, h3, h4, .product-name, .name, a[title]")
        name = name_tag.get_text(strip=True) if name_tag else ""

        # URL
        a = c.select_one("a[href]")
        url = urljoin(page_url, a["href"]) if a and a.get("href") else ""

        # Price
        price_tag = c.select_one(
            ".price, .product-price, .price-new, .sale-price, .current-price, [class*='price']"
        )
        price = price_tag.get_text(" ", strip=True) if price_tag else ""

        if name or url or price:
            products.append({
                "url": url,
                "name": name,
                "price": price
            })
    return products

def crawl_site(start_url=BASE_URL, max_pages=20, delay=1.0):
    queue = [start_url]
    visited = set()
    all_products = []

    while queue and len(visited) < max_pages:
        url = queue.pop(0)
        if url in visited:
            continue
        visited.add(url)

        soup = get_soup(url)
        if soup is None:
            continue

        # Extract products from current page
        products = extract_products(soup, url)
        all_products.extend(products)
        print(f"[INFO] Crawled: {url} | products found: {len(products)}")

        # Discover internal links
        for a in soup.select("a[href]"):
            nxt = urljoin(url, a["href"]).split("#")[0]
            if is_internal(nxt) and nxt not in visited and nxt not in queue:
                queue.append(nxt)

        time.sleep(delay)

    # Deduplicate by URL+name
    unique = {}
    for p in all_products:
        key = (p["url"], p["name"])
        if key not in unique:
            unique[key] = p
    return list(unique.values())

# Run crawl
# products = crawl_site(max_pages=25, delay=1.2)
# print(f"\nTotal unique products: {len(products)}")

# # Save CSV
# out_file = "chiaki_products.csv"
# with open(out_file, "w", newline="", encoding="utf-8-sig") as f:
#     writer = csv.DictWriter(f, fieldnames=["url", "name", "price"])
#     writer.writeheader()
#     writer.writerows(products)

# print(f"Saved: {out_file}")
get_soup("https://chiaki.vn/vitamin-tong-hop-va-khoang-chat")
# Out:
# <!DOCTYPE html>
#
# <html lang="vi">
# <head>
# <script>
#         var dataLayer = window.dataLayer || [];
#         var strCode = ""; var productTitle = ""; var productCode = ""; var productId = ""; var productQuantity = "0"; var productPrice = "0"; var pageType = "view_item_list"; var actionType = "PageView"; var fbContentType = "product"; var totalValue = ""; var cameback_title = 'Chiaki.vn - Khuyến mãi hấp dẫn đang chờ bạn'; var x = document.referrer; var pathname = window.location.pathname; var date = new Date(); var current_url = extractDomain(window.location.href); var domain = extractDomain(x); var guid_tab = getWindowGUID(); var tab_count = 0; var shippingExtramural = {"73":["co-nhue","phu-dien","cau-thang-long","gan-cau-thang-long","hoc-vien-tai-chinh","h-vien-tai-chinh","h-v-tai-chinh","hoc-vien-canh-sat","h-v-canh-sat","h-vien-canh-sat"],"79":["nhat-tan","gan-cau-nhat-tan"],"75":["tran-phu"],"97":["ngoc-hoi"],"76":["chuong-duong-do"]}; var storeId = null; var restQDomain = 'https://restq.chiaki.vn'; var chatUrl = 'https://chat-crm.megaads.vn'; var totalOrder = "0"; var orderCurrency = ""; var orderItems = '';  var fbItemsIds = ''; var google_tag_params = { dynx_pagetype: pageType, event: pageType, items:[] }; var facebook_pixel_action = actionType; var facebook_pixel_params = { content_type: fbContentType };  if (productCode != '' && productId != '') { google_tag_params.dynx_itemid = productCode; google_tag_params.dynx_itemid2 = productId; google_tag_params.items = [{id:productCode,location_id:productId,google_business_vertical:'custom'},{id:productCode,google_business_vertical:'retail'}]; facebook_pixel_params.content_name = productTitle; facebook_pixel_params.value = productPrice; facebook_pixel_params.currency = 'VND'; facebook_pixel_params.content_ids = [productCode]; facebook_pixel_params.contents = [{id: productCode, quantity: parseInt((productQuantity === '0' ) ? 1 : productQuantity), item_price: productPrice }]; } if (totalValue != '') { google_tag_params.dynx_totalvalue = totalValue; google_tag_params.value = totalValue; } if (strCode != '') { var arrCode = strCode.split(","); google_tag_params.dynx_itemid = arrCode; arrCode.forEach(function(code){ google_tag_params.items.push({id:code,google_business_vertical:'custom'}); google_tag_params.items.push({id:code,google_business_vertical:'retail'}); }); } if (totalOrder !== '' && orderItems !== '' && fbItemsIds !== '') { facebook_pixel_params.value = totalOrder; facebook_pixel_params.currency = orderCurrency; facebook_pixel_params.contents = JSON.parse(orderItems); facebook_pixel_params.content_ids = fbItemsIds; } if ( actionType === 'Purchase' && (totalOrder === 0 || orderItems === '')) { facebook_pixel_action = ''; } dataLayer.push(facebook_pixel_params); document.addEventListener('DOMContentLoaded', function() { if (pageType == 'view_item') { dataLayer.push({'event': "ViewContent"}); } }); function extractDomain(url) { var domain; if (url.indexOf("://") > -1) { domain = url.split('/')[2]; } else { domain = url.split('/')[0]; } domain = domain.split(':')[0]; return domain; } function getWindowGUID() { var windowGUID = function () { var S4 = function () { return ( Math.floor( Math.random() * 0x10000 /* 65536 */ ).toString(16) ); }; return ( S4() + S4() + "_" + S4() + S4() + S4() ); }; var topMostWindow = window; while (topMostWindow != topMostWindow.parent) { topMostWindow = topMostWindow.parent; } if (!topMostWindow.name.match(/^GUID_/)) { topMostWindow.name = "GUID_" + windowGUID(); } return topMostWindow.name; } </script> <script>function gtag(){dataLayer.push(arguments)}dataLayer.push({google_tag_params:google_tag_params}),gtag("js",new Date)</script><script>!function(e,t,a,n,g){e[n]=e[n]||[],e[n].push({"gtm.start":(new Date).getTime(),event:"gtm.js"});var m=t.getElementsByTagName(a)[0],r=t.createElement(a);r.async=!0,r.src="//www.googletagmanager.com/gtm.js?id=GTM-K3PGCX",m.parentNode.insertBefore(r,m)}(window,document,"script","dataLayer")</script> <meta charset="utf-8"/> <link href="/frontend/images/favicon.ico" rel="shortcut icon" type="image/x-icon"/> <link ...
# <!-- <script type="text/javascript">
#         window._uxa = window._uxa || [];
#         window._uxa.push(["setCustomVariable", 1, "PageType", "category", "page"]);
#     </script> -->
# <meta content="#2199c4" name="theme-color"/>
# <script type="text/javascript">
#         var commentsNote = []; var tokenGetCustomer = 'IsOQkI7Df9VGXZ4CBTb9Q7Ixerw24kDoRP0kWhDO'; var userLoggedIn = 0; var userTracking = {}; var API_URL = 'https://api.chiaki.vn'; var SITE_URL = 'https://chiaki.vn'; var AB_TEST_GROUP = 'A'; </script> <script type="text/javascript">
#     var referHost = ''; var fullUrl = window.location.href; var host = "chiaki.vn"; var tr = ""; if(tr){ if (fullUrl.indexOf("?") >= 0){ fullUrl = fullUrl + "&tr="+tr; }else{ fullUrl = fullUrl + "?tr="+tr; } } </script> <link href="https://chiaki.vn/build/css/desktop/chiaki.frontend-style.min.css?v=20260504141443" media="all" onerror="onCssError(this)" rel="stylesheet" type="text/css"/>
# <link href="https://chiaki.vn/frontend/css/location.css?v=20260504141443" media="all" onerror="onCssError(this)" rel="stylesheet" type="text/css"/>
# <script onerror="onJsError(this)" src="https://chiaki.vn/frontend/js/jquery.js?v=20260504141443"></script>
# <script onerror="onJsError(this)" src="https://chiaki.vn/frontend/js/slick/slick.min.js?v=20260504141443"></script>
# <script onerror="onJsError(this)" src="https://chiaki.vn/frontend/js/jquery.cookie.js?v=20260504141443"></script>
# <script onerror="onJsError(this)" src="https://chiaki.vn/system/script/angular.min.js"></script>
# <script onerror="onJsError(this)" src="https://chiaki.vn/system/script/angular-sanitize.min.js"></script>
# <script onerror="onJsError(this)" src="https://chiaki.vn/system/script/ng-file-upload.min.js"></script>
# <script onerror="onJsError(this)" src="https://chiaki.vn/frontend/js/chiaki-app.js?v=20260504141443"></script>
# <script onerror="onJsError(this)" src="https://chiaki.vn/frontend/js/controller/header.js?v=20260504141443"></script>
# <script onerror="onJsError(this)" src="https://chiaki.vn/frontend/js/mailstream-tracking.js?v=20260504141443"></script>
# <script type="application/ld+json">
#         {
#             "@context": "http://schema.org/",
#             "@type": "WebSite",
#             "url": "https://chiaki.vn/",
#             "potentialAction": {
#                 "@type": "SearchAction",
#                 "target": "https://chiaki.vn/search?q={search_term_string}",
#                 "query-input": "required name=search_term_string"
#             }
#         }
#     </script>
# <script type="application/ld+json">
#         {
#             "@context": "https://schema.org",
#             "@type": "Organization",
#             "name": "Chiaki",
#             "alternateName": "Chiaki.vn",
#             "description":"Mua sắm trực tuyến hàng nghìn sản phẩm: Mẹ và bé, sức khỏe & làm đẹp, thời trang, đồng hồ, đồ gia dụng, chăm sóc thú cưng... giá tốt nhất tại Chiaki.vn",
#             "leiCode": "0108196083",
#             "legalName": "Chiaki.vn",
#             "foundingDate": "2018-03-23",
#             "founder":{
#             "@type": "Person",
#             "name": "Đặng Minh Nguyệt"
#             },
#             "address":{
#                 "@type": "PostalAddress",
#                 "streetAddress": "Tầng 3, tòa A, Hoành Sơn Complex, số 282 Nguyễn Huy Tưởng, Thanh Xuân Trung, Thanh Xuân",
#                 "addressLocality": "Hà Nội",
#                 "postalCode": "100000",
#                 "addressCountry": "VN"
#             },
#             "member":{
#                 "@type": "Organization",
#                 "name":"Công ty Cổ phần Thương mại Chiaki"
#             },
#             "url": "https://chiaki.vn/",
#             "logo": "https://chiaki.vn/frontend/images/chiaki-large.png",
#             "contactPoint": {
#                 "@type": "ContactPoint",
#                 "telephone": "+84932888300",
#                 "email": "cskh@chiaki.vn",
#                 "contactType": "customer service",
#                 "areaServed": "Việt Nam",
#                 "availableLanguage": "Vietnamese"
#             },
#             "sameAs" : [
#                 "https://www.facebook.com/chiaki.vietnam/",
#                 "https://twitter.com/chiakivnonline",
#                 "https://www.instagram.com/chiakivnonline/",
#                 "https://www.youtube.com/channel/UCDPLKy0Fl5_d2tJ2oRWVicQ",
#                 "https://www.linkedin.com/in/chiakivn/",
#                 "https://www.pinterest.com/chiakivnonline/",
#                 "https://www.tiktok.com/@chiaki_vn",
#                 "https://chiakivn.blogspot.com/",
#                 "https://chiakishop.wordpress.com",
#                 "https://sites.google.com/view/chiakivn",
#                 "https://about.me/chiakivnonline/",
#                 "https://apps.apple.com/vn/app/chiaki/id1304836406",
#                 "https://play.google.com/store/apps/details?id=vn.chiaki"
#             ]
#         }
#     </script>
# <script type="application/ld+json">
#         {
#             "@context": "https://schema.org/",
#             "@type": "Person",
#             "name": "Phan Thanh Dần",
#             "url": "https://chiaki.vn/tac-gia/phanthanhdan",
#             "image": "https://chiaki.vn/upload/avatar/2020/09/bac-si-phan-thanh-dan-jpg-5f55a7db24483-07092020102411.jpg",
#             "sameAs": [
#                 "https://www.facebook.com/thanhdan1511/",
#                 "https://twitter.com/thanhdan1511",
#                 "https://www.instagram.com/thanhdan1511/",
#                 "https://www.youtube.com/channel/UCxzyl4-YxKx-rWUQ0Zv7wQQ/",
#                 "https://www.linkedin.com/in/thanhdan1511/",
#                 "https://www.pinterest.com/thanhdan1511/",
#                 "https://soundcloud.com/thanhdan1511",
#                 "https://about.me/thanhdan1511",
#                 "https://www.flickr.com/people/thanhdan1511/",
#                 "https://chiaki.vn"
#             ],
#             "jobTitle": "Consulting Doctor",
#             "description": "Thầy thuốc ưu tú, bác sĩ cố vấn chuyên môn sản phẩm sức khỏe trên chiaki.vn",
#             "worksFor": {
#                 "@type": "Organization",
#                 "name": "Công ty Cổ phần Thương mại Chiaki"
#             }
#         }
#     </script>
# <link href="/frontend/css/category.css?v=20260504141443" rel="stylesheet"/> <link href="/frontend/css/dk-quick-add-cart.css?v=20260504141443" rel="stylesheet"/> </meta></meta></meta></meta></head> <body ng-app="chiaki-app"> <!-- Google Tag Manager -->
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-K3PGCX" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager --><script defer="true" onerror="onJsError(this)" src="https://chiaki.vn/build/js/desktop/ctr-hamster.min.js?v=20260504141443"></script>
# <link href="/frontend/css/search-by-image.css?v=20260504141443" rel="stylesheet"/> <link href="/assets/css/dk-layout.css?v=20260504141443" rel="stylesheet"/> <link href="/frontend/css/sign-in.css?v=20260504141443" rel="stylesheet"/> <div class="show-menu-allpage" id="header" ng-controller="HeaderController"> <div class="product-header-top header-background-color"> <div class="site-w"> <div class="product-header-top-content d-flex justify-between items-center gap8"> <div class="product-header-top-content-left d-flex justify-start items-center"> <a class="header-top-link d-flex justify-center items-center" href="https://seller.chiaki.vn/login" rel="nofollow" target="_blank">Kênh người bán</a> <a class="header-top-link d-flex justify-center items-center" href="https://seller.chiaki.vn/register" rel="nofollow">Tạo shop</a> <a class="header-top-link d-flex justify-center items-center" href="/apps" rel="nofollow">Tải ứng dụng</a> <a class="header-top-link complain-phone-link d-flex justify-center items-center" href="tel:0911.888.300" rel="nofollow"> Khiếu nại, báo lỗi: 0911.888.300 </a> </div> <div class="product-header-top-content-right d-flex justify-end items-center"> <a class="header-top-link d-flex justify-center items-center" href="/tin-tuc"> <svg fill="none" height="17" viewbox="0 0 16 17" width="16" xmlns="http://www.w3.org/2000/svg"> <path d="M8 1.33301C11.958 1.33301 15.167 4.54196 15.167 8.5C15.167 12.458 11.958 15.667 8 15.667C4.04196 15.667 0.833008 12.458 0.833008 8.5C0.833008 4.54196 4.04196 1.33301 8 1.33301ZM8 2.33301C4.59424 2.33301 1.83301 5.09424 1.83301 8.5C1.83301 11.9058 4.59424 14.667 8 14.667C11.4058 14.667 14.167 11.9058 14.167 8.5C14.167 5.09424 11.4058 2.33301 8 2.33301ZM8 10.5C8.36819 10.5 8.66699 10.7988 8.66699 11.167C8.66682 11.535 8.36808 11.833 8 11.833C7.63192 11.833 7.33318 11.535 7.33301 11.167C7.33301 10.7988 7.63181 10.5 8 10.5ZM8 4.66699C8.9665 4.66699 9.75 5.45049 9.75 6.41699C9.74988 7.05899 9.40401 7.61999 8.89062 7.92383C8.75946 8.00143 8.65062 8.08582 8.58008 8.16895C8.51183 8.24937 8.50008 8.30203 8.5 8.33301V9.16699C8.49982 9.44299 8.27603 9.66699 8 9.66699C7.72397 9.66699 7.50018 9.44299 7.5 9.16699V8.33301C7.50009 7.99614 7.64751 7.72277 7.81738 7.52246C7.9854 7.32447 8.19514 7.17238 8.38086 7.0625C8.60269 6.93121 8.74988 6.69119 8.75 6.41699C8.75 6.00278 8.41421 5.66699 8 5.66699C7.58579 5.66699 7.25 6.00278 7.25 6.41699C7.24982 6.69299 7.02603 6.91699 6.75 6.91699C6.47397 6.91699 6.25018 6.69299 6.25 6.41699C6.25 5.45049 7.0335 4.66699 8 4.66699Z" fill="white"></path> </svg> <span>Hỏi đáp</span> </a> <div class="header-top-link tracking-order-link d-flex justify-center items-center"> <svg fill="none" height="17" viewbox="0 0 16 17" width="16" xmlns="http://www.w3.org/2000/svg"> <path clip-rule="evenodd" d="M3.5 5.6337C3.5 3.23493 5.53917 1.3335 8 1.3335C10.4053 1.3335 12.4078 3.15008 12.4969 5.47208L12.8154 5.57826C13.1242 5.68115 13.3948 5.77134 13.6095 5.87121C13.8416 5.97918 14.0543 6.11826 14.2169 6.34386C14.3795 6.56946 14.4441 6.81522 14.4732 7.06954C14.5 7.3048 14.5 7.59004 14.5 7.91548V11.7476C14.5 12.1539 14.5 12.5005 14.4685 12.7785C14.4353 13.071 14.3612 13.3585 14.1603 13.6037C14.0449 13.7445 13.9049 13.8632 13.747 13.9538C13.4721 14.1117 13.1764 14.1376 12.8824 14.1222C12.6029 14.1076 12.261 14.0506 11.8603 13.9838L11.8326 13.9792C10.9707 13.8355 10.6234 13.7812 10.2849 13.8095C10.1611 13.8199 10.0381 13.8384 9.91669 13.8649C9.58493 13.9374 9.2659 14.0929 8.47736 14.4872C8.44994 14.5009 8.42283 14.5144 8.39602 14.5279C7.47425 14.9889 6.90635 15.273 6.29354 15.3617C6.10923 15.3884 5.92321 15.4016 5.73697 15.4013C5.11779 15.4001 4.51997 15.2007 3.55024 14.8773C3.52219 14.8679 3.49382 14.8585 3.46514 14.8489L3.20943 14.7637L3.18456 14.7554C2.87582 14.6525 2.60522 14.5623 2.39053 14.4624C2.15844 14.3545 1.94574 14.2154 1.78314 13.9898C1.62054 13.7642 1.55586 13.5184 1.52682 13.2641C1.49997 13.0289 1.49998 12.7436 1.5 12.4182L1.5 9.07165C1.49998 8.54758 1.49996 8.1058 1.5448 ...
# </form>
# </div>
# </div>
# <script>
#     var API_URL = 'https://api.chiaki.vn'; var APP_URL = 'https://chiaki.vn'; var flashEmail = ''; var flashPhone = ''; var flashUserExists = ''; var flashPasswordError = ''; var flashPreviousStep = ''; var isDesktop = 1; window.openDesktopSignInPopup = function(redirectUrl) { setTimeout(function() { var trigger = document.getElementById('desktopSignInTrigger'); if (trigger) { if (redirectUrl) { trigger.setAttribute('data-redirect-url', redirectUrl); } trigger.click(); } }, 0); }; </script><script type="text/javascript">
# var userType = "customer"; var checkCustomerHasPhone = ""; var checkGetHotlines = 1; var searchPlaceHolderConfig = "Tìm kiếm sản phẩm, thương hiệu, và tên shop"; var isHomePage = ''; var showCheckOrder = 1; </script><script onerror="onJsError(this)" src="https://chiaki.vn/frontend/js/header.js?v=20260504141443"></script>
# <script onerror="onJsError(this)" src="https://chiaki.vn/frontend/js/product/cart-info.js?v=20260504141443"></script>
# <script onerror="onJsError(this)" src="https://chiaki.vn/assets/js/dk-layout.js?v=20260504141443"></script>
# <script onerror="onJsError(this)" src="https://chiaki.vn/frontend/js/controller/base-controller.js?v=20260504141443"></script>
# <script onerror="onJsError(this)" src="https://chiaki.vn/frontend/js/controller/sign-in-sign-up-controller.js?v=20260504141443"></script>
# <div id="bg-dummy"></div> <span class="navbar-background"></span> <div class="view-category" id="main"> <div class="category-breadcrumb" role="navigation"> <ul class="breadcrumb-nav"> <li> <a href="/" title="Trang chủ">Trang chủ</a> </li> <li> <a href="thuc-pham-chuc-nang" title="Thực phẩm chức năng"><span>Thực phẩm chức năng</span></a> </li> <li> <span>Vitamin Tổng Hợp Và Khoáng Chất</span> </li> </ul>
# </div>
# <script type="application/ld+json">
#         {
#             "@context":"https://schema.org",
#             "@type":"BreadcrumbList",
#             "itemListElement":[
#                 {
#                     "@type":"ListItem",
#                     "position":1,
#                     "item":{
#                         "@id":"https://chiaki.vn/",
#                         "name":"Chiaki"
#                     }
#                 }
#
#                         ,{
#                             "@type":"ListItem",
#                             "position": 2,
#                             "item":{
#                                 "@id":"thuc-pham-chuc-nang",
#                                 "name":"Thực phẩm chức năng"
#                             }
#                         }
#
#                         ,{
#                             "@type":"ListItem",
#                             "position": 3,
#                             "item":{
#                                 "@id":"vitamin-tong-hop-va-khoang-chat",
#                                 "name":"Vitamin Tổng Hợp Và Khoáng Chất"
#                             }
#                         }
#                          ] } </script> <div class="container"> <script type="application/ld+json">
#                     {
#                         "@context": "https://schema.org/",
#                         "@type": "Product",
#                         "name": "Vitamin Tổng Hợp Và Khoáng Chất Chính Hãng Giá Tốt", "image": ["https://cdn.chiaki.vn/unsafe/0x480/left/top/smart/filters:quality(75)/https://s3-images.chiaki.vn/seller/1765206910046/cloud-image-1765206910046-1765205986490-screen-shot-2025-12-08-at-9.46.59-pm.png","https://cdn.chiaki.vn/unsafe/0x480/left/top/smart/filters:quality(75)/https://s3-images.chiaki.vn/system/uploads/product/1768019001194/cloud-image-1768019001194-hang-nhap-khau-vien-uong-canxi-huu-co-olympian-labs-green-calcium.png","https://cdn.chiaki.vn/unsafe/0x480/left/top/smart/filters:quality(75)/https://s3-images.chiaki.vn/seller/1762523460753/cloud-image-1762523460753-1762522041922-zinc-tadavina-ma--i-2.jpeg","https://cdn.chiaki.vn/unsafe/0x480/left/top/smart/filters:quality(75)/https://s3-images.chiaki.vn/seller/1768055675250/cloud-image-1768055675250-1768055591849-screenshot-2026-01-10-at-9.28.21a--pm.png","https://cdn.chiaki.vn/unsafe/0x480/left/top/smart/filters:quality(75)/https://s3-images.chiaki.vn/seller/1763985334242/cloud-image-1763985334242-24112025185534-date-2026-vien-bo-sung-vitamin-b12-nature-made-1000mcg-160vien-hang-noi-dia-my.jpg","https://cdn.chiaki.vn/unsafe/0x480/left/top/smart/filters:quality(75)/https://chiaki.vn/upload/seller/1742346135-37.png","https://cdn.chiaki.vn/unsafe/0x480/left/top/smart/filters:quality(75)/https://s3-images.chiaki.vn/seller/1768876197056/cloud-image-1768876197056-vien-uong-kem-dhc-date.jpg","https://cdn.chiaki.vn/unsafe/0x480/left/top/smart/filters:quality(75)/https://s3-images.chiaki.vn/system/uploads/product/1776913817791/cloud-image-1776913817791-vien-uong-liposomal-magnesium-glycinate.jpg","https://cdn.chiaki.vn/unsafe/0x480/left/top/smart/filters:quality(75)/https://s3-images.chiaki.vn/seller/1765222449548/cloud-image-1765222449548-1765221881850-screen-shot-2025-12-09-at-2.22.36-am.png","https://cdn.chiaki.vn/unsafe/0x480/left/top/smart/filters:quality(75)/https://chiaki.vn/upload/seller/1715999525-set-kem-vitamin-c-dhc-nhat.jpg"], "brand": { "@type": "Brand", "name": ["Nature Made","DHC","Blackmores","KIRKLAND","Nature's Bounty","Uvedose"," KIRKLAND SIGNATURE","Bayer","Centrum","Now Foods"] }, "offers": { "@type": "AggregateOffer", "lowPrice": "0", "highPrice": "11475000", "priceCurrency": "VND", "offerCount": "17" }, "description": "Mua Vitamin tổng hợp và khoáng chất chính hãng: Anh, Mỹ, Nhật, Úc... ✅ Tốt cho sức khỏe người già, trẻ nhỏ, nam và nữ tại Chiaki.vn ✅ Giao hàng miễn phí!", "aggregateRating": { "@type": "AggregateRating", "ratingValue": "4.4", "reviewCount": "600" }, "review": { "@type": "Review", "author": { "@type": "Person", "name": "thuthao.milo" }, "reviewRating": { "@type": "Rating", "ratingValue": "5", "bestRating": "5" } } } </script> <script type="application/ld+json">
#                         {
#                             "@context": "https://schema.org",
#                             "@type": "ItemList",
#                             "itemListElement": [
#
#                         {
#                             "@type":"ListItem",
#                             "position": "1",
#                             "url": "https://chiaki.vn/daily-vien-uong-duong-chat-thuc-vat-tu-trang-trai-huu-co"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "2",
#                             "url": "https://chiaki.vn/hang-nhap-khau-vien-uong-canxi-huu-co-olympian-labs-green-calcium"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "3",
#                             "url": "https://chiaki.vn/siro-bo-sung-kem-zinc-tadavina-giup-tang-cuong-suc-de-khang-an-ngon"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "4",
#                             "url": "https://chiaki.vn/vien-uong-canxi-magie-d3-ho-tro-xuong-chac-khoe-bo-sung-canxi"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "5",
#                             "url": "https://chiaki.vn/date-2026-vien-bo-sung-vitamin-b12-nature-made-1000mcg-160vien-hang-noi-dia-my"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "6",
#                             "url": "https://chiaki.vn/vitamin-d3-2000iu-kirkland-vitamin-mat-troi-600-vien"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "7",
#                             "url": "https://chiaki.vn/vien-uong-dhc-kem-nhat-ban-chinh-hang-60-vien-hsd-2028"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "8",
#                             "url": "https://chiaki.vn/codeage-liposomal-magnesium-glycinate-ho-tro-bo-sung-magie"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "9",
#                             "url": "https://chiaki.vn/vien-uong-vitamin-c-180-vien-ho-tro-tang-cuong-suc-de-khang"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "10",
#                             "url": "https://chiaki.vn/combo-vien-uong-dhc-vitamin-c-va-kem-ngua-mun-mo-tham-60-ngay"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "11",
#                             "url": "https://chiaki.vn/kem-ada-kem-gluconate-nguyen-lieu-nhap-khau-phap-ho-tro-tang-cuong-suc-khoe"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "12",
#                             "url": "https://chiaki.vn/vien-uong-bo-sung-canxi-tao-bien-do-calci-mk7-max"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "13",
#                             "url": "https://chiaki.vn/vien-uong-bo-sung-magie-magtein-magnesium-l-threonate-2000mg-449613"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "14",
#                             "url": "https://chiaki.vn/vien-uong-bo-sung-vitamin-c-blackmores-bio-c-1000mg-150-vien-uc-me-soc"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "15",
#                             "url": "https://chiaki.vn/vien-uong-bo-sung-magie-nature-s-bounty-magnesium-glycinate-240mg-180-vien-cua-my"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "16",
#                             "url": "https://chiaki.vn/vien-uong-bo-sung-canxi-bio-island-milk-calcium-bone-care"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "17",
#                             "url": "https://chiaki.vn/vitamin-tong-hop-cho-nu-one-a-day-women-s-formula-cua-my-300-vien"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "18",
#                             "url": "https://chiaki.vn/vien-uong-bo-sung-magie-now-magnesium-glycinate-with-bioperine-180-vien-nang-thuc-vat-ho-tro-he-than-kinh-cua-my"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "19",
#                             "url": "https://chiaki.vn/vien-uong-bo-sung-magie-webber-naturals-magnesium-bisglycinate-200mg-60-vien"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "20",
#                             "url": "https://chiaki.vn/vitamin-d3-uvedose-100-000-iu-phap-tang-de-khang-hap-thu-canxi-phong-coi-xuong-ong-uong-3-thang"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "21",
#                             "url": "https://chiaki.vn/vien-uong-dhc-bo-sung-vitamin-c-120-vien"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "22",
#                             "url": "https://chiaki.vn/vien-bo-sung-magnesium-glycinate-240mg-nature-s-bounty-180-vien-449478"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "23",
#                             "url": "https://chiaki.vn/vien-uong-bo-sung-vitamin-b-tong-hop-blackmores-mega-b-complex-cua-uc-200-vien-me-soc"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "24",
#                             "url": "https://chiaki.vn/vien-uong-bo-sung-magie-nature-made-magnesium-250-mg-hop-100vien-cua-my"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "25",
#                             "url": "https://chiaki.vn/vien-uong-vitamin-tong-hop-dhc-multi-vitamins-nhat-ban-60-ngay"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "26",
#                             "url": "https://chiaki.vn/kirkland-calcium-600-mg-d3-500-vien-canxi-hong-date-1-2028"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "27",
#                             "url": "https://chiaki.vn/hang-air-du-bill-vien-uong-bo-sung-magie-nature-made-magnesium-citrate-250-mg-180-vien"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "28",
#                             "url": "https://chiaki.vn/vien-uong-ho-tro-bo-sung-canxi-chela-calcium-d3"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "29",
#                             "url": "https://chiaki.vn/vien-uong-bo-sung-magie-glycinate-240-mg-nature-s-bounty-180-vien-ho-tro-suc-khoe-tim-mach-va-giac-ngu-sau"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "30",
#                             "url": "https://chiaki.vn/vitamin-e-500-vien-kirkland-cua-my-dep-da-chong-lao-hoa"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "31",
#                             "url": "https://chiaki.vn/vien-uong-dhc-bo-sung-32-loai-rau-cu-240-vien"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "32",
#                             "url": "https://chiaki.vn/vien-uong-bo-sung-magie-glycinate-hap-thu-cao-nature-s-bounty-240-mg-180-vien-nang"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "33",
#                             "url": "https://chiaki.vn/vien-uong-tang-can-trung-thao-sam-nhung-bo-ty-khai-vi-dai-bo-hoan-nhap-khau-malaysia-giup-an-ngon-mieng-ngu-ngon-ma-1407-657864"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "34",
#                             "url": "https://chiaki.vn/bot-diep-luc-unicity-super-chlorophyll-power-92g-tu-my"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "35",
#                             "url": "https://chiaki.vn/chinh-hang-vien-uong-vitamin-tong-hop-one-a-day-men-s-300v-cua-my"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "36",
#                             "url": "https://chiaki.vn/hang-nhap-khau-vien-canxi-huu-co-nano-nz-ultra-cal"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "37",
#                             "url": "https://chiaki.vn/vien-uong-tang-thu-thai-conceptive-pregnacare-him-and-her-bo-trung-tinh-trung-cua-anh-60-vien"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "38",
#                             "url": "https://chiaki.vn/vien-uong-bo-sung-magie-now-magnesium-glycinate-voi-bioperine-180-vien-nang-thuc-vat-ho-tro-suc-khoe-he-than-kinh-giam-cang-thang"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "39",
#                             "url": "https://chiaki.vn/vien-uong-vitamin-tong-hop-centrum-for-men-90-tablets"
#                         },
#                         {
#                             "@type":"ListItem",
#                             "position": "40",
#                             "url": "https://chiaki.vn/vitamin-tong-hop-cho-nam-one-a-day-men-s-heath-formul"
#                         } ] } </script> <div class="clearfix"></div> <div class="product-list promotion-for-watch"> <div class="site-bar-left"> <div class="sidebar-item cat-information"> <div class="category-title"> <span>Danh mục sản phẩm</span> </div> <div class="sidebar-left-content"> <div class="cat-link title-option-manufactureers"> <span class="filter-watch-category filter-option" data-url="magnesium" onclick="handleFilter(this)" title="Magnesium"> Magnesium <small>(51)</small> </span> </div> <div class="cat-link title-option-manufactureers"> <span class="filter-watch-category filter-option" data-url="canxi" onclick="handleFilter(this)" title="Canxi"> Canxi <small>(70)</small> </span> </div> <div class="cat-link title-option-manufactureers"> <span class="filter-watch-category filter-option" data-url="kem" onclick="handleFilter(this)" title="Kẽm"> Kẽm <small>(56)</small> </span> </div> <div class="cat-link title-option-manufactureers"> <span class="filter-watch-category filter-option" data-url="vitamin-d" onclick="handleFilter(this)" title="Vitamin D"> Vitamin D <small>(27)</small> </span> </div> <div class="cat-link title-option-manufactureers"> <span class="filter-watch-category filter-option" data-url="vitamin-c" onclick="handleFilter(this)" title="Vitamin C"> Vitamin C <small>(64)</small> </span> </div> <div class="cat-link title-option-manufactureers"> <span class="filter-watch-category filter-option" data-url="vitamin-b" onclick="handleFilter(this)" title="Vitamin B"> Vitamin B <small>(42)</small> </span> </div> <div class="cat-link title-option-manufactureers"> <span class="filter-watch-category filter-option" data-url="sat-bo-mau" onclick="handleFilter(this)" title="Sắt Bổ Máu"> Sắt Bổ Máu <small>(53)</small> </span> </div> <div class="cat-link title-option-manufactureers"> <span class="filter-watch-category filter-option" data-url="vitamin-e" onclick="handleFilter(this)" title="Vitamin E"> Vitamin E <small>(41)</small> </span> </div> <div class="cat-link title-option-manufactureers"> <span class="filter-watch-category filter-option" data-url="vitamin-a" onclick="handleFilter(this)" title="Vitamin A"> Vitamin A <small>(5)</small> </span> </div> </div> </div> <div id="js-async-load-manufacture-filter"> <div class="async-loading-wrapper"> <div class="async-loading-header">Thương hiệu</div> <div class="async-loading-item"> <span class="async-loading-name async-loading-action" style="width: 83%"></span> </div> <div class="async-loading-item"> <span class="async-loading-name async-loading-action" style="width: 47%"></span> </div> <div class="async-loading-item"> <span class="async-loading-name async-loading-action" style="width: 75%"></span> </div> <div class="async-loading-item"> <span class="async-loading-name async-loading-action" style="width: 41%"></span> </div> <div class="async-loading-item"> <span class="async-loading-name async-loading-action" style="width: 90%"></span> </div> <div class="async-loading-item"> <span class="async-loading-name async-loading-action" style="width: 75%"></span> </div> <div class="async-loading-item"> <span class="async-loading-name async-loading-action" style="width: 94%"></span> </div> <div class="async-loading-item"> <span class="async-loading-name async-loading-action" style="width: 66%"></span> </div> <div class="async-loading-item"> <span class="async-loading-name async-loading-action" style="width: 67%"></span> </div> </div> </div> <div id="js-async-load-product-origin-filter"> <div class="async-loading-wrapper"> <div class="async-loading-header">Xuất xứ</div> <div class="async-loading-item"> <span class="async-loading-name async-loading-action" style="width: 66%"></span> </div> <div class="async-loading-item"> <span class="async-loading-name async-loading-action" style="width: 35%"></span> </div> <div class="async-loading-item"> <span class="async-loading-name async-loading-action" style="width: 79%"></span> </div> <div class="async-loading-item"> <span class="async-loading-n ...
# <h2 style="line-height: 1.38; margin-top: 18pt; margin-bottom: 6pt; text-align: justify;"><span style="color: #000000;"><strong><span style="font-size: 14pt; font-family: Arial; background-color: transparent; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre-wrap;">Vai trò của Vitamin tổng hợp đối với sức khỏe con người</span></strong></span></h2>
# <p style="line-height: 1.38; margin-top: 0pt; margin-bottom: 0pt; text-align: justify;"><span style="font-size: 12pt; font-family: Arial; color: #000000; background-color: transparent; font-weight: 400; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre-wrap;"><strong>Vitamin</strong> được biết đến là một hợp chất hữu cơ mà cơ thể không tự tổng hợp, do đó mà con người cần lấy từ bên ngoài thông qua các thực phẩm và khẩu phần ăn hàng ngày. Trong mỗi thực phẩm được nạp vào cơ thể có chứa một lượng nhỏ vitamin, tuy ít nhưng chúng đóng vai trò quan trọng trong việc duy trì sự sống cũng như hoạt động tích cực của cơ thể mỗi ngày. </span></p>
# <p style="line-height: 1.38; margin-top: 0pt; margin-bottom: 0pt; text-align: justify;"><span style="font-size: 12pt; font-family: Arial; color: #000000; background-color: transparent; font-weight: 400; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre-wrap;">Trong đó, mỗi nguồn vitamin sẽ chứa các vai trò khác nhau, từ đó nhiều vitamin tổng hợp lại sẽ hỗ trợ cơ thể khỏe mạnh, phát triển và thông minh. Cụ thể như:</span></p>
# <ul style="margin-top: 0px; margin-bottom: 0px; text-align: justify;">
# <li style="list-style-type: disc; font-size: 12pt; font-family: Arial; color: #000000; background-color: transparent; font-weight: 400; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre;"><span style="font-size: 12pt; font-family: Arial; color: #000000; background-color: transparent; font-weight: 400; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre-wrap;"><strong>Vitamin B:</strong> Hỗ trợ kích thích thèm ăn, hỗ trợ giúp da và tóc trở nên bóng mượt hơn, phát triển hệ thần kinh </span></li>
# <li style="list-style-type: disc; font-size: 12pt; font-family: Arial; color: #000000; background-color: transparent; font-weight: 400; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre;"><span style="font-size: 12pt; font-family: Arial; color: #000000; background-color: transparent; font-weight: 400; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre-wrap;"><strong>Vitamin A:</strong> Hỗ trợ làm sáng mắt, đồng thời bảo vệ cơ thể khỏi những tác động từ môi trường bên ngoài cũng như cải thiện các vấn đề về tuổi tác</span></li>
# <li style="list-style-type: disc; font-size: 12pt; font-family: Arial; color: #000000; background-color: transparent; font-weight: 400; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre;"><span style="font-size: 12pt; font-family: Arial; color: #000000; background-color: transparent; font-weight: 400; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre-wrap;"><strong>Vitamin C:</strong> Mang đến nhiều tích cực cho da liễu, hỗ trợ tăng sức bền cho thành mạch, hỗ trợ các vấn đề về tuổi tác</span></li>
# <li style="list-style-type: disc; font-size: 12pt; font-family: Arial; color: #000000; background-color: transparent; font-weight: 400; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre;"><span style="font-size: 12pt; font-family: Arial; color: #000000; background-color: transparent; font-weight: 400; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre-wrap;"><strong>Vitamin D:</strong> Hỗ trợ cơ thể trong sự phát triển xương, những ai thiếu vitamin D sẽ gặp các vấn đề về còi xương, xương sống cong, chậm mọc răng, … so với người bình thường</span></li>
# <li style="list-style-type: disc; font-size: 12pt; font-family: Arial; color: #000000; background-color: transparent; font-weight: 400; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre;"><span style="font-size: 12pt; font-family: Arial; color: #000000; background-color: transparent; font-weight: 400; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre-wrap;"><strong>Vitamin E:</strong> Hỗ trợ các vấn đề liên quan đến da và tế bào máu</span></li>
# <li style="list-style-type: disc; font-size: 12pt; font-family: Arial; color: #000000; background-color: transparent; font-weight: 400; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre;"><span style="font-size: 12pt; font-family: Arial; color: #000000; background-color: transparent; font-weight: 400; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre-wrap;"><strong>Vitamin K:</strong> Hỗ trợ những yếu tố liên quan đến sự đông máu. Người thiếu vitamin K thường gặp các vấn đề về khó đông máu, các vết thương có thể chảy máu liên tục</span></li>
# </ul>
# <p style="line-height: 1.38; margin-top: 0pt; margin-bottom: 0pt; text-align: justify;"><span style="font-size: 12pt; font-family: Arial; color: #000000; background-color: transparent; font-weight: 400; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre-wrap;">Có thể thấy, Vitamin rất quan trọng đối với cơ thể do đó bạn cần bổ sung Vitamin cần thiết và khoa học, không nên để thừa hoặc thiếu vitamin quá nhiều. </span></p>
# <h2 style="line-height: 1.38; margin-top: 18pt; margin-bottom: 6pt; text-align: justify;"><span style="color: #000000;"><strong><span style="font-size: 14pt; font-family: Arial; background-color: transparent; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre-wrap;">Vai trò của khoáng chất đối với sức khỏe con người</span></strong></span></h2>
# <p style="line-height: 1.38; margin-top: 0pt; margin-bottom: 0pt; text-align: justify;"><span style="font-size: 12pt; font-family: Arial; color: #000000; background-color: transparent; font-weight: 400; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre-wrap;">Đối với sức khỏe con người thì <strong>khoáng chất</strong> cũng đóng vai trò rất quan trọng không kém gì <strong>vitamin</strong>. Trong đó, khoáng chất cũng đóng vai trò trong việc tham gia và cấu tạo tế bào, tham gia vào các hoạt động sống của cơ thể, đồng thời cân bằng các chất lỏng, duy trì sự phát triển của răng và xương, hệ thống dây thần kinh. </span></p>
# <p style="line-height: 1.38; margin-top: 0pt; margin-bottom: 0pt; text-align: justify;"><span style="font-size: 12pt; font-family: Arial; color: #000000; background-color: transparent; font-weight: 400; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre-wrap;">Không khác vitamin là mấy, cơ thể cũng cần phải tự nạp khoáng chất từ bên ngoài bởi cơ thể không tự sản sinh. Theo đó, khoáng chất được cung cấp vào thông qua đường ăn uống khoa học, đảm bảo sức khỏe cho cơ thể. Đặc biệt, mỗi khoáng chất sẽ đóng vai trò khác nhau làm nên một cơ thể khỏe mạnh, cụ thể như:</span></p>
# <ul style="margin-top: 0px; margin-bottom: 0px; text-align: justify;">
# <li style="list-style-type: disc; font-size: 12pt; font-family: Arial; color: #000000; background-color: transparent; font-weight: 400; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre;"><span style="font-size: 12pt; font-family: Arial; color: #000000; background-color: transparent; font-weight: 400; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre-wrap;"><strong>Magie:</strong> Cần thiết cho hệ tiêu hóa, đặc biệt là các cơ co thắt và xung thần kinh. Magie cũng hỗ trợ kiểm soát lượng đường trong máu nhằm điều hòa huyết áp và duy trì sức khỏe cho xương</span></li>
# <li style="list-style-type: disc; font-size: 12pt; font-family: Arial; color: #000000; background-color: transparent; font-weight: 400; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre;"><span style="font-size: 12pt; font-family: Arial; color: #000000; background-color: transparent; font-weight: 400; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre-wrap;"><strong>Selen:</strong> Thành phần có sự tác động đến phát triển của bạch cầu, thiếu hụt chất này con người sẽ gặp vấn đề về suy giảm chức năng bạch cầu, rối loạn chuyển hóa trong hệ tiêu hóa</span></li>
# <li style="list-style-type: disc; font-size: 12pt; font-family: Arial; color: #000000; background-color: transparent; font-weight: 400; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre;"><span style="font-size: 12pt; font-family: Arial; color: #000000; background-color: transparent; font-weight: 400; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre-wrap;"><strong>Sắt:</strong> Cần thiết trong quá trình tạo nên tế bào máu, người thiếu sắt thường hay rụng tóc, đau đầu, chóng mặt.</span></li>
# <li style="list-style-type: disc; font-size: 12pt; font-family: Arial; color: #000000; background-color: transparent; font-weight: 400; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre;"><span style="font-size: 12pt; font-family: Arial; color: #000000; background-color: transparent; font-weight: 400; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre-wrap;"><strong>Kẽm:</strong> Hỗ trợ kích thích các hoạt động của Enzyme, hỗ trợ miễn dịch, hỗ trợ bảo vệ vị giác/ khứu giác và hỗ trợ sự tổng hợp DNA</span></li>
# <li style="list-style-type: disc; font-size: 12pt; font-family: Arial; color: #000000; background-color: transparent; font-weight: 400; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre;"><span style="font-size: 12pt; font-family: Arial; color: #000000; background-color: transparent; font-weight: 400; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre-wrap;"><strong>Clorua:</strong> Đây là khoáng chất đóng vai trò là một phần của dịch dạ dày, chúng hỗ trợ cân bằng hệ chất lỏng trong cơ thể</span></li>
# <li style="list-style-type: disc; font-size: 12pt; font-family: Arial; color: #000000; background-color: transparent; font-weight: 400; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre;"><span style="font-size: 12pt; font-family: Arial; color: #000000; background-color: transparent; font-weight: 400; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre-wrap;"><strong>Kali:</strong> Đây là thành phần cần thiết cho hệ thần kinh trung ương, tham gia vào việc hỗ trợ cân bằng chất lỏng cơ thể, nếu thiếu Kali bạn sẽ gặp vấn đề về rối loạn nhịp tim. </span></li>
# <li style="list-style-type: disc; font-size: 12pt; font-family: Arial; color: #000000; background-color: transparent; font-weight: 400; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre;"><span style="font-size: 12pt; font-family: Arial; color: #000000; background-color: transparent; font-weight: 400; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre-wrap;"><strong>Natri:</strong> Đây là thành phần cần kết hợp với Clorua để hỗ trợ cân bằng dịch ngoại bào, mang đến khả năng điều chỉnh huyết áp. </span></li>
# </ul>
# <h2 style="line-height: 1.38; margin-top: 18pt; margin-bottom: 6pt; text-align: justify;"><span style="color: #000000;"><strong><span style="font-size: 14pt; font-family: Arial; background-color: transparent; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre-wrap;">Khi nào cần bổ sung vitamin và khoáng chất cho cơ thể</span></strong></span></h2>
# <ul style="margin-top: 0px; margin-bottom: 0px; text-align: justify;">
# ...
#         font-size: 16px;
#         font-weight: 600;
#         transition: opacity 1s ease-in;
#         border: none;
#         color: #225b63;
#     }
#
#     .btn.btn-submit:hover {
#         background-color: #a2e7f8da;
#     }
#
#     .rating-describe {
#         margin-top: 4px;
#         padding: 0 12px;
#     }
#
#     .rating-describe textarea {
#         width: 100%;
#         padding: 8px;
#         border: 1px solid #00000066;
#         border-radius: 6px;
#         resize: vertical;
#         overflow-x: hidden;
#     }
#
#     .rating-describe textarea::placeholder {
#         color: #00000066;
#         font-size: 14px;
#     }
#     .feedback-area-error {
#         border: 2px solid #ff0000 !important;
#     }
#     .has-error {
#         color: red;
#     }
#
#     @keyframes  popupFade {
#         0% {
#             opacity: 0;
#             transform: translate(50%, -48%) scale(.92);
#             filter: blur(2px);
#         }
#
#         100% {
#             opacity: 1;
#             transform: translate(50%, -50%) scale(1);
#             filter: blur(0);
#         }
#     }
#
#     @keyframes  showFeedbackBox {
#         0% {
#             opacity: 0;
#             max-height: 0;
#         }
#         99% {
#             opacity: 1;
#             max-height: 160px;
#         }
#         100% {
#             max-height: 100%;
#         }
#     }
#
#     @keyframes  fadeOverlay {
#         0% {
#             opacity: 0;
#         }
#
#         100% {
#             opacity: 1;
#         }
#     }
#
#     .rating-success {
#         color: green;
#     }
# </style>
# <script type="text/javascript">
#     var userIdFeedBack = '';
#     var deviceFeedBack = 'desktop';
# </script>
# <div class="rating-component" ng-class="{ 'hidden': !isFeedbackOpen }" ng-cloak="" ng-controller="FeedbackController">
# <div class="rating-overlay" ng-click="hideFeedbackPopup()"></div>
# <div class="rating-box-wrapper">
# <div class="rating-box">
# <span class="rating-close">
# <button class="chat-close-btn" ng-click="hideFeedbackPopup()">
# <svg fill="none" height="20" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" viewbox="0 0 24 24" width="20" xmlns="http://www.w3.org/2000/svg">
# <path d="M0 0h24v24H0z" fill="none" stroke="none"></path>
# <path d="M18 6l-12 12"></path>
# <path d="M6 6l12 12"></path>
# </svg>
# </button>
# </span>
# <div class="rating-logo">
# <img alt="Chiaki.vn" height="24" src="https://chiaki.vn/images/logo.png?v=20250219103413" width="146"/>
# </div>
# <div class="rating-wrapper">
# <div class="rating-header">
#                     Bạn có hài lòng khi trải nghiệm dịch vụ của Chiaki không ạ?
#                 </div>
# <div class="rating-options">
# <label class="rating-item" for="very-bad">
# <input id="very-bad" name="rate" ng-click="clickRating('very_bad')" ng-model="selectedRating" type="radio" value="very-bad"/>
# <span></span>
# <div class="rating-item-title">Rất tệ</div>
# </label>
# <label class="rating-item" for="bad">
# <input id="bad" name="rate" ng-click="clickRating('bad')" ng-model="selectedRating" type="radio" value="bad"/>
# <span></span>
# <div class="rating-item-title">Tệ</div>
# </label>
# <label class="rating-item" for="normal">
# <input id="normal" name="rate" ng-click="clickRating('normal')" ng-model="selectedRating" type="radio" value="normal"/>
# <span></span>
# <div class="rating-item-title">Ổn</div>
# </label>
# <label class="rating-item" for="good">
# <input id="good" name="rate" ng-click="clickRating('good')" ng-model="selectedRating" type="radio" value="good"/>
# <span></span>
# <div class="rating-item-title">Tốt</div>
# </label>
# <label class="rating-item" for="very-good">
# <input id="very-good" name="rate" ng-click="clickRating('very_good')" ng-model="selectedRating" type="radio" value="very-good"/>
# <span></span>
# <div class="rating-item-title">Rất tốt</div>
# </label>
# </div>
# <div class="has-error" id="feedback-error" ng-if="failMessage">
#                     {{ failMessage }}
#                 </div>
# <div class="feedback-box" ng-show="currentTab">
# <!-- Feedback title cho rating xấu -->
# <div class="feedback-title" ng-if="currentTab !== 'good' &amp;&amp; currentTab !== 'very_good'">
#                         Rất tiếc khi nghe điều đó! Vấn đề bạn gặp phải là gì?
#                     </div>
# <!-- Checkbox chỉ hiện với rating xấu -->
# <div class="feedback-tags" ng-class="{ 'has-border': feedbackTags | filter:{checked:true}:true }" ng-if="currentTab !== 'good' &amp;&amp; currentTab !== 'very_good'">
# <label class="feedback-tag" ng-repeat="tag in feedbackTagsObj[currentTab]">
# <input ng-change="toggleTag(tag)" ng-model="tag.checked" type="checkbox"/>
# <span ng-if="tag.label">{{ tag . label }}</span>
# </label>
# </div>
# <!-- Textarea mapping -->
# <div class="feedback-description" id="tag-item-{{$index}}" ng-repeat="tag in selectedTagsObj[currentTab]">
# <div class="feedback-description-title" ng-show="tag.label">
#                             {{ tag . label }}
#                         </div>
# <div class="feedback-tags" ng-class="{ 'has-border': feedbackTags | filter:{checked:true}:true }" ng-if="tag.specialProblems &amp;&amp; currentTab !== 'good' &amp;&amp; currentTab !== 'very_good'">
# <label class="feedback-tag" ng-repeat="tagChild in tag.specialProblems track by $index">
# <input ng-model="tagChild.checked" type="checkbox"/>
# <span>{{ tagChild . label }}</span>
# </label>
# </div>
# <div class="feedback-description-sub-title" ng-show="currentTab !== 'good' &amp;&amp; currentTab !== 'very_good'">
#                             Bạn có thể mô tả chi tiết hơn không?
#                         </div>
# <div class="feedback-description-sub-title has-error" ng-show="tag.error">
#                             Vui lòng chọn ít nhất 1 trải nghiệm bên trên
#                         </div>
# <textarea ng-class="{ 'feedback-area-error': tag.error }" ng-model="tag.message" placeholder="Hãy chia sẻ thêm với chúng tôi" rows="4"></textarea>
# </div>
# </div>
# <div class="rating-success" id="success-alert">
#                     {{ successMessage }}
#                 </div>
# </div>
# <div class="btn btn-submit" ng-click="submitFeedback()" ng-disabled="isSaving">
# <span>Hoàn thành</span>
# </div>
# </div>
# </div>
# </div>
# <style> .rating-success-wrapper { position: fixed; inset: 0; z-index: 2147483648; /* cao hơn modal đánh giá */ } .rating-success-overlay { position: fixed; inset: 0; background: rgba(0, 0, 0, 0.35); } .rating-success-box { position: fixed; top: 50%; left: 50%; transform: translate(-50%, -50%); background: #fff; width: 500px; max-width: calc(100% - 32px); border-radius: 14px; padding: 24px 20px; text-align: center; box-shadow: 0 12px 40px rgba(0, 0, 0, .25); } .rating-success-icon { font-size: 44px; margin: 12px auto; } .rating-success-icon svg { width: 90px; height: 90px; border: 5px solid var(--primary); border-radius: 50%; fill: var(--primary); } .rating-success-box-title { font-size: 16px; font-weight: 600; margin: 16px auto; } .rating-success-box-description { font-size: 14px; color: #666; margin: 16px auto; } .rating-success-box .btn-submit { width: 80%; align-items: center; border-radius: 24px; margin: 12px auto; outline: none; } </style> <div class="rating-success-wrapper" ng-cloak="" ng-controller="FeedbackController" ng-show="isSuccessOpen"> <div class="rating-success-overlay"></div> <div class="rating-success-box"> <div class="rating-success-icon"> <svg viewbox="0 0 640 640" xmlns="http://www.w3.org/2000/svg"> <path d="M530.8 134.1C545.1 144.5 548.3 164.5 537.9 178.8L281.9 530.8C276.4 538.4 267.9 543.1 258.5 543.9C249.1 544.7 240 541.2 233.4 534.6L105.4 406.6C92.9 394.1 92.9 373.8 105.4 361.3C117.9 348.8 138.2 348.8 150.7 361.3L252.2 462.8L486.2 141.1C496.6 126.8 516.6 123.6 530.9 134z"></path> </svg> </div> <div class="rating-success-box-title"> Cảm ơn bạn đã gửi phản hồi! </div> <div class="rating-success-box-description"> Cảm ơn bạn đã dành thời gian gửi phản hồi. Chúng tôi rất trân trọng sự đóng góp của bạn và sẽ sử dụng những ý kiến này để cải thiện website của mình. </div> <button class="btn btn-submit" ng-click="closeSuccessPopup()"> Xác nhận </button> </div> </div><script>
#
#      $(".slider-on-page").slick({
#             infinite: false,
#             dots: !1, speed: 300, slidesToShow: 5, slidesToScroll: 5, responsive: [
#                   {
#                           breakpoint: 1500, settings: {
#                               slidesToShow: 5, slidesToScroll: 5, infinite: !0, dots: !1
#                           }
#                       }
#                       ,
#               {
#                     breakpoint: 1280, settings: {
#                         slidesToShow: 4, slidesToScroll: 4, infinite: !0, dots: !1
#                     }
#                 }
#                 , {
#                     breakpoint: 1024, settings: {
#                         slidesToShow: 3, slidesToScroll: 3, infinite: !0, dots: !1
#                     }
#                 }
#                 , {
#                     breakpoint: 640, settings: {
#                         slidesToShow: 2, slidesToScroll: 2
#                     }
#                 }
#                 , {
#                     breakpoint: 480, settings: {
#                         slidesToShow: 2, slidesToScroll: 2
#                     }
#                 }
#                 , {
#                     breakpoint: 400, settings: {
#                         slidesToShow: 1, slidesToScroll: 1
#                     }
#                 }
#             ]
#         }
#         );
#
#
# </script>
# <script type="text/javascript">
#
# $('.js-open-seller-layout').click(function() {
#     $('body').addClass('open-seller-wrapper')
# })
#
# $('#hotsearch').slick({
#     dots: false,
#     infinite: false,
#     speed: 300,
#     slidesToShow: 6,
#     slidesToScroll: 6,
#     variableWidth: true
# });
#
# $('.other-seller-background, .close-seller-layout').click(function() {
#     $('body').removeClass('open-seller-wrapper')
# })
# </script>
# <script type="text/javascript">
#     var messageLoginFailed = ''; var messageLoginSuccess = ''; var messageRecoverFailed = ''; var messageRecoverSuccess = ''; var resendOrderUrl = 'https://chiaki.vn/send-sms'; </script> <script>
#     var tagParams = 'facebook_pixel_params' in window ? facebook_pixel_params : {};
#     var tagParamPageType = 'pageType' in window ? pageType : '';
#     if (pageType !== 'purchase') {
#         if (!facebook_pixel_params.content_ids) {
#             facebook_pixel_params.content_ids = google_tag_params.dynx_itemid;
#         }
#         if (!facebook_pixel_params.contents) {
#             // facebook_pixel_params.contents = google_tag_params.items;
#         }
#         if (!facebook_pixel_params.currency) {
#             facebook_pixel_params.currency = 'VND';
#         }
#         if (facebook_pixel_params.content_ids) {
#             facebook_pixel_params.num_items = facebook_pixel_params.content_ids.length;
#         }
#         if (tagParamPageType === 'add_to_cart') {
#             var cartItems = []; facebook_pixel_params.contents = cartItems; tagParamPageType = 'begin_checkout'; if (facebook_pixel_params.value) { delete facebook_pixel_params.value; } window.dataLayer.push(facebook_pixel_params); window.dataLayer.push({event: 'add_payment_info'}); } window.dataLayer.push(facebook_pixel_params); window.dataLayer.push({event: tagParamPageType}); $(document).ready(function () { $('.btn-add-to-cart').click(function() { facebook_pixel_params.contents[0].quantity = $('.js-buying-number').val(); window.dataLayer.push(facebook_pixel_params); window.dataLayer.push({event: "add_to_cart"}); }); $('.btn-buy-now').click(function(e) { e.preventDefault(); facebook_pixel_params.contents[0].quantity = $('.js-buying-number').val(); window.dataLayer.push(facebook_pixel_params); window.dataLayer.push({event: "add_to_cart"}); }); }); } </script><script onerror="onJsError(this)" src="https://chiaki.vn/frontend/js/footer.js?v=20260504141443"></script>
# <script src="https://images.dmca.com/Badges/DMCABadgeHelper.min.js"></script><script onerror="onJsError(this)" src="https://chiaki.vn/frontend/js/show-promotion-code.js?v=20260504141443"></script>
# <script onerror="onJsError(this)" src="https://chiaki.vn/frontend/js/show-warning.js?v=20260504141443"></script>
# <script onerror="onJsError(this)" src="https://chiaki.vn/frontend/js/controller/feedback.js?v=20260504141443"></script>
# <link href="https://chiaki.vn/build/css/desktop/chiaki.frontend-lib.min.css?v=20260504141443" media="all" onerror="onCssError(this)" rel="stylesheet" type="text/css"/>
# <link href="https://chiaki.vn/build/css/desktop/chiaki-frontend-not-critical.min.css?v=20260504141443" media="all" onerror="onCssError(this)" rel="stylesheet" type="text/css"/>
# <link href="/styles/search-trend.css?v=20260504141443" rel="stylesheet"/> <link href="/styles/add2basket.css?v=20260504141443" rel="stylesheet"/> <link href="/frontend/css/c-icons.css?v=20260504141443" rel="stylesheet"/> <link href="https://chiaki.vn/frontend/css/bootstrap.min.css?v=20260504141443" media="all" onerror="onCssError(this)" rel="stylesheet" type="text/css"/>
# <link href="https://chiaki.vn/frontend/css/featherlight.min.css?v=20260504141443" media="all" onerror="onCssError(this)" rel="stylesheet" type="text/css"/>
# <script onerror="onJsError(this)" src="https://chiaki.vn/build/js/desktop/chiaki-desktop-lib.min.js?v=20260504141443"></script>
# <script defer="true" onerror="onJsError(this)" src="https://chiaki.vn/build/js/desktop/chiaki.frontend.min.js?v=20260504141443"></script>
# <script defer="true" onerror="onJsError(this)" src="https://chiaki.vn/build/js/desktop/chiaki-desktop-defer.min.js?v=20260504141443"></script>
# <input id="idOrderSourceAdword" name="idOrderSourceAdword" type="hidden" value="-1"/> <input id="js-user-agent-os" name="userAgentOs" type="hidden" value="Mac"> <script async="" src="//affiliate.chiaki.vn/js/script/trackingJs.min.js?v=20260504141443"></script> <script>
#   window.___gcfg = {
#     lang: 'vi'
#   };
# </script>
# <script async="" defer="" src="https://apis.google.com/js/platform.js?onload=renderBadge"></script>
# <script>
#   window.renderBadge = function() {
#     var ratingBadgeContainer = document.createElement("div");
#     document.body.appendChild(ratingBadgeContainer);
#     window.gapi.load('ratingbadge', function() {
#       window.gapi.ratingbadge.render(ratingBadgeContainer, {"merchant_id": 122681438,"position": "BOTTOM_LEFT"}); }); } </script> <script onerror="onJsError(this)" src="https://chiaki.vn/frontend/js/lazyload.min.js"></script>
# <script onerror="onJsError(this)" src="https://chiaki.vn/frontend/js/get-cart-info-and-handle-lazyload.js?v=20260504141443"></script>
# <script onerror="onJsError(this)" src="https://chiaki.vn/frontend/js/product/customer-event.js?v=20260504141443"></script>
# <script defer="true" onerror="onJsError(this)" src="https://chiaki.vn/frontend/js/section-conversion-tracker.js?v=20260504141443"></script>
# <script onerror="onJsError(this)" src="https://chiaki.vn/frontend/js/toast.js?v=20260504141443"></script>
# <script>
#         const version = 20260504141443; window.addEventListener('load', function() { const script = document.createElement('script'); script.src = chatUrl + '/public/integration.js?v=' + version + '&site=Chiaki'; script.defer = true; script.async = true; const timeout = setTimeout(() => { console.warn('Chat CRM server quá chậm, bỏ qua load.'); script.src = ''; }, 3000); script.onload = () => clearTimeout(timeout); script.onerror = () => console.warn('Chat CRM load thất bại.'); document.body.appendChild(script); }); </script> <script defer="1" onerror="onJsError(this)" src="https://chiaki.vn/frontend/js/user/check-login.js?v=20260504141443"></script>
# <script>
#         var affiliateCId = localStorage.getItem('affiliateCId');
#         var sellerDomain = "https://seller.chiaki.vn"; if (affiliateCId > 0) { var selectorHref = 'a[href^="' + sellerDomain + '"]'; document.querySelectorAll(selectorHref).forEach(a => { try { const url = new URL(a.href); const allowed = [ sellerDomain, sellerDomain + '/login', sellerDomain + '/register' ]; const baseUrl = url.origin + url.pathname.replace(/\/$/, ''); if (allowed.includes(baseUrl)) { url.searchParams.set('ma_gioi_thieu', affiliateCId); a.href = url.toString(); } } catch (e) { } }); } </script>
# </input></body> </html>

# %%
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Collecting beautifulsoup4 (from bs4)
#   Downloading beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4->bs4)
#   Downloading soupsieve-2.8.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in /mnt/phongdq/miniconda3/envs/antidistill/lib/python3.10/site-packages (from beautifulsoup4->bs4) (4.15.0)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Downloading beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Downloading soupsieve-2.8.3-py3-none-any.whl (37 kB)
# Installing collected packages: soupsieve, beautifulsoup4, bs4
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [bs4]
# Successfully installed beautifulsoup4-4.14.3 bs4-0.0.2 soupsieve-2.8.3
