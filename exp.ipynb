# %%
from datasets import load_dataset


ace_gen = load_dataset("datht/ace-short-generated-dataset")

# %%
# ace = load_dataset("datht/ace-event-dataset")

# %%
system_prompt = """You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.
IMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.
Output Format (JSON only, no markdown):

{
  "events": [
    [<trigger span>, <event type>, [[<argument span>, <semantic role>], [<argument span 2>, <semantic role 2>]], <description>],
    [<trigger span 2>, <event type 2>, [], <description 2>]
  ]
}

- If no events are detected, return: {"events": []}"""

user_prompt = """Given an input text: {input}

Your task is to extract all events present in the text. The text may contain zero, one, or multiple events.

For each event:
- Identify event type
- Identify a trigger: the word or phrase that most clearly indicates the event.
- Extract all relevant arguments participating in the event.
- Each argument must be an exact span from the text and assigned a semantic role.
- Description: explaining what this event type means

Constraints and Guidelines
- Do not invent information not supported by the text.
- Do not paraphrase triggers or arguments.
- The "text" field must exactly match a span in the original input.
"""

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained('Qwen/Qwen3-4B', padding_side="right")

# %%
tokenizer.eos_token_id = 151645
# Out:
# 151645

# %%
tokenizer.bos_token

# %%
tokenizer.apply_chat_template(
                [{"role": "system", "content": "sample['system_prompt']"},
                {"role": "user", "content": "sample['user_prompt']"}],
                add_generation_prompt=True,
                tokenize=False 
            )
# Out:
# "<|im_start|>system\nsample['system_prompt']<|im_end|>\n<|im_start|>user\nsample['user_prompt']<|im_end|>\n<|im_start|>assistant\n"

# %%
tokenizer
# Out:
# Qwen2TokenizerFast(name_or_path='Qwen/Qwen2.5-0.5B', vocab_size=151643, model_max_length=131072, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'eos_token': '<|endoftext|>', 'pad_token': '<|endoftext|>', 'additional_special_tokens': ['<|im_start|>', '<|im_end|>', '<|object_ref_start|>', '<|object_ref_end|>', '<|box_start|>', '<|box_end|>', '<|quad_start|>', '<|quad_end|>', '<|vision_start|>', '<|vision_end|>', '<|vision_pad|>', '<|image_pad|>', '<|video_pad|>']}, clean_up_tokenization_spaces=False, added_tokens_decoder={
# 	151643: AddedToken("<|endoftext|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151644: AddedToken("<|im_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151645: AddedToken("<|im_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151646: AddedToken("<|object_ref_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151647: AddedToken("<|object_ref_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151648: AddedToken("<|box_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151649: AddedToken("<|box_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151650: AddedToken("<|quad_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151651: AddedToken("<|quad_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151652: AddedToken("<|vision_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151653: AddedToken("<|vision_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151654: AddedToken("<|vision_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151655: AddedToken("<|image_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151656: AddedToken("<|video_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151657: AddedToken("<tool_call>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151658: AddedToken("</tool_call>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151659: AddedToken("<|fim_prefix|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151660: AddedToken("<|fim_middle|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151661: AddedToken("<|fim_suffix|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151662: AddedToken("<|fim_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151663: AddedToken("<|repo_name|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151664: AddedToken("<|file_sep|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# }
# )

# %%
import json
import numpy as np
import random


def process_ace_data(raw_data, is_test=False):
    full_len = []
    sent_total = 0
    data = []
    prompt_len = []
    response_len = []
    none_data = []

    for sample in raw_data:
        sent_id_to_sentence = {i: content['sentence'] for i, content in enumerate(sample["content"])}
        sent_id_set = set(sent_id_to_sentence.keys())
        sent_total += len(sent_id_to_sentence)
        sent_to_existing_events = {}
        for event in sample.get("events", []):
            if event.get("type_id", -1) == -1: continue
            event_type = event.get("type")
            description = event.get("description")
            
            for mention in event.get("mention", []):
                sent_id = mention.get("sent_id")
                             
                if sent_id not in sent_to_existing_events:
                    sent_to_existing_events[sent_id] = []
                args = [{"text": arg["text"], "role": arg["role"]} for arg in mention.get("arguments", [])]
                if description:
                    event_info = {
                        "description": description,
                        "trigger_text": mention.get("trigger_word"),
                        "type": event_type,
                        "arguments": args 
                    }
                else:
                    event_info = {
                        "trigger_text": mention.get("trigger_word"),
                        "type": event_type,
                        "arguments": args 
                    }
                    print("no desc")

                sent_to_existing_events[sent_id].append(event_info)

        for sent_id, events in sent_to_existing_events.items():
            sent_txt = sent_id_to_sentence[sent_id]
            sent_id_set.remove(sent_id)

            response = json.dumps({"events": events})

            data.append({"system_prompt": system_prompt, "user_prompt": user_prompt.format(input=sent_txt), "response": response})

        for sent_id in random.sample(list(sent_id_set), min(len(sent_id_set), 1)):
            sent_txt = sent_id_to_sentence[sent_id]

            response = json.dumps({"events": []})
            
            none_data.append({"system_prompt": system_prompt, "user_prompt": user_prompt.format(input=sent_txt), "response": response})


    if is_test:
        data.extend(none_data)
    else:
        data.extend(random.sample(list(none_data), min(len(none_data), len(data) // 100)))
    for sample in data:
        prompt = tokenizer.apply_chat_template(
                [{"role": "system", "content": sample['system_prompt']},
                {"role": "user", "content": sample['user_prompt']}],
                add_generation_prompt=True,
                tokenize=False 
            )
        full = prompt + sample['response'] + tokenizer.eos_token
        
        prompt_tokens = tokenizer.encode(prompt, add_special_tokens=False)
        full_tokens = tokenizer.encode(full, add_special_tokens=False)
        response_tokens = full_tokens[len(prompt_tokens):]

        full_len.append(len(full_tokens))
        prompt_len.append(len(prompt_tokens))
        response_len.append(len(response_tokens))

    return data, full_len, prompt_len, response_len

# %%
data, full_len, prompt_len, response_len = process_ace_data(ace_gen["train"])

# %%
type_set = set()
for item in data:
    events = json.loads(item['response'])["events"]
    for trigger in events:
        type_set.add(trigger['trigger_text'])

# %%
len (data)
# Out:
# 3167

# %%
len(type_set)
# Out:
# 918

# %%
np.max(response_len)
# Out:
# np.int64(513)

# %%
np.max(prompt_len)
# Out:
# np.int64(480)

# %%
np.median(full_len)
# Out:
# np.float64(359.0)

# %%
np.sum(np.array(prompt_len) > 460)
# Out:
# np.int64(1)

# %%
np.max(full_len)
# Out:
# np.int64(823)

# %%
len(data)
# Out:
# 3167

# %%
np.mean(full_len)
# Out:
# np.float64(415.7120303125987)

# %%
import os

def save(data, data_name): 
    os.makedirs(f"data/{data_name}", exist_ok=True)
    train, _, _, _ = process_ace_data(data["train"])
    with open(f"data/{data_name}/train.jsonl", "w", encoding="utf-8") as f:
        for item in train:
            f.write(json.dumps(item, ensure_ascii=False) + "\n")

    dev, _, prompt_len, _ = process_ace_data(data["validation"], is_test=True)
    with open(f"data/{data_name}/dev.jsonl", "w", encoding="utf-8") as f:
        for item in dev:
            f.write(json.dumps(item, ensure_ascii=False) + "\n")

    test, _, prompt_len, _ = process_ace_data(data["test"], is_test=True)
    with open(f"data/{data_name}/test.jsonl", "w", encoding="utf-8") as f:
        for item in test:
            f.write(json.dumps(item, ensure_ascii=False) + "\n")

    return train, dev, test

# %%
save(ace_gen, "ace")
# Out:
# no desc
# no desc
# no desc
# no desc
# ([{'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{\n  "events": [\n    {\n      "trigger_text": <trigger span>,\n      "type": <event type>,\n      "description": <description>,\n      "arguments": [\n        {"text": <argument span>, "role": <semantic role>},\n        {"text": <argument span 2>, "role": <semantic role 2>}\n      ]\n    },\n    {\n      "trigger_text": <trigger span 2>,\n      "type": <event type 2>,\n      "description": <description 2>,\n      "arguments": []\n    }\n  ]\n}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: Even as the secretary of homeland security was putting his people on high alert last month , a 30-foot Cuban patrol boat with four heavily armed men landed on American shores , utterly undetected by the Coast Guard Secretary Ridge now leads .\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify event type\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Extract all relevant arguments participating in the event.\n- Each argument must be an exact span from the text and assigned a semantic role.\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input.\n',
#    'response': '{"events": [{"description": "An entity moves from one location to another, involving physical transition across a boundary, such as landfall or arrival.", "trigger_text": "landed", "type": "Movement:Transport", "arguments": [{"text": "a 30-foot Cuban patrol boat with four heavily armed men", "role": "Agent"}, {"text": "American shores", "role": "Place"}, {"text": "last month", "role": "Time"}]}]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{\n  "events": [\n    {\n      "trigger_text": <trigger span>,\n      "type": <event type>,\n      "description": <description>,\n      "arguments": [\n        {"text": <argument span>, "role": <semantic role>},\n        {"text": <argument span 2>, "role": <semantic role 2>}\n      ]\n    },\n    {\n      "trigger_text": <trigger span 2>,\n      "type": <event type 2>,\n      "description": <description 2>,\n      "arguments": []\n    }\n  ]\n}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: He lost an election to a dead man .\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify event type\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Extract all relevant arguments participating in the event.\n- Each argument must be an exact span from the text and assigned a semantic role.\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input.\n',
#    'response': '{"events": [{"description": "This event represents a personnel election outcome where one person loses to another in a formal voting process.", "trigger_text": "election", "type": "Personnel:Elect", "arguments": [{"text": "He", "role": "Agent"}, {"text": "a dead man", "role": "Victim"}]}]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{\n  "events": [\n    {\n      "trigger_text": <trigger span>,\n      "type": <event type>,\n      "description": <description>,\n      "arguments": [\n        {"text": <argument span>, "role": <semantic role>},\n        {"text": <argument span 2>, "role": <semantic role 2>}\n      ]\n    },\n    {\n      "trigger_text": <trigger span 2>,\n      "type": <event type 2>,\n      "description": <description 2>,\n      "arguments": []\n    }\n  ]\n}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: NOVAK Paul , as I understand your definition of a political -- of a professional politician based on that is somebody who is elected to public office .\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify event type\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Extract all relevant arguments participating in the event.\n- Each argument must be an exact span from the text and assigned a semantic role.\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input.\n',
#    'response': '{"events": [{"description": "This event signifies the formal selection of an individual to hold a public office through a democratic process.", "trigger_text": "elected", "type": "Personnel:Elect", "arguments": [{"text": "NOVAK Paul", "role": "Agent"}, {"text": "public office", "role": "Place"}]}]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{\n  "events": [\n    {\n      "trigger_text": <trigger span>,\n      "type": <event type>,\n      "description": <description>,\n      "arguments": [\n        {"text": <argument span>, "role": <semantic role>},\n        {"text": <argument span 2>, "role": <semantic role 2>}\n      ]\n    },\n    {\n      "trigger_text": <trigger span 2>,\n      "type": <event type 2>,\n      "description": <description 2>,\n      "arguments": []\n    }\n  ]\n}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: And these bozos let four armed Cubans land on our shores when they \'re trying to make a high terrorist alert .\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify event type\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Extract all relevant arguments participating in the event.\n- Each argument must be an exact span from the text and assigned a semantic role.\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input.\n',
#    'response': '{"events": [{"description": "Refers to the physical movement of individuals from one location to another, such as landing on a shore.", "trigger_text": "land", "type": "Movement:Transport", "arguments": [{"text": "four armed Cubans", "role": "Agent"}, {"text": "our shores", "role": "Place"}]}]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{\n  "events": [\n    {\n      "trigger_text": <trigger span>,\n      "type": <event type>,\n      "description": <description>,\n      "arguments": [\n        {"text": <argument span>, "role": <semantic role>},\n        {"text": <argument span 2>, "role": <semantic role 2>}\n      ]\n    },\n    {\n      "trigger_text": <trigger span 2>,\n      "type": <event type 2>,\n      "description": <description 2>,\n      "arguments": []\n    }\n  ]\n}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: Hire professionals , Mr. President .\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify event type\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Extract all relevant arguments participating in the event.\n- Each argument must be an exact span from the text and assigned a semantic role.\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input.\n',
#    'response': '{"events": [{"description": "This event marks the beginning of a person\'s assignment to a new role or position within an organization or team.", "trigger_text": "Hire", "type": "Personnel:Start-Position", "arguments": [{"text": "professionals", "role": "Agent"}, {"text": "Mr. President", "role": "Beneficiary"}]}]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{\n  "events": [\n    {\n      "trigger_text": <trigger span>,\n      "type": <event type>,\n      "description": <description>,\n      "arguments": [\n        {"text": <argument span>, "role": <semantic role>},\n        {"text": <argument span 2>, "role": <semantic role 2>}\n      ]\n    },\n    {\n      "trigger_text": <trigger span 2>,\n      "type": <event type 2>,\n      "description": <description 2>,\n      "arguments": []\n    }\n  ]\n}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: It \'s OK to put Democratic career politicians at the Pentagon and the Justice Department if they \'re Democrats but not if they \'re Republicans , is that right ?\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify event type\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Extract all relevant arguments participating in the event.\n- Each argument must be an exact span from the text and assigned a semantic role.\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input.\n',
#    'response': '{"events": [{"description": "Assigning individuals to specific government positions within the Pentagon or Justice Department based on political party affiliation.", "trigger_text": "put", "type": "Personnel:Start-Position", "arguments": [{"text": "Democratic career politicians", "role": "Agent"}, {"text": "the Pentagon and the Justice Department", "role": "Place"}]}]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{\n  "events": [\n    {\n      "trigger_text": <trigger span>,\n      "type": <event type>,\n      "description": <description>,\n      "arguments": [\n        {"text": <argument span>, "role": <semantic role>},\n        {"text": <argument span 2>, "role": <semantic role 2>}\n      ]\n    },\n    {\n      "trigger_text": <trigger span 2>,\n      "type": <event type 2>,\n      "description": <description 2>,\n      "arguments": []\n    }\n  ]\n}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: Senator Christopher Dodd of Connecticut made the announcement today that he would not be the 10th candidate for the nomination .\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify event type\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Extract all relevant arguments participating in the event.\n- Each argument must be an exact span from the text and assigned a semantic role.\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input.\n',
#    'response': '{"events": [{"description": "An individual is officially recognized as a candidate for a political nomination process.", "trigger_text": "nomination", "type": "Personnel:Nominate", "arguments": [{"text": "Senator Christopher Dodd of Connecticut", "role": "Agent"}, {"text": "the 10th candidate for the nomination", "role": "Patient"}]}]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{\n  "events": [\n    {\n      "trigger_text": <trigger span>,\n      "type": <event type>,\n      "description": <description>,\n      "arguments": [\n        {"text": <argument span>, "role": <semantic role>},\n        {"text": <argument span 2>, "role": <semantic role 2>}\n      ]\n    },\n    {\n      "trigger_text": <trigger span 2>,\n      "type": <event type 2>,\n      "description": <description 2>,\n      "arguments": []\n    }\n  ]\n}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: He explained he could better spend the next two years on homeland security , the economy and judicial nominations .\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify event type\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Extract all relevant arguments participating in the event.\n- Each argument must be an exact span from the text and assigned a semantic role.\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input.\n',
#    'response': '{"events": [{"description": "This event signifies the process of proposing a person for a judicial position within the government.", "trigger_text": "nominations", "type": "Personnel:Nominate", "arguments": [{"text": "judicial nominations", "role": "Beneficiary"}]}]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{\n  "events": [\n    {\n      "trigger_text": <trigger span>,\n      "type": <event type>,\n      "description": <description>,\n      "arguments": [\n        {"text": <argument span>, "role": <semantic role>},\n        {"text": <argument span 2>, "role": <semantic role 2>}\n      ]\n    },\n    {\n      "trigger_text": <trigger span 2>,\n      "type": <event type 2>,\n      "description": <description 2>,\n      "arguments": []\n    }\n  ]\n}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: It could swell to as much as $ 500 billion if we go to war in Iraq .\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify event type\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Extract all relevant arguments participating in the event.\n- Each argument must be an exact span from the text and assigned a semantic role.\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input.\n',
#    'response': '{"events": [{"description": "A conflict event representing an armed attack or engagement, indicating potential violence or military action between parties.", "trigger_text": "war", "type": "Conflict:Attack", "arguments": [{"text": "Iraq", "role": "Place"}, {"text": "as much as $500 billion", "role": "Beneficiary"}]}]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{\n  "events": [\n    {\n      "trigger_text": <trigger span>,\n      "type": <event type>,\n      "description": <description>,\n      "arguments": [\n        {"text": <argument span>, "role": <semantic role>},\n        {"text": <argument span 2>, "role": <semantic role 2>}\n      ]\n    },\n    {\n      "trigger_text": <trigger span 2>,\n      "type": <event type 2>,\n      "description": <description 2>,\n      "arguments": []\n    }\n  ]\n}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: NOVAK Former Arkansas Governor and U.S. Senator Dale Bumpers has just published a memoir called " The Best Lawyer in a One - Lawyer Town . " And it spans his life from the depression era to the Clinton era .\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify event type\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Extract all relevant arguments participating in the event.\n- Each argument must be an exact span from the text and assigned a semantic role.\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input.\n',
#    'response': '{"events": [{"description": "This event indicates the end of a person\'s official position in an organization or government role.", "trigger_text": "Former", "type": "Personnel:End-Position", "arguments": [{"text": "Arkansas Governor", "role": "Position"}, {"text": "U.S. Senator", "role": "Position"}]}]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{\n  "events": [\n    {\n      "trigger_text": <trigger span>,\n      "type": <event type>,\n      "description": <description>,\n      "arguments": [\n        {"text": <argument span>, "role": <semantic role>},\n        {"text": <argument span 2>, "role": <semantic role 2>}\n      ]\n    },\n    {\n      "trigger_text": <trigger span 2>,\n      "type": <event type 2>,\n      "description": <description 2>,\n      "arguments": []\n    }\n  ]\n}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: You cite a session you had with President Lyndon Johnson in Austin , I guess , at his ranch , right ? Here is what you quote our President Johnson to you .\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify event type\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Extract all relevant arguments participating in the event.\n- Each argument must be an exact span from the text and assigned a semantic role.\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input.\n',
#    'response': '{"events": [{"description": "An event representing a direct interaction or meeting between two individuals in a specific location and time.", "trigger_text": "session", "type": "Contact:Meet", "arguments": [{"text": "President Lyndon Johnson", "role": "Agent"}, {"text": "Austin", "role": "Place"}, {"text": "his ranch", "role": "Place"}]}]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{\n  "events": [\n    {\n      "trigger_text": <trigger span>,\n      "type": <event type>,\n      "description": <description>,\n      "arguments": [\n        {"text": <argument span>, "role": <semantic role>},\n        {"text": <argument span 2>, "role": <semantic role 2>}\n      ]\n    },\n    {\n      "trigger_text": <trigger span 2>,\n      "type": <event type 2>,\n      "description": <description 2>,\n      "arguments": []\n    }\n  ]\n}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: " When I was majority leader , and later president , I spent all my time pulling every power string I could find to pull , trying to pass bills that helped people . That made their lives better and the country stronger .\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify event type\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Extract all relevant arguments participating in the event.\n- Each argument must be an exact span from the text and assigned a semantic role.\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input.\n',
#    'response': '{"events": [{"description": "Marks the end of a person\'s official role in a political or organizational hierarchy.", "trigger_text": "was", "type": "Personnel:End-Position", "arguments": [{"text": "majority leader", "role": "Agent"}, {"text": "president", "role": "Beneficiary"}]}]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{\n  "events": [\n    {\n      "trigger_text": <trigger span>,\n      "type": <event type>,\n      "description": <description>,\n      "arguments": [\n        {"text": <argument span>, "role": <semantic role>},\n        {"text": <argument span 2>, "role": <semantic role 2>}\n      ]\n    },\n    {\n      "trigger_text": <trigger span 2>,\n      "type": <event type 2>,\n      "description": <description 2>,\n      "arguments": []\n    }\n  ]\n}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: I knew it was time to leave .\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify event type\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Extract all relevant arguments participating in the event.\n- Each argument must be an exact span from the text and assigned a semantic role.\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input.\n',
#    'response': '{"events": [{"description": "Signifies the conclusion of a person\'s role or position in an organization or group, indicating a transition out of duty or responsibility.", "trigger_text": "leave", "type": "Personnel:End-Position", "arguments": [{"text": "I", "role": "Agent"}]}]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{\n  "events": [\n    {\n      "trigger_text": <trigger span>,\n      "type": <event type>,\n      "description": <description>,\n      "arguments": [\n        {"text": <argument span>, "role": <semantic role>},\n        {"text": <argument span 2>, "role": <semantic role 2>}\n      ]\n    },\n    {\n      "trigger_text": <trigger span 2>,\n      "type": <event type 2>,\n      "description": <description 2>,\n      "arguments": []\n    }\n  ]\n}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: And I \'ve said many times , if we all agreed on everything , everybody would want to marry Betty and we would really be in a mess , would n\'t we , Bob ?\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify event type\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Extract all relevant arguments participating in the event.\n- Each argument must be an exact span from the text and assigned a semantic role.\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input.\n',
#    'response': '{"events": [{"description": "Marrying represents a formal union between two individuals, involving commitment and legal or social recognition of a marital relationship.", "trigger_text": "marry", "type": "Life:Marry", "arguments": [{"text": "Betty", "role": "Patient"}, {"text": "we", "role": "Agent"}]}]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{\n  "events": [\n    {\n      "trigger_text": <trigger span>,\n      "type": <event type>,\n      "description": <description>,\n      "arguments": [\n        {"text": <argument span>, "role": <semantic role>},\n        {"text": <argument span 2>, "role": <semantic role 2>}\n      ]\n    },\n    {\n      "trigger_text": <trigger span 2>,\n      "type": <event type 2>,\n      "description": <description 2>,\n      "arguments": []\n    }\n  ]\n}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: NOVAK Senator Bumpers , of the 22 senators of the old confederacy , when I got to Washington with the Associated Press , 45 years ago , 22 of them were Democrats , nine were Republicans .\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify event type\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Extract all relevant arguments participating in the event.\n- Each argument must be an exact span from the text and assigned a semantic role.\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input.\n',
#    'response': '{"events": [{"description": "Describes the physical movement of an entity from one location to another, such as traveling to a destination.", "trigger_text": "got", "type": "Movement:Transport", "arguments": [{"text": "Washington", "role": "Place"}, {"text": "Associated Press", "role": "Instrument"}]}]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{\n  "events": [\n    {\n      "trigger_text": <trigger span>,\n      "type": <event type>,\n      "description": <description>,\n      "arguments": [\n        {"text": <argument span>, "role": <semantic role>},\n        {"text": <argument span 2>, "role": <semantic role 2>}\n      ]\n    },\n    {\n      "trigger_text": <trigger span 2>,\n      "type": <event type 2>,\n      "description": <description 2>,\n      "arguments": []\n    }\n  ]\n}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: BUMPERS Bob , I think that the reason everybody in the south -- you know , first of all , we were -- when Franklin Roosevelt was elected president , we had been living what we thought was still a conquered nation after the Civil War .\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify event type\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Extract all relevant arguments participating in the event.\n- Each argument must be an exact span from the text and assigned a semantic role.\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input.\n',
#    'response': '{"events": [{"description": "This event denotes the election of a political leader, marking a significant change in leadership and governance.", "trigger_text": "elected", "type": "Personnel:Elect", "arguments": [{"text": "Franklin Roosevelt", "role": "Agent"}, {"text": "president", "role": "Beneficiary"}]}]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{\n  "events": [\n    {\n      "trigger_text": <trigger span>,\n      "type": <event type>,\n      "description": <description>,\n      "arguments": [\n        {"text": <argument span>, "role": <semantic role>},\n        {"text": <argument span 2>, "role": <semantic role 2>}\n      ]\n    },\n    {\n      "trigger_text": <trigger span 2>,\n      "type": <event type 2>,\n      "description": <description 2>,\n      "arguments": []\n    }\n  ]\n}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: It \'s amazing how someone can actually do two things at once . I \'m chewing gum and talking on the phone while writing this note . " Joshua , you could n\'t have said anything better .\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify event type\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Extract all relevant arguments participating in the event.\n- Each argument must be an exact span from the text and assigned a semantic role.\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input.\n',
#    'response': '{"events": [{"description": "Simultaneous phone conversation and note writing demonstrate multitasking during a single action.", "trigger_text": "talking", "type": "Contact:Phone-Write", "arguments": [{"text": "chewing gum", "role": "Patient"}, {"text": "writing this note", "role": "Agent"}]}]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{\n  "events": [\n    {\n      "trigger_text": <trigger span>,\n      "type": <event type>,\n      "description": <description>,\n      "arguments": [\n        {"text": <argument span>, "role": <semantic role>},\n        {"text": <argument span 2>, "role": <semantic role 2>}\n      ]\n    },\n    {\n      "trigger_text": <trigger span 2>,\n      "type": <event type 2>,\n      "description": <description 2>,\n      "arguments": []\n    }\n  ]\n}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: Dan Snyder of Baden , Pennsylvania writes , " Bush should torture the al Qaeda chief operations officer .\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify event type\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Extract all relevant arguments participating in the event.\n- Each argument must be an exact span from the text and assigned a semantic role.\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input.\n',
#    'response': '{"events": [{"description": "This event represents an act of violence or harm directed against an individual, typically involving illegal or unethical methods such as torture.", "trigger_text": "torture", "type": "Conflict:Attack", "arguments": [{"text": "al Qaeda chief operations officer", "role": "Patient"}, {"text": "Dan Snyder of Baden, Pennsylvania", "role": "Agent"}]}]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{\n  "events": [\n    {\n      "trigger_text": <trigger span>,\n      "type": <event type>,\n      "description": <description>,\n      "arguments": [\n        {"text": <argument span>, "role": <semantic role>},\n        {"text": <argument span 2>, "role": <semantic role 2>}\n      ]\n    },\n    {\n      "trigger_text": <trigger span 2>,\n      "type": <event type 2>,\n      "description": <description 2>,\n      "arguments": []\n    }\n  ]\n}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: If the budget goes through as is , why do n\'t Mr. Begala and Mr. Carville just donate the extra tax money they do n\'t want ?\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify event type\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Extract all relevant arguments participating in the event.\n- Each argument must be an exact span from the text and assigned a semantic role.\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input.\n',
#    'response': '{"events": [{"description": "An event where money is transferred from one party to another, typically involving a donation or contribution.", "trigger_text": "donate", "type": "Transaction:Transfer-Money", "arguments": [{"text": "Mr. Begala and Mr. Carville", "role": "Agent"}, {"text": "the extra tax money they don\'t want", "role": "Beneficiary"}]}]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{\n  "events": [\n    {\n      "trigger_text": <trigger span>,\n      "type": <event type>,\n      "description": <description>,\n      "arguments": [\n        {"text": <argument span>, "role": <semantic role>},\n        {"text": <argument span 2>, "role": <semantic role 2>}\n      ]\n    },\n    {\n      "trigger_text": <trigger span 2>,\n      "type": <event type 2>,\n      "description": <description 2>,\n      "arguments": []\n    }\n  ]\n}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: BEGALA I \'ll donate to the Democrats .\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify event type\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Extract all relevant arguments participating in the event.\n- Each argument must be an exact span from the text and assigned a semantic role.\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input.\n',
#    'response': '{"events": [{"description": "This event represents a monetary contribution given to a political party, indicating financial support for democratic candidates or causes.", "trigger_text": "donate", "type": "Transaction:Transfer-Money", "arguments": [{"text": "to the Democrats", "role": "Beneficiary"}]}]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{\n  "events": [\n    {\n      "trigger_text": <trigger span>,\n      "type": <event type>,\n      "description": <description>,\n      "arguments": [\n        {"text": <argument span>, "role": <semantic role>},\n        {"text": <argument span 2>, "role": <semantic role 2>}\n      ]\n    },\n    {\n      "trigger_text": <trigger span 2>,\n      "type": <event type 2>,\n      "description": <description 2>,\n      "arguments": []\n    }\n  ]\n}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: He had to sue to become our president , and he keeps trying to bribe other countries \' democratic governments into his supporting his agenda .\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify event type\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Extract all relevant arguments participating in the event.\n- Each argument must be an exact span from the text and assigned a semantic role.\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input.\n',
#    'response': '{"events": [{"description": "Suing is a legal action initiated to seek justice or redress, typically involving a formal complaint against another party in a court of law.", "trigger_text": "sue", "type": "Justice:Sue", "arguments": [{"text": "to become our president", "role": "Purpose"}]}]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{\n  "events": [\n    {\n      "trigger_text": <trigger span>,\n      "type": <event type>,\n      "description": <description>,\n      "arguments": [\n        {"text": <argument span>, "role": <semantic role>},\n        {"text": <argument span 2>, "role": <semantic role 2>}\n      ]\n    },\n    {\n      "trigger_text": <trigger span 2>,\n      "type": <event type 2>,\n      "description": <description 2>,\n      "arguments": []\n    }\n  ]\n}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: And now how are people going to argue that the U.S. can no longer both fight a war with Iraq and also fight terrorism , specifically al Qaeda ?\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify event type\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Extract all relevant arguments participating in the event.\n- Each argument must be an exact span from the text and assigned a semantic role.\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input.\n',
#    'response': '{"events": [{"description": "Represents an instance where one party launches an aggressive action against another in a hostile or violent context.", "trigger_text": "war", "type": "Conflict:Attack", "arguments": [{"text": "Iraq", "role": "Patient"}]}, {"description": "Represents an instance where one party launches an aggressive action against another in a hostile or violent context.", "trigger_text": "terrorism", "type": "Conflict:Attack", "arguments": [{"text": "al Qaeda", "role": "Attacker"}]}]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{\n  "events": [\n    {\n      "trigger_text": <trigger span>,\n      "type": <event type>,\n      "description": <description>,\n      "arguments": [\n        {"text": <argument span>, "role": <semantic role>},\n        {"text": <argument span 2>, "role": <semantic role 2>}\n      ]\n    },\n    {\n      "trigger_text": <trigger span 2>,\n      "type": <event type 2>,\n      "description": <description 2>,\n      "arguments": []\n    }\n  ]\n}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: We go to war in Iraq , 200,000 people start protesting in Pakistan , they put too much pressure on the government .\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify event type\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Extract all relevant arguments participating in the event.\n- Each argument must be an exact span from the text and assigned a semantic role.\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input.\n',
#    'response': '{"events": [{"description": "A military conflict initiated by one party against another, involving violence or hostile actions in a specific location and time.", "trigger_text": "war", "type": "Conflict:Attack", "arguments": [{"text": "Iraq", "role": "Place"}]}, {"description": "A peaceful gathering of people to express political or social opinions, often in response to government actions or policies.", "trigger_text": "protesting", "type": "Conflict:Demonstrate", "arguments": [{"text": "200,000 people", "role": "Agent"}, {"text": "Pakistan", "role": "Place"}]}]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{\n  "events": [\n    {\n      "trigger_text": <trigger span>,\n      "type": <event type>,\n      "description": <description>,\n      "arguments": [\n        {"text": <argument span>, "role": <semantic role>},\n        {"text": <argument span 2>, "role": <semantic role 2>}\n      ]\n    },\n    {\n      "trigger_text": <trigger span 2>,\n      "type": <event type 2>,\n      "description": <description 2>,\n      "arguments": []\n    }\n  ]\n}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: We go to war in Iraq , it would be the worst thing we can do ...\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify event type\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Extract all relevant arguments participating in the event.\n- Each argument must be an exact span from the text and assigned a semantic role.\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input.\n',
#    'response': '{"events": [{"description": "A military conflict initiated by one party against another, involving violence and strategic confrontation in a specific location or time.", "trigger_text": "war", "type": "Conflict:Attack", "arguments": [{"text": "Iraq", "role": "Place"}, {"text": "we", "role": "Agent"}]}]}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{\n  "events": [\n    {\n      "trigger_text": <trigger span>,\n      "type": <event type>,\n      "description": <description>,\n      "arguments": [\n        {"text": <argument span>, "role": <semantic role>},\n        {"text": <argument span 2>, "role": <semantic role 2>}\n      ]\n    },\n    {\n      "trigger_text": <trigger span 2>,\n      "type": <event type 2>,\n      "description": <description 2>,\n      "arguments": []\n    }\n  ]\n}\n\n- If no events are detected, return: {"events": []}',
# ...
#    'user_prompt': 'Given an input text: The United States still does n\'t have the nine votes needed to win approval of the resolution , according to supporters and opponents , and many undecided council members are looking for a compromise .\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify event type\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Extract all relevant arguments participating in the event.\n- Each argument must be an exact span from the text and assigned a semantic role.\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input.\n',
#    'response': '{"events": []}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{\n  "events": [\n    {\n      "trigger_text": <trigger span>,\n      "type": <event type>,\n      "description": <description>,\n      "arguments": [\n        {"text": <argument span>, "role": <semantic role>},\n        {"text": <argument span 2>, "role": <semantic role 2>}\n      ]\n    },\n    {\n      "trigger_text": <trigger span 2>,\n      "type": <event type 2>,\n      "description": <description 2>,\n      "arguments": []\n    }\n  ]\n}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: Milosevic and his wife wielded enormous power in Yugoslavia for more than a decade before he was swept out of power after a popular revolt in October 2000 .\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify event type\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Extract all relevant arguments participating in the event.\n- Each argument must be an exact span from the text and assigned a semantic role.\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input.\n',
#    'response': '{"events": []}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{\n  "events": [\n    {\n      "trigger_text": <trigger span>,\n      "type": <event type>,\n      "description": <description>,\n      "arguments": [\n        {"text": <argument span>, "role": <semantic role>},\n        {"text": <argument span 2>, "role": <semantic role 2>}\n      ]\n    },\n    {\n      "trigger_text": <trigger span 2>,\n      "type": <event type 2>,\n      "description": <description 2>,\n      "arguments": []\n    }\n  ]\n}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: `` At the front of those that must be rid of these weapons is the Zionist entity , \'\' he said in a reference to Israel , adding that the order should `` move on after this region to America . \'\'\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify event type\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Extract all relevant arguments participating in the event.\n- Each argument must be an exact span from the text and assigned a semantic role.\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input.\n',
#    'response': '{"events": []}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{\n  "events": [\n    {\n      "trigger_text": <trigger span>,\n      "type": <event type>,\n      "description": <description>,\n      "arguments": [\n        {"text": <argument span>, "role": <semantic role>},\n        {"text": <argument span 2>, "role": <semantic role 2>}\n      ]\n    },\n    {\n      "trigger_text": <trigger span 2>,\n      "type": <event type 2>,\n      "description": <description 2>,\n      "arguments": []\n    }\n  ]\n}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: NEWS STORY\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify event type\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Extract all relevant arguments participating in the event.\n- Each argument must be an exact span from the text and assigned a semantic role.\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input.\n',
#    'response': '{"events": []}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{\n  "events": [\n    {\n      "trigger_text": <trigger span>,\n      "type": <event type>,\n      "description": <description>,\n      "arguments": [\n        {"text": <argument span>, "role": <semantic role>},\n        {"text": <argument span 2>, "role": <semantic role 2>}\n      ]\n    },\n    {\n      "trigger_text": <trigger span 2>,\n      "type": <event type 2>,\n      "description": <description 2>,\n      "arguments": []\n    }\n  ]\n}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: Unlike the soft - spoken Gul , Erdogan has a reputation as a fighter .\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify event type\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Extract all relevant arguments participating in the event.\n- Each argument must be an exact span from the text and assigned a semantic role.\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input.\n',
#    'response': '{"events": []}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{\n  "events": [\n    {\n      "trigger_text": <trigger span>,\n      "type": <event type>,\n      "description": <description>,\n      "arguments": [\n        {"text": <argument span>, "role": <semantic role>},\n        {"text": <argument span 2>, "role": <semantic role 2>}\n      ]\n    },\n    {\n      "trigger_text": <trigger span 2>,\n      "type": <event type 2>,\n      "description": <description 2>,\n      "arguments": []\n    }\n  ]\n}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: `` I would like to see that the European Union countries will come through this difficult moment with a determination to work for peace and look to the future , \'\' EU foreign policy chief Javier Solana said .\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify event type\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Extract all relevant arguments participating in the event.\n- Each argument must be an exact span from the text and assigned a semantic role.\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input.\n',
#    'response': '{"events": []}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{\n  "events": [\n    {\n      "trigger_text": <trigger span>,\n      "type": <event type>,\n      "description": <description>,\n      "arguments": [\n        {"text": <argument span>, "role": <semantic role>},\n        {"text": <argument span 2>, "role": <semantic role 2>}\n      ]\n    },\n    {\n      "trigger_text": <trigger span 2>,\n      "type": <event type 2>,\n      "description": <description 2>,\n      "arguments": []\n    }\n  ]\n}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: Diller will continue to play a critical role in the future of Vivendi \'s entertainment arm .\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify event type\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Extract all relevant arguments participating in the event.\n- Each argument must be an exact span from the text and assigned a semantic role.\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input.\n',
#    'response': '{"events": []}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{\n  "events": [\n    {\n      "trigger_text": <trigger span>,\n      "type": <event type>,\n      "description": <description>,\n      "arguments": [\n        {"text": <argument span>, "role": <semantic role>},\n        {"text": <argument span 2>, "role": <semantic role 2>}\n      ]\n    },\n    {\n      "trigger_text": <trigger span 2>,\n      "type": <event type 2>,\n      "description": <description 2>,\n      "arguments": []\n    }\n  ]\n}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: _\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify event type\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Extract all relevant arguments participating in the event.\n- Each argument must be an exact span from the text and assigned a semantic role.\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input.\n',
#    'response': '{"events": []}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{\n  "events": [\n    {\n      "trigger_text": <trigger span>,\n      "type": <event type>,\n      "description": <description>,\n      "arguments": [\n        {"text": <argument span>, "role": <semantic role>},\n        {"text": <argument span 2>, "role": <semantic role 2>}\n      ]\n    },\n    {\n      "trigger_text": <trigger span 2>,\n      "type": <event type 2>,\n      "description": <description 2>,\n      "arguments": []\n    }\n  ]\n}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: He said he drank three martinis and some wine before getting behind the wheel .\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify event type\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Extract all relevant arguments participating in the event.\n- Each argument must be an exact span from the text and assigned a semantic role.\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input.\n',
#    'response': '{"events": []}'},
#   {'system_prompt': 'You are an open-domain event extraction system. Your task is to identify events expressed or clearly implied in a given text.\nIMPORTANT:Output ONLY valid JSON. No explanations, no markdown, no extra text.\nOutput Format (JSON only, no markdown):\n\n{\n  "events": [\n    {\n      "trigger_text": <trigger span>,\n      "type": <event type>,\n      "description": <description>,\n      "arguments": [\n        {"text": <argument span>, "role": <semantic role>},\n        {"text": <argument span 2>, "role": <semantic role 2>}\n      ]\n    },\n    {\n      "trigger_text": <trigger span 2>,\n      "type": <event type 2>,\n      "description": <description 2>,\n      "arguments": []\n    }\n  ]\n}\n\n- If no events are detected, return: {"events": []}',
#    'user_prompt': 'Given an input text: The court order was requested by Jack Welch \'s attorney , Daniel K. Webb , who said Welch would likely be asked about his business dealings , his health and entries in his personal diary .\n\nYour task is to extract all events present in the text. The text may contain zero, one, or multiple events.\n\nFor each event:\n- Identify event type\n- Identify a trigger: the word or phrase that most clearly indicates the event.\n- Extract all relevant arguments participating in the event.\n- Each argument must be an exact span from the text and assigned a semantic role.\n- Description: explaining what this event type means\n\nConstraints and Guidelines\n- Do not invent information not supported by the text.\n- Do not paraphrase triggers or arguments.\n- The "text" field must exactly match a span in the original input.\n',
#    'response': '{"events": []}'}])

# %%
maven = load_dataset("datht/maven-event-dataset")

# %%
maven_train, maven_dev, maven_test = save(maven, "maven")

# %%
geneva = load_dataset("datht/geneva-event-dataset")

geneva_train, geneva_dev, geneva_test = save(geneva, "geneva")

# %%
with open(f"data/train.jsonl", "w", encoding="utf-8") as f:
    for item in maven_train + geneva_train:
        f.write(json.dumps(item, ensure_ascii=False) + "\n")

with open(f"data/dev.jsonl", "w", encoding="utf-8") as f:
    for item in geneva_dev + maven_dev:
        f.write(json.dumps(item, ensure_ascii=False) + "\n")

with open(f"data/test.jsonl", "w", encoding="utf-8") as f:
    for item in maven_test + geneva_test:
        f.write(json.dumps(item, ensure_ascii=False) + "\n")

# %%
data, full_len, prompt_len, response_len = process_ace_data(geneva["train"])

# %%
len(data)
# Out:
# 26278

# %%
np.median(full_len)
# Out:
# np.float64(414.0)

# %%
np.sum(np.array(full_len) > 768)
# Out:
# np.int64(3)

# %%
np.sum(np.array(prompt_len) > 460)
# Out:
# np.int64(5)

# %%
np.max(response_len)
# Out:
# np.int64(296)

# %%
rams = load_dataset("datht/rams-event-dataset")

# %%
data, full_len, prompt_len, response_len = process_ace_data(rams["train"])

# %%
len(data)
# Out:
# 7402

# %%
geneva = load_dataset("datht/geneva-event-dataset")

# %%
data, full_len, prompt_len, response_len = process_ace_data(geneva["train"])

# %%
len(data)
# Out:
# 1968

# %%
np.median(full_len)
# Out:
# np.float64(448.0)

# %%
np.sum(np.array(full_len) > 768)
# Out:
# np.int64(8)

# %%
print("{\"events\": [{\"trigger_text\": \"sponsored\", \"type\": \"Supply\", \"arguments\": []}]}{\"events\": [{\"trigger_text\": \"tour\", \"type\": \"Traveling\", \"arguments\": []}]}{\"events\": [{\"trigger_text\": \"promotion\", \"type\": \"Cause_change_of_position_on_a_scale\", \"arguments\": []}]}{\"events\": [{\"trigger_text\": \"concert\", \"type\": \"Social_event\", \"arguments\": []}]}{\"events\": [{\"trigger_text\": \"sponsored\", \"type\": \"Supply\", \"arguments\": []}]}{\"events\": [{\"trigger_text\": \"tour\", \"type\": \"Traveling\", \"arguments\": []}]}{\"events\": [{\"trigger_text\": \"sponsored\", \"type\": \"Supply\", \"arguments\": []}]}{\"events\": [{\"trigger_text\": \"suggested\", \"type\": \"Convincing\", \"arguments\": []}]}{\"events\": [{\"trigger_text\": \"tour\", \"type\": \"Traveling\", \"arguments\": []}]}{\"events\": [{\"trigger_text\": \"tour\", \"type\": \"Traveling\", \"arguments\": []}]}{\"events\": [{\"trigger_text\": \"sponsored\", \"type\": \"Supply\", \"arguments\": []}]}{\"events\": [{\"trigger_text\": \"suggested\", \"type\": \"Convincing\", \"arguments\": []}]}{\"events\": [{\"trigger_text\": \"tour\", \"")
# Out:
# {"events": [{"trigger_text": "sponsored", "type": "Supply", "arguments": []}]}{"events": [{"trigger_text": "tour", "type": "Traveling", "arguments": []}]}{"events": [{"trigger_text": "promotion", "type": "Cause_change_of_position_on_a_scale", "arguments": []}]}{"events": [{"trigger_text": "concert", "type": "Social_event", "arguments": []}]}{"events": [{"trigger_text": "sponsored", "type": "Supply", "arguments": []}]}{"events": [{"trigger_text": "tour", "type": "Traveling", "arguments": []}]}{"events": [{"trigger_text": "sponsored", "type": "Supply", "arguments": []}]}{"events": [{"trigger_text": "suggested", "type": "Convincing", "arguments": []}]}{"events": [{"trigger_text": "tour", "type": "Traveling", "arguments": []}]}{"events": [{"trigger_text": "tour", "type": "Traveling", "arguments": []}]}{"events": [{"trigger_text": "sponsored", "type": "Supply", "arguments": []}]}{"events": [{"trigger_text": "suggested", "type": "Convincing", "arguments": []}]}{"events": [{"trigger_text": "tour", "
