# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from peft import PeftModel

base_model_path = "Qwen/Qwen3-8B" 
lora_path = "results/qwen3/sft_8B/e5-bs1-lr0.0001-G16-N2-NN1-lora-16-64-0.1/294" 
save_path = "merged_model"

# Load base model
base_model = AutoModelForCausalLM.from_pretrained(
    base_model_path,
    torch_dtype=torch.bfloat16,   # hoặc float16
    device_map="cpu"
)

# Load LoRA vào base model
model = PeftModel.from_pretrained(base_model, lora_path)

# Merge LoRA weights vào base weights
model = model.merge_and_unload()

# Save model hoàn chỉnh
model.save_pretrained(save_path)

# Save tokenizer (quan trọng)
tokenizer = AutoTokenizer.from_pretrained(base_model_path)
tokenizer.save_pretrained(save_path)

print("✅ Merge hoàn tất và đã lưu model.")
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# /home/hungpv/miniconda3/envs/ad-sampling/compiler_compat/ld: cannot find -laio: No such file or directory
# collect2: error: ld returned 1 exit status
# /home/hungpv/miniconda3/envs/ad-sampling/compiler_compat/ld: cannot find -laio: No such file or directory
# collect2: error: ld returned 1 exit status
# ✅ Merge hoàn tất và đã lưu model.

# %%
from huggingface_hub import login, upload_folder

# (optional) Login with your Hugging Face credentials
login("")

# Push your model files
upload_folder(folder_path="results", repo_id="VoCuc/open-ed-ckpt", repo_type="model")
# Out:
# It seems you are trying to upload a large folder at once. This might take some time and then fail if the folder is too large. For such cases, it is recommended to upload in smaller batches or to use `HfApi().upload_large_folder(...)`/`hf upload-large-folder` instead. For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/upload#upload-a-large-folder.
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# CommitInfo(commit_url='https://huggingface.co/VoCuc/open-ed-ckpt/commit/560e008cf4dc793f2faea9defeefb2e4e3fc5311', commit_message='Upload folder using huggingface_hub', commit_description='', oid='560e008cf4dc793f2faea9defeefb2e4e3fc5311', pr_url=None, repo_url=RepoUrl('https://huggingface.co/VoCuc/open-ed-ckpt', endpoint='https://huggingface.co', repo_type='model', repo_id='VoCuc/open-ed-ckpt'), pr_revision=None, pr_num=None)

# %%
print("sk")
# Out:
# sk
